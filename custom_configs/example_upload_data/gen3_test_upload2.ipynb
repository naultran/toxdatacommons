# %% [markdown]
# <h1 align="center">upload data version2</h1>
#
# This Jupyter notebook demonstrates how to upload data to [ToxDataCommons](fairtox.com).
#
# __Created by: Shuangyu Zhap, Michigan State University__
#
# -------

# %%
import pandas as pd
import numpy as np
import subprocess
import sys
import gen3
import json
from gen3.submission import Gen3Submission
from gen3.auth import Gen3Auth
from gen3.index import Gen3Index
from gen3.query import Gen3Query
from gen3.metadata import Gen3Metadata
from gen3.file import Gen3File
import os

# download and import some custom Python scripts from https://github.com/cgmeyer/gen3sdk-python
# os.system("wget https://raw.githubusercontent.com/cgmeyer/gen3sdk-python/master/expansion/expansion.py")
from expansion import Gen3Expansion
# Out:
# --2023-06-16 14:36:24--  https://raw.githubusercontent.com/cgmeyer/gen3sdk-python/master/expansion/expansion.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 224796 (220K) [text/plain]
# Saving to: 'expansion.py'
#
#      0K .......... .......... .......... .......... .......... 22% 10.6M 0s
#     50K .......... .......... .......... .......... .......... 45% 9.65M 0s
#    100K .......... .......... .......... .......... .......... 68% 11.1M 0s
#    150K .......... .......... .......... .......... .......... 91% 13.2M 0s
#    200K .......... .........                                  100% 19.3M=0.02s
#
# 2023-06-16 14:36:24 (11.4 MB/s) - 'expansion.py' saved [224796/224796]

# %%
api = 'https://fairtox.com/'
cred = '/Users/apple/Desktop/test_gen3/credentials23.json'
auth = Gen3Auth(api, refresh_file=cred)
sub = Gen3Submission(api, auth)
query = Gen3Query(auth)
index = Gen3Index(auth)
file = Gen3File(auth)
metadata = Gen3Metadata(auth)
exp = Gen3Expansion(api,auth,sub)

# %% [markdown]
# ## create program

# %%
prog = 'MyFirstProgram'

prog_txt = """{
    "dbgap_accession_number": "%s",
    "type": "program",
    "name": "%s"
}""" % (prog,prog)

prog_json = json.loads(prog_txt)
data = sub.create_program(json=prog_json)

# %% [markdown]
# ## create project

# %%
proj_txt = """{
    "availability_type": "Open",
    "code": "MyFirstProject",
    "dbgap_accession_number": "MyFirstProject",
    "type": "project",
    "contact_name": "Timonthy Zacharewski",
    "institution": "MSU",
    "description": "test",
    "email_address": "xxxxx@fdas.sdfs",
    "telephone_number": "ssd-asdf-asdf"
    }"""
proj_json = json.loads(proj_txt)
data = sub.create_project(program="MyFirstProgram",json=proj_json)

# %% [markdown]
# ## upload other nodes

# %%
df = pd.read_table("/Users/apple/Desktop/test_gen3/DH_ExportedFiles/study.tsv")
df.head()
# Out:
#     type submitter_id   projects.code                   study_title  \
# 0  study       Prj171  MyFirstProject  Prj171_Mm_TCDD_RDDR-28D_Male
#
#                                    study_description          study_design  \
# 0  Male mice were treated with TCDD every 4 days ...  dose response design
#
#        study_type experimental_setting      organism  provenance
# 0  Toxicogenomics              in vivo  Mus musculus         NaN

# %%
# study
df = pd.read_table('/Users/apple/Desktop/test_gen3/DH_ExportedFiles/study.tsv')
df["projects.code"].fillna("MyFirstProject", inplace=True)
df.to_csv('/Users/apple/Desktop/test_gen3/DH_ExportedFiles/study.tsv', sep='\t', index=False)
data = sub.submit_file(filename="/Users/apple/Desktop/test_gen3/DH_ExportedFiles/study.tsv", project_id="MyFirstProgram-MyFirstProject")
# Out:
# Submitting /Users/apple/Desktop/test_gen3/DH_ExportedFiles/study.tsv with 1 records.
# Chunk 1 (chunk size: 30, submitted: 0 of 1)
# 	 Succeeded: 1 entities.
# Finished data submission.
# Successful records: 1
# Failed invalid records: 0

# %%
df = pd.read_table('/Users/apple/Desktop/test_gen3/DH_ExportedFiles/contact.tsv')
df.head()
# Out:
#       type                submitter_id studies.submitter_id    last_name  \
# 0  contact  Prj171:Zacharewski:Timothy               Prj171  Zacharewski
#
#   first_name  middle_name        contact_orcid     contact_email  \
# 0    Timothy          NaN  0000-0002-3662-7919  tzachare@msu.edu
#
#   contact_telephone                  contact_department  \
# 0      517-884-2054  Biochemistry and Molecular Biology
#
#          contact_institution            location  provenance
# 0  Michigan State University  48824:East Lansing         NaN

# %%
# contact
data = sub.submit_file(filename="/Users/apple/Desktop/test_gen3/DH_ExportedFiles/contact.tsv", project_id="MyFirstProgram-MyFirstProject")
# Out:
# Submitting /Users/apple/Desktop/test_gen3/DH_ExportedFiles/contact.tsv with 1 records.
# Chunk 1 (chunk size: 30, submitted: 0 of 1)
# 	 Succeeded: 1 entities.
# Finished data submission.
# Successful records: 1
# Failed invalid records: 0

# %%
df = pd.read_table('/Users/apple/Desktop/test_gen3/DH_ExportedFiles/funding.tsv')
df.head()
# Out:
#       type                    submitter_id studies.submitter_id  \
# 0  funding  Prj171:R01ES029541:P42ES004911               Prj171
#
#                 support_id                           support_source  \
# 0  R01ES029541:P42ES004911  NIEHS; Superfund Basic Research Program
#
#    provenance
# 0         NaN

# %%
# funding
data = sub.submit_file(filename="/Users/apple/Desktop/test_gen3/DH_ExportedFiles/funding.tsv", project_id="MyFirstProgram-MyFirstProject")
# Out:
# Submitting /Users/apple/Desktop/test_gen3/DH_ExportedFiles/funding.tsv with 1 records.
# Chunk 1 (chunk size: 30, submitted: 0 of 1)
# 	 Succeeded: 1 entities.
# Finished data submission.
# Successful records: 1
# Failed invalid records: 0

# %%
df = pd.read_table('/Users/apple/Desktop/test_gen3/DH_ExportedFiles/publication.tsv')
df.head()
# Out:
#           type    submitter_id studies.submitter_id   PMC_id  \
# 0  publication  Prj171:9418907               Prj171  9418907
#
#                          DOI      PMID  provenance
# 0  10.1016/j.jbc.2022.102301  35931118         NaN

# %%
# publication
data = sub.submit_file(filename="/Users/apple/Desktop/test_gen3/DH_ExportedFiles/publication.tsv", project_id="MyFirstProgram-MyFirstProject")
# Out:
# Submitting /Users/apple/Desktop/test_gen3/DH_ExportedFiles/publication.tsv with 1 records.
# Chunk 1 (chunk size: 30, submitted: 0 of 1)
# 	 Succeeded: 1 entities.
# Finished data submission.
# Successful records: 1
# Failed invalid records: 0

# %%
df = pd.read_table("/Users/apple/Desktop/test_gen3/DH_ExportedFiles/subject.tsv")
df.head()
# Out:
#       type submitter_id studies.submitter_id  start_date  start_date_age  \
# 0  subject   Prj171:M97               Prj171  2022-03-09              23
# 1  subject   Prj171:M94               Prj171  2022-03-09              23
# 2  subject   Prj171:M92               Prj171  2022-03-09              23
# 3  subject   Prj171:M91               Prj171  2022-03-09              23
# 4  subject   Prj171:M89               Prj171  2022-03-09              23
#
#   experiment_start_date  experiment_start_zt   sex       strain  \
# 0            2022-03-14                    0  male  C57BL/6NCrl
# 1            2022-03-14                    0  male  C57BL/6NCrl
# 2            2022-03-14                    0  male  C57BL/6NCrl
# 3            2022-03-14                    0  male  C57BL/6NCrl
# 4            2022-03-14                    0  male  C57BL/6NCrl
#
#                  strain_source euthanasia_date  euthanasia_zt  \
# 0  Charles Rivers Laboratories      2022-04-11              0
# 1  Charles Rivers Laboratories      2022-04-11              0
# 2  Charles Rivers Laboratories      2022-04-11              0
# 3  Charles Rivers Laboratories      2022-04-11              0
# 4  Charles Rivers Laboratories      2022-04-11              0
#
#              euthanasia_method  provenance
# 0  Carbon dioxide asphyxiation         NaN
# 1  Carbon dioxide asphyxiation         NaN
# 2  Carbon dioxide asphyxiation         NaN
# 3  Carbon dioxide asphyxiation         NaN
# 4  Carbon dioxide asphyxiation         NaN

# %%
# subject
data = sub.submit_file(filename="/Users/apple/Desktop/test_gen3/DH_ExportedFiles/subject.tsv", project_id="MyFirstProgram-MyFirstProject")
# Out:
# Submitting /Users/apple/Desktop/test_gen3/DH_ExportedFiles/subject.tsv with 144 records.
# Chunk 1 (chunk size: 30, submitted: 0 of 144)
# 	 Succeeded: 30 entities.
# Chunk 2 (chunk size: 30, submitted: 30 of 144)
# 	 Succeeded: 30 entities.
# Chunk 3 (chunk size: 30, submitted: 60 of 144)
# 	 Succeeded: 30 entities.
# Chunk 4 (chunk size: 30, submitted: 90 of 144)
# 	 Succeeded: 30 entities.
# Chunk 5 (chunk size: 30, submitted: 120 of 144)
# 	 Succeeded: 24 entities.
# Finished data submission.
# Successful records: 144
# Failed invalid records: 0

# %%
# treatment 
data = sub.submit_file(filename="/Users/apple/Desktop/test_gen3/DH_ExportedFiles/treatment.tsv", project_id="MyFirstProgram-MyFirstProject")
# Out:
# Submitting /Users/apple/Desktop/test_gen3/DH_ExportedFiles/treatment.tsv with 56 records.
# Chunk 1 (chunk size: 30, submitted: 0 of 56)
# 	 Succeeded: 30 entities.
# Chunk 2 (chunk size: 30, submitted: 30 of 56)
# 	 Succeeded: 26 entities.
# Finished data submission.
# Successful records: 56
# Failed invalid records: 0

# %%
# housing
data = sub.submit_file(filename="/Users/apple/Desktop/test_gen3/DH_ExportedFiles/housing.tsv", project_id="MyFirstProgram-MyFirstProject")
# Out:
# Submitting /Users/apple/Desktop/test_gen3/DH_ExportedFiles/housing.tsv with 48 records.
# Chunk 1 (chunk size: 30, submitted: 0 of 48)
# 	 Succeeded: 30 entities.
# Chunk 2 (chunk size: 30, submitted: 30 of 48)
# 	 Succeeded: 18 entities.
# Finished data submission.
# Successful records: 48
# Failed invalid records: 0

# %%
df = pd.read_table("/Users/apple/Desktop/test_gen3/DH_ExportedFiles/diet.tsv")
df.head()
# Out:
#    type            submitter_id  \
# 0  diet  Prj171:8940:2022-03-09
#
#                                housings.submitter_id        date  \
# 0  Prj171:Cage033:2022-03-09,Prj171:Cage032:2022-...  2022-03-09
#
#    feed_catalog_number    feed_description           feed_name    feed_vendor  \
# 0                 8940  Harlan Teklad 8940  Harlan Teklad 8940  Harlan Teklad
#
#   water_type feed_paradigm  provenance
# 0   Innovive    ad libitum         NaN

# %%
# diet 
data = sub.submit_file(filename="/Users/apple/Desktop/test_gen3/DH_ExportedFiles/diet.tsv", project_id="MyFirstProgram-MyFirstProject")
# Out:
# Submitting /Users/apple/Desktop/test_gen3/DH_ExportedFiles/diet.tsv with 1 records.
# Chunk 1 (chunk size: 30, submitted: 0 of 1)
# 	 Succeeded: 1 entities.
# Finished data submission.
# Successful records: 1
# Failed invalid records: 0

# %%
df = pd.read_table("/Users/apple/Desktop/test_gen3/DH_ExportedFiles/sample.tsv")
df.head()
# Out:
#      type submitter_id subjects.submitter_id        date  \
# 0  sample    Prj171:L1             Prj171:M1  2022-04-11
# 1  sample    Prj171:L2             Prj171:M2  2022-04-11
# 2  sample    Prj171:L3             Prj171:M3  2022-04-11
# 3  sample    Prj171:L4             Prj171:M4  2022-04-11
# 4  sample    Prj171:L5             Prj171:M5  2022-04-11
#
#   biospecimen_anatomic_site  method_of_sample_procurement preservation_method  \
# 0                     Liver                           NaN         Snap Frozen
# 1                     Liver                           NaN         Snap Frozen
# 2                     Liver                           NaN         Snap Frozen
# 3                     Liver                           NaN         Snap Frozen
# 4                     Liver                           NaN         Snap Frozen
#
#    weight  volume      storage_vessel  \
# 0     NaN     NaN  2 mL screwcap tube
# 1     NaN     NaN  2 mL screwcap tube
# 2     NaN     NaN  2 mL screwcap tube
# 3     NaN     NaN  2 mL screwcap tube
# 4     NaN     NaN  2 mL screwcap tube
#
#                                  collection_protocol  \
# 0  Tissue was carefully excised and immediately f...
# 1  Tissue was carefully excised and immediately f...
# 2  Tissue was carefully excised and immediately f...
# 3  Tissue was carefully excised and immediately f...
# 4  Tissue was carefully excised and immediately f...
#
#                               provenance
# 0  DataHarmonizer v1.4.10, Sample v4.3.1
# 1  DataHarmonizer v1.4.10, Sample v4.3.1
# 2  DataHarmonizer v1.4.10, Sample v4.3.1
# 3  DataHarmonizer v1.4.10, Sample v4.3.1
# 4  DataHarmonizer v1.4.10, Sample v4.3.1

# %%
data = sub.submit_file(filename="/Users/apple/Desktop/test_gen3/DH_ExportedFiles/sample.tsv", project_id="MyFirstProgram-MyFirstProject")
# Out:
# Submitting /Users/apple/Desktop/test_gen3/DH_ExportedFiles/sample.tsv with 268 records.
# Chunk 1 (chunk size: 30, submitted: 0 of 268)
# 	 Succeeded: 30 entities.
# Chunk 2 (chunk size: 30, submitted: 30 of 268)
# 	 Succeeded: 30 entities.
# Chunk 3 (chunk size: 30, submitted: 60 of 268)
# 	 Succeeded: 30 entities.
# Chunk 4 (chunk size: 30, submitted: 90 of 268)
# 	 Succeeded: 30 entities.
# Chunk 5 (chunk size: 30, submitted: 120 of 268)
# 	 Succeeded: 30 entities.
# Chunk 6 (chunk size: 30, submitted: 150 of 268)
# 	 Succeeded: 30 entities.
# Chunk 7 (chunk size: 30, submitted: 180 of 268)
# 	 Succeeded: 30 entities.
# Chunk 8 (chunk size: 30, submitted: 210 of 268)
# 	 Succeeded: 30 entities.
# Chunk 9 (chunk size: 30, submitted: 240 of 268)
# 	 Succeeded: 28 entities.
# Finished data submission.
# Successful records: 268
# Failed invalid records: 0

# %%
df = pd.read_table("/Users/apple/Desktop/test_gen3/DH_ExportedFiles/aliquot.tsv")
df.head()
# Out:
#       type                    submitter_id samples.submitter_id analyte_type  \
# 0  aliquot   Prj171:metabolite_extract_L75           Prj171:L75      Aqueous
# 1  aliquot  Prj171:metabolite_extract_L121          Prj171:L121      Aqueous
# 2  aliquot   Prj171:metabolite_extract_L27           Prj171:L27      Aqueous
# 3  aliquot  Prj171:metabolite_extract_L122          Prj171:L122      Aqueous
# 4  aliquot  Prj171:metabolite_extract_L123          Prj171:L123      Aqueous
#
#    derivitization extract_preservation_method  \
# 0             NaN                        -80C
# 1             NaN                        -80C
# 2             NaN                        -80C
# 3             NaN                        -80C
# 4             NaN                        -80C
#
#                                     analyte_protocol  \
# 0  Flash frozen liver samples (about 25 mg) were ...
# 1  Flash frozen liver samples (about 25 mg) were ...
# 2  Flash frozen liver samples (about 25 mg) were ...
# 3  Flash frozen liver samples (about 25 mg) were ...
# 4  Flash frozen liver samples (about 25 mg) were ...
#
#                                        provenance
# 0  DataHarmonizer v1.4.10, mass_spec_assay v1.0.0
# 1  DataHarmonizer v1.4.10, mass_spec_assay v1.0.0
# 2  DataHarmonizer v1.4.10, mass_spec_assay v1.0.0
# 3  DataHarmonizer v1.4.10, mass_spec_assay v1.0.0
# 4  DataHarmonizer v1.4.10, mass_spec_assay v1.0.0

# %%
# ms_aliquot
import requests
COMMONS = "https://fairtox.com/"
API_KEY_FILEPATH = '/Users/apple/Desktop/test_gen3/credentials23.json'

projectname = 'MyFirstProject'
programname = 'MyFirstProgram'
api_url = "{}/api/v0/submission/{}/{}".format(COMMONS,programname,projectname)
df = pd.read_table('/Users/apple/Desktop/test_gen3/DH_ExportedFiles/aliquot.tsv')
col_name = df.columns.tolist()
# this is external link
col_name.remove("samples.submitter_id")

for _, row in df.iterrows():
    jsondata = []
    # this is for the external link
    dic = {
        "samples": [
            {
                "submitter_id": row["samples.submitter_id"]
            }
        ]
    }

    for i in col_name:
        value = row[i]
        if isinstance(value, float) and (value == float('inf') or value == float('-inf') or pd.isna(value)):
            dic[i] = str(value)
        else:
            dic[i] = value

    jsondata.append(dic)
    print(jsondata)
    authn = Gen3Auth(COMMONS, refresh_file=API_KEY_FILEPATH)
    output = requests.put(api_url, auth=authn, json=jsondata)
    output.json()
# Out:
# [{'samples': [{'submitter_id': 'Prj171:L75'}], 'type': 'aliquot', 'submitter_id': 'Prj171:metabolite_extract_L75', 'analyte_type': 'Aqueous', 'derivitization': 'nan', 'extract_preservation_method': '-80C', 'analyte_protocol': 'Flash frozen liver samples (about 25 mg) were extracted using HPLC-grade methanol and water (5:3 ratio) containing 13C-,15N-labeled amino acid (Sigma; 767964) internal standards. HPLC-grade chloroform (methanol:water:chloroform ratio 5:3:5) was added, vortexed, shaken for 15 min at 4 Celsius, and centrifuged at maximum speed (3000 x g) to achieve phase separation. The methanol:water phase containing the polar metabolites was transferred, dried under nitrogen gas at room temperature. Untargeted extractions were reconstituted with 400 ul of 10 mM tributylamine and 15 mM acetic acid in 97:3 water:methanol for analysis.', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'samples': [{'submitter_id': 'Prj171:L121'}], 'type': 'aliquot', 'submitter_id': 'Prj171:metabolite_extract_L121', 'analyte_type': 'Aqueous', 'derivitization': 'nan', 'extract_preservation_method': '-80C', 'analyte_protocol': 'Flash frozen liver samples (about 25 mg) were extracted using HPLC-grade methanol and water (5:3 ratio) containing 13C-,15N-labeled amino acid (Sigma; 767964) internal standards. HPLC-grade chloroform (methanol:water:chloroform ratio 5:3:5) was added, vortexed, shaken for 15 min at 4 Celsius, and centrifuged at maximum speed (3000 x g) to achieve phase separation. The methanol:water phase containing the polar metabolites was transferred, dried under nitrogen gas at room temperature. Untargeted extractions were reconstituted with 400 ul of 10 mM tributylamine and 15 mM acetic acid in 97:3 water:methanol for analysis.', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'samples': [{'submitter_id': 'Prj171:L27'}], 'type': 'aliquot', 'submitter_id': 'Prj171:metabolite_extract_L27', 'analyte_type': 'Aqueous', 'derivitization': 'nan', 'extract_preservation_method': '-80C', 'analyte_protocol': 'Flash frozen liver samples (about 25 mg) were extracted using HPLC-grade methanol and water (5:3 ratio) containing 13C-,15N-labeled amino acid (Sigma; 767964) internal standards. HPLC-grade chloroform (methanol:water:chloroform ratio 5:3:5) was added, vortexed, shaken for 15 min at 4 Celsius, and centrifuged at maximum speed (3000 x g) to achieve phase separation. The methanol:water phase containing the polar metabolites was transferred, dried under nitrogen gas at room temperature. Untargeted extractions were reconstituted with 400 ul of 10 mM tributylamine and 15 mM acetic acid in 97:3 water:methanol for analysis.', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'samples': [{'submitter_id': 'Prj171:L122'}], 'type': 'aliquot', 'submitter_id': 'Prj171:metabolite_extract_L122', 'analyte_type': 'Aqueous', 'derivitization': 'nan', 'extract_preservation_method': '-80C', 'analyte_protocol': 'Flash frozen liver samples (about 25 mg) were extracted using HPLC-grade methanol and water (5:3 ratio) containing 13C-,15N-labeled amino acid (Sigma; 767964) internal standards. HPLC-grade chloroform (methanol:water:chloroform ratio 5:3:5) was added, vortexed, shaken for 15 min at 4 Celsius, and centrifuged at maximum speed (3000 x g) to achieve phase separation. The methanol:water phase containing the polar metabolites was transferred, dried under nitrogen gas at room temperature. Untargeted extractions were reconstituted with 400 ul of 10 mM tributylamine and 15 mM acetic acid in 97:3 water:methanol for analysis.', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'samples': [{'submitter_id': 'Prj171:L123'}], 'type': 'aliquot', 'submitter_id': 'Prj171:metabolite_extract_L123', 'analyte_type': 'Aqueous', 'derivitization': 'nan', 'extract_preservation_method': '-80C', 'analyte_protocol': 'Flash frozen liver samples (about 25 mg) were extracted using HPLC-grade methanol and water (5:3 ratio) containing 13C-,15N-labeled amino acid (Sigma; 767964) internal standards. HPLC-grade chloroform (methanol:water:chloroform ratio 5:3:5) was added, vortexed, shaken for 15 min at 4 Celsius, and centrifuged at maximum speed (3000 x g) to achieve phase separation. The methanol:water phase containing the polar metabolites was transferred, dried under nitrogen gas at room temperature. Untargeted extractions were reconstituted with 400 ul of 10 mM tributylamine and 15 mM acetic acid in 97:3 water:methanol for analysis.', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'samples': [{'submitter_id': 'Prj171:L82'}], 'type': 'aliquot', 'submitter_id': 'Prj171:metabolite_extract_L82', 'analyte_type': 'Aqueous', 'derivitization': 'nan', 'extract_preservation_method': '-80C', 'analyte_protocol': 'Flash frozen liver samples (about 25 mg) were extracted using HPLC-grade methanol and water (5:3 ratio) containing 13C-,15N-labeled amino acid (Sigma; 767964) internal standards. HPLC-grade chloroform (methanol:water:chloroform ratio 5:3:5) was added, vortexed, shaken for 15 min at 4 Celsius, and centrifuged at maximum speed (3000 x g) to achieve phase separation. The methanol:water phase containing the polar metabolites was transferred, dried under nitrogen gas at room temperature. Untargeted extractions were reconstituted with 400 ul of 10 mM tributylamine and 15 mM acetic acid in 97:3 water:methanol for analysis.', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'samples': [{'submitter_id': 'Prj171:L83'}], 'type': 'aliquot', 'submitter_id': 'Prj171:metabolite_extract_L83', 'analyte_type': 'Aqueous', 'derivitization': 'nan', 'extract_preservation_method': '-80C', 'analyte_protocol': 'Flash frozen liver samples (about 25 mg) were extracted using HPLC-grade methanol and water (5:3 ratio) containing 13C-,15N-labeled amino acid (Sigma; 767964) internal standards. HPLC-grade chloroform (methanol:water:chloroform ratio 5:3:5) was added, vortexed, shaken for 15 min at 4 Celsius, and centrifuged at maximum speed (3000 x g) to achieve phase separation. The methanol:water phase containing the polar metabolites was transferred, dried under nitrogen gas at room temperature. Untargeted extractions were reconstituted with 400 ul of 10 mM tributylamine and 15 mM acetic acid in 97:3 water:methanol for analysis.', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'samples': [{'submitter_id': 'Prj171:L106'}], 'type': 'aliquot', 'submitter_id': 'Prj171:metabolite_extract_L106', 'analyte_type': 'Aqueous', 'derivitization': 'nan', 'extract_preservation_method': '-80C', 'analyte_protocol': 'Flash frozen liver samples (about 25 mg) were extracted using HPLC-grade methanol and water (5:3 ratio) containing 13C-,15N-labeled amino acid (Sigma; 767964) internal standards. HPLC-grade chloroform (methanol:water:chloroform ratio 5:3:5) was added, vortexed, shaken for 15 min at 4 Celsius, and centrifuged at maximum speed (3000 x g) to achieve phase separation. The methanol:water phase containing the polar metabolites was transferred, dried under nitrogen gas at room temperature. Untargeted extractions were reconstituted with 400 ul of 10 mM tributylamine and 15 mM acetic acid in 97:3 water:methanol for analysis.', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'samples': [{'submitter_id': 'Prj171:L107'}], 'type': 'aliquot', 'submitter_id': 'Prj171:metabolite_extract_L107', 'analyte_type': 'Aqueous', 'derivitization': 'nan', 'extract_preservation_method': '-80C', 'analyte_protocol': 'Flash frozen liver samples (about 25 mg) were extracted using HPLC-grade methanol and water (5:3 ratio) containing 13C-,15N-labeled amino acid (Sigma; 767964) internal standards. HPLC-grade chloroform (methanol:water:chloroform ratio 5:3:5) was added, vortexed, shaken for 15 min at 4 Celsius, and centrifuged at maximum speed (3000 x g) to achieve phase separation. The methanol:water phase containing the polar metabolites was transferred, dried under nitrogen gas at room temperature. Untargeted extractions were reconstituted with 400 ul of 10 mM tributylamine and 15 mM acetic acid in 97:3 water:methanol for analysis.', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'samples': [{'submitter_id': 'Prj171:L131'}], 'type': 'aliquot', 'submitter_id': 'Prj171:metabolite_extract_L131', 'analyte_type': 'Aqueous', 'derivitization': 'nan', 'extract_preservation_method': '-80C', 'analyte_protocol': 'Flash frozen liver samples (about 25 mg) were extracted using HPLC-grade methanol and water (5:3 ratio) containing 13C-,15N-labeled amino acid (Sigma; 767964) internal standards. HPLC-grade chloroform (methanol:water:chloroform ratio 5:3:5) was added, vortexed, shaken for 15 min at 4 Celsius, and centrifuged at maximum speed (3000 x g) to achieve phase separation. The methanol:water phase containing the polar metabolites was transferred, dried under nitrogen gas at room temperature. Untargeted extractions were reconstituted with 400 ul of 10 mM tributylamine and 15 mM acetic acid in 97:3 water:methanol for analysis.', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'samples': [{'submitter_id': 'Prj171:L85'}], 'type': 'aliquot', 'submitter_id': 'Prj171:metabolite_extract_L85', 'analyte_type': 'Aqueous', 'derivitization': 'nan', 'extract_preservation_method': '-80C', 'analyte_protocol': 'Flash frozen liver samples (about 25 mg) were extracted using HPLC-grade methanol and water (5:3 ratio) containing 13C-,15N-labeled amino acid (Sigma; 767964) internal standards. HPLC-grade chloroform (methanol:water:chloroform ratio 5:3:5) was added, vortexed, shaken for 15 min at 4 Celsius, and centrifuged at maximum speed (3000 x g) to achieve phase separation. The methanol:water phase containing the polar metabolites was transferred, dried under nitrogen gas at room temperature. Untargeted extractions were reconstituted with 400 ul of 10 mM tributylamine and 15 mM acetic acid in 97:3 water:methanol for analysis.', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'samples': [{'submitter_id': 'Prj171:L86'}], 'type': 'aliquot', 'submitter_id': 'Prj171:metabolite_extract_L86', 'analyte_type': 'Aqueous', 'derivitization': 'nan', 'extract_preservation_method': '-80C', 'analyte_protocol': 'Flash frozen liver samples (about 25 mg) were extracted using HPLC-grade methanol and water (5:3 ratio) containing 13C-,15N-labeled amino acid (Sigma; 767964) internal standards. HPLC-grade chloroform (methanol:water:chloroform ratio 5:3:5) was added, vortexed, shaken for 15 min at 4 Celsius, and centrifuged at maximum speed (3000 x g) to achieve phase separation. The methanol:water phase containing the polar metabolites was transferred, dried under nitrogen gas at room temperature. Untargeted extractions were reconstituted with 400 ul of 10 mM tributylamine and 15 mM acetic acid in 97:3 water:methanol for analysis.', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'samples': [{'submitter_id': 'Prj171:L109'}], 'type': 'aliquot', 'submitter_id': 'Prj171:metabolite_extract_L109', 'analyte_type': 'Aqueous', 'derivitization': 'nan', 'extract_preservation_method': '-80C', 'analyte_protocol': 'Flash frozen liver samples (about 25 mg) were extracted using HPLC-grade methanol and water (5:3 ratio) containing 13C-,15N-labeled amino acid (Sigma; 767964) internal standards. HPLC-grade chloroform (methanol:water:chloroform ratio 5:3:5) was added, vortexed, shaken for 15 min at 4 Celsius, and centrifuged at maximum speed (3000 x g) to achieve phase separation. The methanol:water phase containing the polar metabolites was transferred, dried under nitrogen gas at room temperature. Untargeted extractions were reconstituted with 400 ul of 10 mM tributylamine and 15 mM acetic acid in 97:3 water:methanol for analysis.', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'samples': [{'submitter_id': 'Prj171:L110'}], 'type': 'aliquot', 'submitter_id': 'Prj171:metabolite_extract_L110', 'analyte_type': 'Aqueous', 'derivitization': 'nan', 'extract_preservation_method': '-80C', 'analyte_protocol': 'Flash frozen liver samples (about 25 mg) were extracted using HPLC-grade methanol and water (5:3 ratio) containing 13C-,15N-labeled amino acid (Sigma; 767964) internal standards. HPLC-grade chloroform (methanol:water:chloroform ratio 5:3:5) was added, vortexed, shaken for 15 min at 4 Celsius, and centrifuged at maximum speed (3000 x g) to achieve phase separation. The methanol:water phase containing the polar metabolites was transferred, dried under nitrogen gas at room temperature. Untargeted extractions were reconstituted with 400 ul of 10 mM tributylamine and 15 mM acetic acid in 97:3 water:methanol for analysis.', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'samples': [{'submitter_id': 'Prj171:L134'}], 'type': 'aliquot', 'submitter_id': 'Prj171:metabolite_extract_L134', 'analyte_type': 'Aqueous', 'derivitization': 'nan', 'extract_preservation_method': '-80C', 'analyte_protocol': 'Flash frozen liver samples (about 25 mg) were extracted using HPLC-grade methanol and water (5:3 ratio) containing 13C-,15N-labeled amino acid (Sigma; 767964) internal standards. HPLC-grade chloroform (methanol:water:chloroform ratio 5:3:5) was added, vortexed, shaken for 15 min at 4 Celsius, and centrifuged at maximum speed (3000 x g) to achieve phase separation. The methanol:water phase containing the polar metabolites was transferred, dried under nitrogen gas at room temperature. Untargeted extractions were reconstituted with 400 ul of 10 mM tributylamine and 15 mM acetic acid in 97:3 water:methanol for analysis.', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'samples': [{'submitter_id': 'Prj171:L88'}], 'type': 'aliquot', 'submitter_id': 'Prj171:metabolite_extract_L88', 'analyte_type': 'Aqueous', 'derivitization': 'nan', 'extract_preservation_method': '-80C', 'analyte_protocol': 'Flash frozen liver samples (about 25 mg) were extracted using HPLC-grade methanol and water (5:3 ratio) containing 13C-,15N-labeled amino acid (Sigma; 767964) internal standards. HPLC-grade chloroform (methanol:water:chloroform ratio 5:3:5) was added, vortexed, shaken for 15 min at 4 Celsius, and centrifuged at maximum speed (3000 x g) to achieve phase separation. The methanol:water phase containing the polar metabolites was transferred, dried under nitrogen gas at room temperature. Untargeted extractions were reconstituted with 400 ul of 10 mM tributylamine and 15 mM acetic acid in 97:3 water:methanol for analysis.', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'samples': [{'submitter_id': 'Prj171:L89'}], 'type': 'aliquot', 'submitter_id': 'Prj171:metabolite_extract_L89', 'analyte_type': 'Aqueous', 'derivitization': 'nan', 'extract_preservation_method': '-80C', 'analyte_protocol': 'Flash frozen liver samples (about 25 mg) were extracted using HPLC-grade methanol and water (5:3 ratio) containing 13C-,15N-labeled amino acid (Sigma; 767964) internal standards. HPLC-grade chloroform (methanol:water:chloroform ratio 5:3:5) was added, vortexed, shaken for 15 min at 4 Celsius, and centrifuged at maximum speed (3000 x g) to achieve phase separation. The methanol:water phase containing the polar metabolites was transferred, dried under nitrogen gas at room temperature. Untargeted extractions were reconstituted with 400 ul of 10 mM tributylamine and 15 mM acetic acid in 97:3 water:methanol for analysis.', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'samples': [{'submitter_id': 'Prj171:L112'}], 'type': 'aliquot', 'submitter_id': 'Prj171:metabolite_extract_L112', 'analyte_type': 'Aqueous', 'derivitization': 'nan', 'extract_preservation_method': '-80C', 'analyte_protocol': 'Flash frozen liver samples (about 25 mg) were extracted using HPLC-grade methanol and water (5:3 ratio) containing 13C-,15N-labeled amino acid (Sigma; 767964) internal standards. HPLC-grade chloroform (methanol:water:chloroform ratio 5:3:5) was added, vortexed, shaken for 15 min at 4 Celsius, and centrifuged at maximum speed (3000 x g) to achieve phase separation. The methanol:water phase containing the polar metabolites was transferred, dried under nitrogen gas at room temperature. Untargeted extractions were reconstituted with 400 ul of 10 mM tributylamine and 15 mM acetic acid in 97:3 water:methanol for analysis.', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'samples': [{'submitter_id': 'Prj171:L113'}], 'type': 'aliquot', 'submitter_id': 'Prj171:metabolite_extract_L113', 'analyte_type': 'Aqueous', 'derivitization': 'nan', 'extract_preservation_method': '-80C', 'analyte_protocol': 'Flash frozen liver samples (about 25 mg) were extracted using HPLC-grade methanol and water (5:3 ratio) containing 13C-,15N-labeled amino acid (Sigma; 767964) internal standards. HPLC-grade chloroform (methanol:water:chloroform ratio 5:3:5) was added, vortexed, shaken for 15 min at 4 Celsius, and centrifuged at maximum speed (3000 x g) to achieve phase separation. The methanol:water phase containing the polar metabolites was transferred, dried under nitrogen gas at room temperature. Untargeted extractions were reconstituted with 400 ul of 10 mM tributylamine and 15 mM acetic acid in 97:3 water:methanol for analysis.', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'samples': [{'submitter_id': 'Prj171:L137'}], 'type': 'aliquot', 'submitter_id': 'Prj171:metabolite_extract_L137', 'analyte_type': 'Aqueous', 'derivitization': 'nan', 'extract_preservation_method': '-80C', 'analyte_protocol': 'Flash frozen liver samples (about 25 mg) were extracted using HPLC-grade methanol and water (5:3 ratio) containing 13C-,15N-labeled amino acid (Sigma; 767964) internal standards. HPLC-grade chloroform (methanol:water:chloroform ratio 5:3:5) was added, vortexed, shaken for 15 min at 4 Celsius, and centrifuged at maximum speed (3000 x g) to achieve phase separation. The methanol:water phase containing the polar metabolites was transferred, dried under nitrogen gas at room temperature. Untargeted extractions were reconstituted with 400 ul of 10 mM tributylamine and 15 mM acetic acid in 97:3 water:methanol for analysis.', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'samples': [{'submitter_id': 'Prj171:L91'}], 'type': 'aliquot', 'submitter_id': 'Prj171:metabolite_extract_L91', 'analyte_type': 'Aqueous', 'derivitization': 'nan', 'extract_preservation_method': '-80C', 'analyte_protocol': 'Flash frozen liver samples (about 25 mg) were extracted using HPLC-grade methanol and water (5:3 ratio) containing 13C-,15N-labeled amino acid (Sigma; 767964) internal standards. HPLC-grade chloroform (methanol:water:chloroform ratio 5:3:5) was added, vortexed, shaken for 15 min at 4 Celsius, and centrifuged at maximum speed (3000 x g) to achieve phase separation. The methanol:water phase containing the polar metabolites was transferred, dried under nitrogen gas at room temperature. Untargeted extractions were reconstituted with 400 ul of 10 mM tributylamine and 15 mM acetic acid in 97:3 water:methanol for analysis.', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'samples': [{'submitter_id': 'Prj171:L92'}], 'type': 'aliquot', 'submitter_id': 'Prj171:metabolite_extract_L92', 'analyte_type': 'Aqueous', 'derivitization': 'nan', 'extract_preservation_method': '-80C', 'analyte_protocol': 'Flash frozen liver samples (about 25 mg) were extracted using HPLC-grade methanol and water (5:3 ratio) containing 13C-,15N-labeled amino acid (Sigma; 767964) internal standards. HPLC-grade chloroform (methanol:water:chloroform ratio 5:3:5) was added, vortexed, shaken for 15 min at 4 Celsius, and centrifuged at maximum speed (3000 x g) to achieve phase separation. The methanol:water phase containing the polar metabolites was transferred, dried under nitrogen gas at room temperature. Untargeted extractions were reconstituted with 400 ul of 10 mM tributylamine and 15 mM acetic acid in 97:3 water:methanol for analysis.', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'samples': [{'submitter_id': 'Prj171:L115'}], 'type': 'aliquot', 'submitter_id': 'Prj171:metabolite_extract_L115', 'analyte_type': 'Aqueous', 'derivitization': 'nan', 'extract_preservation_method': '-80C', 'analyte_protocol': 'Flash frozen liver samples (about 25 mg) were extracted using HPLC-grade methanol and water (5:3 ratio) containing 13C-,15N-labeled amino acid (Sigma; 767964) internal standards. HPLC-grade chloroform (methanol:water:chloroform ratio 5:3:5) was added, vortexed, shaken for 15 min at 4 Celsius, and centrifuged at maximum speed (3000 x g) to achieve phase separation. The methanol:water phase containing the polar metabolites was transferred, dried under nitrogen gas at room temperature. Untargeted extractions were reconstituted with 400 ul of 10 mM tributylamine and 15 mM acetic acid in 97:3 water:methanol for analysis.', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'samples': [{'submitter_id': 'Prj171:L116'}], 'type': 'aliquot', 'submitter_id': 'Prj171:metabolite_extract_L116', 'analyte_type': 'Aqueous', 'derivitization': 'nan', 'extract_preservation_method': '-80C', 'analyte_protocol': 'Flash frozen liver samples (about 25 mg) were extracted using HPLC-grade methanol and water (5:3 ratio) containing 13C-,15N-labeled amino acid (Sigma; 767964) internal standards. HPLC-grade chloroform (methanol:water:chloroform ratio 5:3:5) was added, vortexed, shaken for 15 min at 4 Celsius, and centrifuged at maximum speed (3000 x g) to achieve phase separation. The methanol:water phase containing the polar metabolites was transferred, dried under nitrogen gas at room temperature. Untargeted extractions were reconstituted with 400 ul of 10 mM tributylamine and 15 mM acetic acid in 97:3 water:methanol for analysis.', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'samples': [{'submitter_id': 'Prj171:L139'}], 'type': 'aliquot', 'submitter_id': 'Prj171:metabolite_extract_L139', 'analyte_type': 'Aqueous', 'derivitization': 'nan', 'extract_preservation_method': '-80C', 'analyte_protocol': 'Flash frozen liver samples (about 25 mg) were extracted using HPLC-grade methanol and water (5:3 ratio) containing 13C-,15N-labeled amino acid (Sigma; 767964) internal standards. HPLC-grade chloroform (methanol:water:chloroform ratio 5:3:5) was added, vortexed, shaken for 15 min at 4 Celsius, and centrifuged at maximum speed (3000 x g) to achieve phase separation. The methanol:water phase containing the polar metabolites was transferred, dried under nitrogen gas at room temperature. Untargeted extractions were reconstituted with 400 ul of 10 mM tributylamine and 15 mM acetic acid in 97:3 water:methanol for analysis.', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'samples': [{'submitter_id': 'Prj171:L118'}], 'type': 'aliquot', 'submitter_id': 'Prj171:metabolite_extract_L118', 'analyte_type': 'Aqueous', 'derivitization': 'nan', 'extract_preservation_method': '-80C', 'analyte_protocol': 'Flash frozen liver samples (about 25 mg) were extracted using HPLC-grade methanol and water (5:3 ratio) containing 13C-,15N-labeled amino acid (Sigma; 767964) internal standards. HPLC-grade chloroform (methanol:water:chloroform ratio 5:3:5) was added, vortexed, shaken for 15 min at 4 Celsius, and centrifuged at maximum speed (3000 x g) to achieve phase separation. The methanol:water phase containing the polar metabolites was transferred, dried under nitrogen gas at room temperature. Untargeted extractions were reconstituted with 400 ul of 10 mM tributylamine and 15 mM acetic acid in 97:3 water:methanol for analysis.', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'samples': [{'submitter_id': 'Prj171:L119'}], 'type': 'aliquot', 'submitter_id': 'Prj171:metabolite_extract_L119', 'analyte_type': 'Aqueous', 'derivitization': 'nan', 'extract_preservation_method': '-80C', 'analyte_protocol': 'Flash frozen liver samples (about 25 mg) were extracted using HPLC-grade methanol and water (5:3 ratio) containing 13C-,15N-labeled amino acid (Sigma; 767964) internal standards. HPLC-grade chloroform (methanol:water:chloroform ratio 5:3:5) was added, vortexed, shaken for 15 min at 4 Celsius, and centrifuged at maximum speed (3000 x g) to achieve phase separation. The methanol:water phase containing the polar metabolites was transferred, dried under nitrogen gas at room temperature. Untargeted extractions were reconstituted with 400 ul of 10 mM tributylamine and 15 mM acetic acid in 97:3 water:methanol for analysis.', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'samples': [{'submitter_id': 'Prj171:L94'}], 'type': 'aliquot', 'submitter_id': 'Prj171:metabolite_extract_L94', 'analyte_type': 'Aqueous', 'derivitization': 'nan', 'extract_preservation_method': '-80C', 'analyte_protocol': 'Flash frozen liver samples (about 25 mg) were extracted using HPLC-grade methanol and water (5:3 ratio) containing 13C-,15N-labeled amino acid (Sigma; 767964) internal standards. HPLC-grade chloroform (methanol:water:chloroform ratio 5:3:5) was added, vortexed, shaken for 15 min at 4 Celsius, and centrifuged at maximum speed (3000 x g) to achieve phase separation. The methanol:water phase containing the polar metabolites was transferred, dried under nitrogen gas at room temperature. Untargeted extractions were reconstituted with 400 ul of 10 mM tributylamine and 15 mM acetic acid in 97:3 water:methanol for analysis.', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'samples': [{'submitter_id': 'Prj171:L142'}], 'type': 'aliquot', 'submitter_id': 'Prj171:metabolite_extract_L142', 'analyte_type': 'Aqueous', 'derivitization': 'nan', 'extract_preservation_method': '-80C', 'analyte_protocol': 'Flash frozen liver samples (about 25 mg) were extracted using HPLC-grade methanol and water (5:3 ratio) containing 13C-,15N-labeled amino acid (Sigma; 767964) internal standards. HPLC-grade chloroform (methanol:water:chloroform ratio 5:3:5) was added, vortexed, shaken for 15 min at 4 Celsius, and centrifuged at maximum speed (3000 x g) to achieve phase separation. The methanol:water phase containing the polar metabolites was transferred, dried under nitrogen gas at room temperature. Untargeted extractions were reconstituted with 400 ul of 10 mM tributylamine and 15 mM acetic acid in 97:3 water:methanol for analysis.', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'samples': [{'submitter_id': 'Prj171:L143'}], 'type': 'aliquot', 'submitter_id': 'Prj171:metabolite_extract_L143', 'analyte_type': 'Aqueous', 'derivitization': 'nan', 'extract_preservation_method': '-80C', 'analyte_protocol': 'Flash frozen liver samples (about 25 mg) were extracted using HPLC-grade methanol and water (5:3 ratio) containing 13C-,15N-labeled amino acid (Sigma; 767964) internal standards. HPLC-grade chloroform (methanol:water:chloroform ratio 5:3:5) was added, vortexed, shaken for 15 min at 4 Celsius, and centrifuged at maximum speed (3000 x g) to achieve phase separation. The methanol:water phase containing the polar metabolites was transferred, dried under nitrogen gas at room temperature. Untargeted extractions were reconstituted with 400 ul of 10 mM tributylamine and 15 mM acetic acid in 97:3 water:methanol for analysis.', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]

# %%
df = pd.read_table("/Users/apple/Desktop/test_gen3/DH_ExportedFiles/mass_spec_assay.tsv")
df["chromatography_instrument"] = "Waters TQS"
df.to_csv('/Users/apple/Desktop/test_gen3/DH_ExportedFiles/mass_spec_assay.tsv', sep='\t', index=False)
df.head()
# Out:
#               type            submitter_id           aliquots.submitter_id  \
# 0  mass_spec_assay  Prj171:TQSm_042122_010   Prj171:metabolite_extract_L75
# 1  mass_spec_assay  Prj171:TQSm_042122_011  Prj171:metabolite_extract_L121
# 2  mass_spec_assay  Prj171:TQSm_042122_012   Prj171:metabolite_extract_L27
# 3  mass_spec_assay  Prj171:TQSm_042122_013  Prj171:metabolite_extract_L122
# 4  mass_spec_assay  Prj171:TQSm_042122_014  Prj171:metabolite_extract_L123
#
#   sample_dilution calibration_standard chromatography_type  \
# 0             1:1   13C,15N-methionine      Reversed phase
# 1             1:1   13C,15N-methionine      Reversed phase
# 2             1:1   13C,15N-methionine      Reversed phase
# 3             1:1   13C,15N-methionine      Reversed phase
# 4             1:1   13C,15N-methionine      Reversed phase
#
#                             chromatography_column  \
# 0  Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)
# 1  Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)
# 2  Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)
# 3  Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)
# 4  Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)
#
#                              chromatography_protocol  \
# 0  The mobile phases were 10mM PFHA in water (mob...
# 1  The mobile phases were 10mM PFHA in water (mob...
# 2  The mobile phases were 10mM PFHA in water (mob...
# 3  The mobile phases were 10mM PFHA in water (mob...
# 4  The mobile phases were 10mM PFHA in water (mob...
#
#   chromatography_instrument  chromatography_method_filename  ...  \
# 0                Waters TQS                             NaN  ...
# 1                Waters TQS                             NaN  ...
# 2                Waters TQS                             NaN  ...
# 3                Waters TQS                             NaN  ...
# 4                Waters TQS                             NaN  ...
#
#                                      solventA              solventB solventC  \
# 0  100% water; ; 10mM perfluoroheptanoic acid  100% acetonitrile; ;      NaN
# 1  100% water; ; 10mM perfluoroheptanoic acid  100% acetonitrile; ;      NaN
# 2  100% water; ; 10mM perfluoroheptanoic acid  100% acetonitrile; ;      NaN
# 3  100% water; ; 10mM perfluoroheptanoic acid  100% acetonitrile; ;      NaN
# 4  100% water; ; 10mM perfluoroheptanoic acid  100% acetonitrile; ;      NaN
#
#   carrier_gas  oven_temperature_program  ms_type  \
# 0         NaN                       NaN      ESI
# 1         NaN                       NaN      ESI
# 2         NaN                       NaN      ESI
# 3         NaN                       NaN      ESI
# 4         NaN                       NaN      ESI
#
#                                          ms_protocol ms_method_filename  \
# 0  Multiple reaction monitoring in positive ion mode                NaN
# 1  Multiple reaction monitoring in positive ion mode                NaN
# 2  Multiple reaction monitoring in positive ion mode                NaN
# 3  Multiple reaction monitoring in positive ion mode                NaN
# 4  Multiple reaction monitoring in positive ion mode                NaN
#
#    ion_mode                                      provenance
# 0  POSITIVE  DataHarmonizer v1.4.10, mass_spec_assay v1.0.0
# 1  POSITIVE  DataHarmonizer v1.4.10, mass_spec_assay v1.0.0
# 2  POSITIVE  DataHarmonizer v1.4.10, mass_spec_assay v1.0.0
# 3  POSITIVE  DataHarmonizer v1.4.10, mass_spec_assay v1.0.0
# 4  POSITIVE  DataHarmonizer v1.4.10, mass_spec_assay v1.0.0
#
# [5 rows x 22 columns]

# %%
# mass_spec_assay
import requests
COMMONS = "https://fairtox.com/"
API_KEY_FILEPATH = '/Users/apple/Desktop/test_gen3/credentials23.json'

projectname = 'MyFirstProject'
programname = 'MyFirstProgram'
api_url = "{}/api/v0/submission/{}/{}".format(COMMONS,programname,projectname)
df = pd.read_table('/Users/apple/Desktop/test_gen3/DH_ExportedFiles/mass_spec_assay.tsv')
col_name = df.columns.tolist()
# this is external link
col_name.remove("aliquots.submitter_id")

for _, row in df.iterrows():
    jsondata = []
    # this is for the external link
    dic = {
        "aliquots": [
            {
                "submitter_id": row["aliquots.submitter_id"]
            }
        ]
    }

    for i in col_name:
        value = row[i]
        if isinstance(value, float) and (value == float('inf') or value == float('-inf') or pd.isna(value)):
            dic[i] = str(value)
        else:
            dic[i] = value

    jsondata.append(dic)
    print(jsondata)
    authn = Gen3Auth(COMMONS, refresh_file=API_KEY_FILEPATH)
    output = requests.put(api_url, auth=authn, json=jsondata)
    output.json()
# Out:
# [{'aliquots': [{'submitter_id': 'Prj171:metabolite_extract_L75'}], 'type': 'mass_spec_assay', 'submitter_id': 'Prj171:TQSm_042122_010', 'sample_dilution': '1:1', 'calibration_standard': '13C,15N-methionine', 'chromatography_type': 'Reversed phase', 'chromatography_column': 'Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)', 'chromatography_protocol': 'The mobile phases were 10mM PFHA in water (mobile phase A) and acetonitrile (mobile phase B) using the following gradient: 0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'chromatography_instrument': 'Waters TQS', 'chromatography_method_filename': 'nan', 'elution_program': '0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'flow_rate': '0.3 ml/minute', 'solventA': '100% water; ; 10mM perfluoroheptanoic acid', 'solventB': '100% acetonitrile; ;', 'solventC': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_type': 'ESI', 'ms_protocol': 'Multiple reaction monitoring in positive ion mode', 'ms_method_filename': 'nan', 'ion_mode': 'POSITIVE', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'Prj171:metabolite_extract_L121'}], 'type': 'mass_spec_assay', 'submitter_id': 'Prj171:TQSm_042122_011', 'sample_dilution': '1:1', 'calibration_standard': '13C,15N-methionine', 'chromatography_type': 'Reversed phase', 'chromatography_column': 'Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)', 'chromatography_protocol': 'The mobile phases were 10mM PFHA in water (mobile phase A) and acetonitrile (mobile phase B) using the following gradient: 0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'chromatography_instrument': 'Waters TQS', 'chromatography_method_filename': 'nan', 'elution_program': '0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'flow_rate': '0.3 ml/minute', 'solventA': '100% water; ; 10mM perfluoroheptanoic acid', 'solventB': '100% acetonitrile; ;', 'solventC': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_type': 'ESI', 'ms_protocol': 'Multiple reaction monitoring in positive ion mode', 'ms_method_filename': 'nan', 'ion_mode': 'POSITIVE', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'Prj171:metabolite_extract_L27'}], 'type': 'mass_spec_assay', 'submitter_id': 'Prj171:TQSm_042122_012', 'sample_dilution': '1:1', 'calibration_standard': '13C,15N-methionine', 'chromatography_type': 'Reversed phase', 'chromatography_column': 'Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)', 'chromatography_protocol': 'The mobile phases were 10mM PFHA in water (mobile phase A) and acetonitrile (mobile phase B) using the following gradient: 0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'chromatography_instrument': 'Waters TQS', 'chromatography_method_filename': 'nan', 'elution_program': '0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'flow_rate': '0.3 ml/minute', 'solventA': '100% water; ; 10mM perfluoroheptanoic acid', 'solventB': '100% acetonitrile; ;', 'solventC': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_type': 'ESI', 'ms_protocol': 'Multiple reaction monitoring in positive ion mode', 'ms_method_filename': 'nan', 'ion_mode': 'POSITIVE', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'Prj171:metabolite_extract_L122'}], 'type': 'mass_spec_assay', 'submitter_id': 'Prj171:TQSm_042122_013', 'sample_dilution': '1:1', 'calibration_standard': '13C,15N-methionine', 'chromatography_type': 'Reversed phase', 'chromatography_column': 'Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)', 'chromatography_protocol': 'The mobile phases were 10mM PFHA in water (mobile phase A) and acetonitrile (mobile phase B) using the following gradient: 0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'chromatography_instrument': 'Waters TQS', 'chromatography_method_filename': 'nan', 'elution_program': '0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'flow_rate': '0.3 ml/minute', 'solventA': '100% water; ; 10mM perfluoroheptanoic acid', 'solventB': '100% acetonitrile; ;', 'solventC': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_type': 'ESI', 'ms_protocol': 'Multiple reaction monitoring in positive ion mode', 'ms_method_filename': 'nan', 'ion_mode': 'POSITIVE', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'Prj171:metabolite_extract_L123'}], 'type': 'mass_spec_assay', 'submitter_id': 'Prj171:TQSm_042122_014', 'sample_dilution': '1:1', 'calibration_standard': '13C,15N-methionine', 'chromatography_type': 'Reversed phase', 'chromatography_column': 'Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)', 'chromatography_protocol': 'The mobile phases were 10mM PFHA in water (mobile phase A) and acetonitrile (mobile phase B) using the following gradient: 0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'chromatography_instrument': 'Waters TQS', 'chromatography_method_filename': 'nan', 'elution_program': '0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'flow_rate': '0.3 ml/minute', 'solventA': '100% water; ; 10mM perfluoroheptanoic acid', 'solventB': '100% acetonitrile; ;', 'solventC': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_type': 'ESI', 'ms_protocol': 'Multiple reaction monitoring in positive ion mode', 'ms_method_filename': 'nan', 'ion_mode': 'POSITIVE', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'Prj171:metabolite_extract_L82'}], 'type': 'mass_spec_assay', 'submitter_id': 'Prj171:TQSm_042122_015', 'sample_dilution': '1:1', 'calibration_standard': '13C,15N-methionine', 'chromatography_type': 'Reversed phase', 'chromatography_column': 'Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)', 'chromatography_protocol': 'The mobile phases were 10mM PFHA in water (mobile phase A) and acetonitrile (mobile phase B) using the following gradient: 0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'chromatography_instrument': 'Waters TQS', 'chromatography_method_filename': 'nan', 'elution_program': '0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'flow_rate': '0.3 ml/minute', 'solventA': '100% water; ; 10mM perfluoroheptanoic acid', 'solventB': '100% acetonitrile; ;', 'solventC': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_type': 'ESI', 'ms_protocol': 'Multiple reaction monitoring in positive ion mode', 'ms_method_filename': 'nan', 'ion_mode': 'POSITIVE', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'Prj171:metabolite_extract_L83'}], 'type': 'mass_spec_assay', 'submitter_id': 'Prj171:TQSm_042122_016', 'sample_dilution': '1:1', 'calibration_standard': '13C,15N-methionine', 'chromatography_type': 'Reversed phase', 'chromatography_column': 'Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)', 'chromatography_protocol': 'The mobile phases were 10mM PFHA in water (mobile phase A) and acetonitrile (mobile phase B) using the following gradient: 0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'chromatography_instrument': 'Waters TQS', 'chromatography_method_filename': 'nan', 'elution_program': '0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'flow_rate': '0.3 ml/minute', 'solventA': '100% water; ; 10mM perfluoroheptanoic acid', 'solventB': '100% acetonitrile; ;', 'solventC': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_type': 'ESI', 'ms_protocol': 'Multiple reaction monitoring in positive ion mode', 'ms_method_filename': 'nan', 'ion_mode': 'POSITIVE', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'Prj171:metabolite_extract_L106'}], 'type': 'mass_spec_assay', 'submitter_id': 'Prj171:TQSm_042122_017', 'sample_dilution': '1:1', 'calibration_standard': '13C,15N-methionine', 'chromatography_type': 'Reversed phase', 'chromatography_column': 'Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)', 'chromatography_protocol': 'The mobile phases were 10mM PFHA in water (mobile phase A) and acetonitrile (mobile phase B) using the following gradient: 0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'chromatography_instrument': 'Waters TQS', 'chromatography_method_filename': 'nan', 'elution_program': '0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'flow_rate': '0.3 ml/minute', 'solventA': '100% water; ; 10mM perfluoroheptanoic acid', 'solventB': '100% acetonitrile; ;', 'solventC': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_type': 'ESI', 'ms_protocol': 'Multiple reaction monitoring in positive ion mode', 'ms_method_filename': 'nan', 'ion_mode': 'POSITIVE', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'Prj171:metabolite_extract_L107'}], 'type': 'mass_spec_assay', 'submitter_id': 'Prj171:TQSm_042122_018', 'sample_dilution': '1:1', 'calibration_standard': '13C,15N-methionine', 'chromatography_type': 'Reversed phase', 'chromatography_column': 'Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)', 'chromatography_protocol': 'The mobile phases were 10mM PFHA in water (mobile phase A) and acetonitrile (mobile phase B) using the following gradient: 0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'chromatography_instrument': 'Waters TQS', 'chromatography_method_filename': 'nan', 'elution_program': '0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'flow_rate': '0.3 ml/minute', 'solventA': '100% water; ; 10mM perfluoroheptanoic acid', 'solventB': '100% acetonitrile; ;', 'solventC': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_type': 'ESI', 'ms_protocol': 'Multiple reaction monitoring in positive ion mode', 'ms_method_filename': 'nan', 'ion_mode': 'POSITIVE', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'Prj171:metabolite_extract_L131'}], 'type': 'mass_spec_assay', 'submitter_id': 'Prj171:TQSm_042122_019', 'sample_dilution': '1:1', 'calibration_standard': '13C,15N-methionine', 'chromatography_type': 'Reversed phase', 'chromatography_column': 'Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)', 'chromatography_protocol': 'The mobile phases were 10mM PFHA in water (mobile phase A) and acetonitrile (mobile phase B) using the following gradient: 0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'chromatography_instrument': 'Waters TQS', 'chromatography_method_filename': 'nan', 'elution_program': '0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'flow_rate': '0.3 ml/minute', 'solventA': '100% water; ; 10mM perfluoroheptanoic acid', 'solventB': '100% acetonitrile; ;', 'solventC': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_type': 'ESI', 'ms_protocol': 'Multiple reaction monitoring in positive ion mode', 'ms_method_filename': 'nan', 'ion_mode': 'POSITIVE', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'Prj171:metabolite_extract_L85'}], 'type': 'mass_spec_assay', 'submitter_id': 'Prj171:TQSm_042122_020', 'sample_dilution': '1:1', 'calibration_standard': '13C,15N-methionine', 'chromatography_type': 'Reversed phase', 'chromatography_column': 'Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)', 'chromatography_protocol': 'The mobile phases were 10mM PFHA in water (mobile phase A) and acetonitrile (mobile phase B) using the following gradient: 0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'chromatography_instrument': 'Waters TQS', 'chromatography_method_filename': 'nan', 'elution_program': '0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'flow_rate': '0.3 ml/minute', 'solventA': '100% water; ; 10mM perfluoroheptanoic acid', 'solventB': '100% acetonitrile; ;', 'solventC': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_type': 'ESI', 'ms_protocol': 'Multiple reaction monitoring in positive ion mode', 'ms_method_filename': 'nan', 'ion_mode': 'POSITIVE', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'Prj171:metabolite_extract_L86'}], 'type': 'mass_spec_assay', 'submitter_id': 'Prj171:TQSm_042122_021', 'sample_dilution': '1:1', 'calibration_standard': '13C,15N-methionine', 'chromatography_type': 'Reversed phase', 'chromatography_column': 'Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)', 'chromatography_protocol': 'The mobile phases were 10mM PFHA in water (mobile phase A) and acetonitrile (mobile phase B) using the following gradient: 0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'chromatography_instrument': 'Waters TQS', 'chromatography_method_filename': 'nan', 'elution_program': '0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'flow_rate': '0.3 ml/minute', 'solventA': '100% water; ; 10mM perfluoroheptanoic acid', 'solventB': '100% acetonitrile; ;', 'solventC': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_type': 'ESI', 'ms_protocol': 'Multiple reaction monitoring in positive ion mode', 'ms_method_filename': 'nan', 'ion_mode': 'POSITIVE', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'Prj171:metabolite_extract_L109'}], 'type': 'mass_spec_assay', 'submitter_id': 'Prj171:TQSm_042122_022', 'sample_dilution': '1:1', 'calibration_standard': '13C,15N-methionine', 'chromatography_type': 'Reversed phase', 'chromatography_column': 'Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)', 'chromatography_protocol': 'The mobile phases were 10mM PFHA in water (mobile phase A) and acetonitrile (mobile phase B) using the following gradient: 0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'chromatography_instrument': 'Waters TQS', 'chromatography_method_filename': 'nan', 'elution_program': '0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'flow_rate': '0.3 ml/minute', 'solventA': '100% water; ; 10mM perfluoroheptanoic acid', 'solventB': '100% acetonitrile; ;', 'solventC': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_type': 'ESI', 'ms_protocol': 'Multiple reaction monitoring in positive ion mode', 'ms_method_filename': 'nan', 'ion_mode': 'POSITIVE', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'Prj171:metabolite_extract_L110'}], 'type': 'mass_spec_assay', 'submitter_id': 'Prj171:TQSm_042122_023', 'sample_dilution': '1:1', 'calibration_standard': '13C,15N-methionine', 'chromatography_type': 'Reversed phase', 'chromatography_column': 'Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)', 'chromatography_protocol': 'The mobile phases were 10mM PFHA in water (mobile phase A) and acetonitrile (mobile phase B) using the following gradient: 0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'chromatography_instrument': 'Waters TQS', 'chromatography_method_filename': 'nan', 'elution_program': '0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'flow_rate': '0.3 ml/minute', 'solventA': '100% water; ; 10mM perfluoroheptanoic acid', 'solventB': '100% acetonitrile; ;', 'solventC': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_type': 'ESI', 'ms_protocol': 'Multiple reaction monitoring in positive ion mode', 'ms_method_filename': 'nan', 'ion_mode': 'POSITIVE', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'Prj171:metabolite_extract_L134'}], 'type': 'mass_spec_assay', 'submitter_id': 'Prj171:TQSm_042122_024', 'sample_dilution': '1:1', 'calibration_standard': '13C,15N-methionine', 'chromatography_type': 'Reversed phase', 'chromatography_column': 'Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)', 'chromatography_protocol': 'The mobile phases were 10mM PFHA in water (mobile phase A) and acetonitrile (mobile phase B) using the following gradient: 0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'chromatography_instrument': 'Waters TQS', 'chromatography_method_filename': 'nan', 'elution_program': '0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'flow_rate': '0.3 ml/minute', 'solventA': '100% water; ; 10mM perfluoroheptanoic acid', 'solventB': '100% acetonitrile; ;', 'solventC': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_type': 'ESI', 'ms_protocol': 'Multiple reaction monitoring in positive ion mode', 'ms_method_filename': 'nan', 'ion_mode': 'POSITIVE', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'Prj171:metabolite_extract_L88'}], 'type': 'mass_spec_assay', 'submitter_id': 'Prj171:TQSm_042122_025', 'sample_dilution': '1:1', 'calibration_standard': '13C,15N-methionine', 'chromatography_type': 'Reversed phase', 'chromatography_column': 'Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)', 'chromatography_protocol': 'The mobile phases were 10mM PFHA in water (mobile phase A) and acetonitrile (mobile phase B) using the following gradient: 0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'chromatography_instrument': 'Waters TQS', 'chromatography_method_filename': 'nan', 'elution_program': '0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'flow_rate': '0.3 ml/minute', 'solventA': '100% water; ; 10mM perfluoroheptanoic acid', 'solventB': '100% acetonitrile; ;', 'solventC': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_type': 'ESI', 'ms_protocol': 'Multiple reaction monitoring in positive ion mode', 'ms_method_filename': 'nan', 'ion_mode': 'POSITIVE', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'Prj171:metabolite_extract_L89'}], 'type': 'mass_spec_assay', 'submitter_id': 'Prj171:TQSm_042122_026', 'sample_dilution': '1:1', 'calibration_standard': '13C,15N-methionine', 'chromatography_type': 'Reversed phase', 'chromatography_column': 'Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)', 'chromatography_protocol': 'The mobile phases were 10mM PFHA in water (mobile phase A) and acetonitrile (mobile phase B) using the following gradient: 0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'chromatography_instrument': 'Waters TQS', 'chromatography_method_filename': 'nan', 'elution_program': '0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'flow_rate': '0.3 ml/minute', 'solventA': '100% water; ; 10mM perfluoroheptanoic acid', 'solventB': '100% acetonitrile; ;', 'solventC': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_type': 'ESI', 'ms_protocol': 'Multiple reaction monitoring in positive ion mode', 'ms_method_filename': 'nan', 'ion_mode': 'POSITIVE', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'Prj171:metabolite_extract_L112'}], 'type': 'mass_spec_assay', 'submitter_id': 'Prj171:TQSm_042122_027', 'sample_dilution': '1:1', 'calibration_standard': '13C,15N-methionine', 'chromatography_type': 'Reversed phase', 'chromatography_column': 'Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)', 'chromatography_protocol': 'The mobile phases were 10mM PFHA in water (mobile phase A) and acetonitrile (mobile phase B) using the following gradient: 0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'chromatography_instrument': 'Waters TQS', 'chromatography_method_filename': 'nan', 'elution_program': '0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'flow_rate': '0.3 ml/minute', 'solventA': '100% water; ; 10mM perfluoroheptanoic acid', 'solventB': '100% acetonitrile; ;', 'solventC': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_type': 'ESI', 'ms_protocol': 'Multiple reaction monitoring in positive ion mode', 'ms_method_filename': 'nan', 'ion_mode': 'POSITIVE', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'Prj171:metabolite_extract_L113'}], 'type': 'mass_spec_assay', 'submitter_id': 'Prj171:TQSm_042122_028', 'sample_dilution': '1:1', 'calibration_standard': '13C,15N-methionine', 'chromatography_type': 'Reversed phase', 'chromatography_column': 'Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)', 'chromatography_protocol': 'The mobile phases were 10mM PFHA in water (mobile phase A) and acetonitrile (mobile phase B) using the following gradient: 0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'chromatography_instrument': 'Waters TQS', 'chromatography_method_filename': 'nan', 'elution_program': '0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'flow_rate': '0.3 ml/minute', 'solventA': '100% water; ; 10mM perfluoroheptanoic acid', 'solventB': '100% acetonitrile; ;', 'solventC': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_type': 'ESI', 'ms_protocol': 'Multiple reaction monitoring in positive ion mode', 'ms_method_filename': 'nan', 'ion_mode': 'POSITIVE', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'Prj171:metabolite_extract_L137'}], 'type': 'mass_spec_assay', 'submitter_id': 'Prj171:TQSm_042122_029', 'sample_dilution': '1:1', 'calibration_standard': '13C,15N-methionine', 'chromatography_type': 'Reversed phase', 'chromatography_column': 'Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)', 'chromatography_protocol': 'The mobile phases were 10mM PFHA in water (mobile phase A) and acetonitrile (mobile phase B) using the following gradient: 0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'chromatography_instrument': 'Waters TQS', 'chromatography_method_filename': 'nan', 'elution_program': '0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'flow_rate': '0.3 ml/minute', 'solventA': '100% water; ; 10mM perfluoroheptanoic acid', 'solventB': '100% acetonitrile; ;', 'solventC': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_type': 'ESI', 'ms_protocol': 'Multiple reaction monitoring in positive ion mode', 'ms_method_filename': 'nan', 'ion_mode': 'POSITIVE', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'Prj171:metabolite_extract_L91'}], 'type': 'mass_spec_assay', 'submitter_id': 'Prj171:TQSm_042122_030', 'sample_dilution': '1:1', 'calibration_standard': '13C,15N-methionine', 'chromatography_type': 'Reversed phase', 'chromatography_column': 'Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)', 'chromatography_protocol': 'The mobile phases were 10mM PFHA in water (mobile phase A) and acetonitrile (mobile phase B) using the following gradient: 0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'chromatography_instrument': 'Waters TQS', 'chromatography_method_filename': 'nan', 'elution_program': '0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'flow_rate': '0.3 ml/minute', 'solventA': '100% water; ; 10mM perfluoroheptanoic acid', 'solventB': '100% acetonitrile; ;', 'solventC': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_type': 'ESI', 'ms_protocol': 'Multiple reaction monitoring in positive ion mode', 'ms_method_filename': 'nan', 'ion_mode': 'POSITIVE', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'Prj171:metabolite_extract_L92'}], 'type': 'mass_spec_assay', 'submitter_id': 'Prj171:TQSm_042122_031', 'sample_dilution': '1:1', 'calibration_standard': '13C,15N-methionine', 'chromatography_type': 'Reversed phase', 'chromatography_column': 'Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)', 'chromatography_protocol': 'The mobile phases were 10mM PFHA in water (mobile phase A) and acetonitrile (mobile phase B) using the following gradient: 0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'chromatography_instrument': 'Waters TQS', 'chromatography_method_filename': 'nan', 'elution_program': '0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'flow_rate': '0.3 ml/minute', 'solventA': '100% water; ; 10mM perfluoroheptanoic acid', 'solventB': '100% acetonitrile; ;', 'solventC': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_type': 'ESI', 'ms_protocol': 'Multiple reaction monitoring in positive ion mode', 'ms_method_filename': 'nan', 'ion_mode': 'POSITIVE', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'Prj171:metabolite_extract_L115'}], 'type': 'mass_spec_assay', 'submitter_id': 'Prj171:TQSm_042122_032', 'sample_dilution': '1:1', 'calibration_standard': '13C,15N-methionine', 'chromatography_type': 'Reversed phase', 'chromatography_column': 'Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)', 'chromatography_protocol': 'The mobile phases were 10mM PFHA in water (mobile phase A) and acetonitrile (mobile phase B) using the following gradient: 0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'chromatography_instrument': 'Waters TQS', 'chromatography_method_filename': 'nan', 'elution_program': '0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'flow_rate': '0.3 ml/minute', 'solventA': '100% water; ; 10mM perfluoroheptanoic acid', 'solventB': '100% acetonitrile; ;', 'solventC': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_type': 'ESI', 'ms_protocol': 'Multiple reaction monitoring in positive ion mode', 'ms_method_filename': 'nan', 'ion_mode': 'POSITIVE', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'Prj171:metabolite_extract_L116'}], 'type': 'mass_spec_assay', 'submitter_id': 'Prj171:TQSm_042122_033', 'sample_dilution': '1:1', 'calibration_standard': '13C,15N-methionine', 'chromatography_type': 'Reversed phase', 'chromatography_column': 'Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)', 'chromatography_protocol': 'The mobile phases were 10mM PFHA in water (mobile phase A) and acetonitrile (mobile phase B) using the following gradient: 0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'chromatography_instrument': 'Waters TQS', 'chromatography_method_filename': 'nan', 'elution_program': '0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'flow_rate': '0.3 ml/minute', 'solventA': '100% water; ; 10mM perfluoroheptanoic acid', 'solventB': '100% acetonitrile; ;', 'solventC': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_type': 'ESI', 'ms_protocol': 'Multiple reaction monitoring in positive ion mode', 'ms_method_filename': 'nan', 'ion_mode': 'POSITIVE', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'Prj171:metabolite_extract_L139'}], 'type': 'mass_spec_assay', 'submitter_id': 'Prj171:TQSm_042122_034', 'sample_dilution': '1:1', 'calibration_standard': '13C,15N-methionine', 'chromatography_type': 'Reversed phase', 'chromatography_column': 'Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)', 'chromatography_protocol': 'The mobile phases were 10mM PFHA in water (mobile phase A) and acetonitrile (mobile phase B) using the following gradient: 0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'chromatography_instrument': 'Waters TQS', 'chromatography_method_filename': 'nan', 'elution_program': '0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'flow_rate': '0.3 ml/minute', 'solventA': '100% water; ; 10mM perfluoroheptanoic acid', 'solventB': '100% acetonitrile; ;', 'solventC': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_type': 'ESI', 'ms_protocol': 'Multiple reaction monitoring in positive ion mode', 'ms_method_filename': 'nan', 'ion_mode': 'POSITIVE', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'Prj171:metabolite_extract_L118'}], 'type': 'mass_spec_assay', 'submitter_id': 'Prj171:TQSm_042122_035', 'sample_dilution': '1:1', 'calibration_standard': '13C,15N-methionine', 'chromatography_type': 'Reversed phase', 'chromatography_column': 'Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)', 'chromatography_protocol': 'The mobile phases were 10mM PFHA in water (mobile phase A) and acetonitrile (mobile phase B) using the following gradient: 0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'chromatography_instrument': 'Waters TQS', 'chromatography_method_filename': 'nan', 'elution_program': '0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'flow_rate': '0.3 ml/minute', 'solventA': '100% water; ; 10mM perfluoroheptanoic acid', 'solventB': '100% acetonitrile; ;', 'solventC': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_type': 'ESI', 'ms_protocol': 'Multiple reaction monitoring in positive ion mode', 'ms_method_filename': 'nan', 'ion_mode': 'POSITIVE', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'Prj171:metabolite_extract_L119'}], 'type': 'mass_spec_assay', 'submitter_id': 'Prj171:TQSm_042122_036', 'sample_dilution': '1:1', 'calibration_standard': '13C,15N-methionine', 'chromatography_type': 'Reversed phase', 'chromatography_column': 'Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)', 'chromatography_protocol': 'The mobile phases were 10mM PFHA in water (mobile phase A) and acetonitrile (mobile phase B) using the following gradient: 0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'chromatography_instrument': 'Waters TQS', 'chromatography_method_filename': 'nan', 'elution_program': '0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'flow_rate': '0.3 ml/minute', 'solventA': '100% water; ; 10mM perfluoroheptanoic acid', 'solventB': '100% acetonitrile; ;', 'solventC': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_type': 'ESI', 'ms_protocol': 'Multiple reaction monitoring in positive ion mode', 'ms_method_filename': 'nan', 'ion_mode': 'POSITIVE', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'Prj171:metabolite_extract_L94'}], 'type': 'mass_spec_assay', 'submitter_id': 'Prj171:TQSm_042122_037', 'sample_dilution': '1:1', 'calibration_standard': '13C,15N-methionine', 'chromatography_type': 'Reversed phase', 'chromatography_column': 'Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)', 'chromatography_protocol': 'The mobile phases were 10mM PFHA in water (mobile phase A) and acetonitrile (mobile phase B) using the following gradient: 0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'chromatography_instrument': 'Waters TQS', 'chromatography_method_filename': 'nan', 'elution_program': '0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'flow_rate': '0.3 ml/minute', 'solventA': '100% water; ; 10mM perfluoroheptanoic acid', 'solventB': '100% acetonitrile; ;', 'solventC': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_type': 'ESI', 'ms_protocol': 'Multiple reaction monitoring in positive ion mode', 'ms_method_filename': 'nan', 'ion_mode': 'POSITIVE', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'Prj171:metabolite_extract_L142'}], 'type': 'mass_spec_assay', 'submitter_id': 'Prj171:TQSm_042122_038', 'sample_dilution': '1:1', 'calibration_standard': '13C,15N-methionine', 'chromatography_type': 'Reversed phase', 'chromatography_column': 'Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)', 'chromatography_protocol': 'The mobile phases were 10mM PFHA in water (mobile phase A) and acetonitrile (mobile phase B) using the following gradient: 0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'chromatography_instrument': 'Waters TQS', 'chromatography_method_filename': 'nan', 'elution_program': '0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'flow_rate': '0.3 ml/minute', 'solventA': '100% water; ; 10mM perfluoroheptanoic acid', 'solventB': '100% acetonitrile; ;', 'solventC': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_type': 'ESI', 'ms_protocol': 'Multiple reaction monitoring in positive ion mode', 'ms_method_filename': 'nan', 'ion_mode': 'POSITIVE', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'Prj171:metabolite_extract_L143'}], 'type': 'mass_spec_assay', 'submitter_id': 'Prj171:TQSm_042122_039', 'sample_dilution': '1:1', 'calibration_standard': '13C,15N-methionine', 'chromatography_type': 'Reversed phase', 'chromatography_column': 'Waters ACQUITY UPLC HSS T3 (100 x 2.1mm,1.8um)', 'chromatography_protocol': 'The mobile phases were 10mM PFHA in water (mobile phase A) and acetonitrile (mobile phase B) using the following gradient: 0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'chromatography_instrument': 'Waters TQS', 'chromatography_method_filename': 'nan', 'elution_program': '0 min - 100% A, 1.0 min - 100% A, 6.0 min - 35% A, 6.01 min - 10% A, 7.0 min - 10% A, 7.01 min - 100% A, 9.0 min - 100% A', 'flow_rate': '0.3 ml/minute', 'solventA': '100% water; ; 10mM perfluoroheptanoic acid', 'solventB': '100% acetonitrile; ;', 'solventC': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_type': 'ESI', 'ms_protocol': 'Multiple reaction monitoring in positive ion mode', 'ms_method_filename': 'nan', 'ion_mode': 'POSITIVE', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]

# %%
df = pd.read_table("/Users/apple/Desktop/test_gen3/DH_ExportedFiles/ms_raw_data.tsv")
file_names = df["file_name"].to_list()
for file_name in file_names:
    path = '/Users/apple/Desktop/test_gen3/DH_ExportedFiles/ms_raw_data/' + file_name
    with open(path, 'w') as file:
        file.write(path)

# %%
# automatically insert md5sum and file_size
import pandas as pd
import hashlib
import os
def calculate_md5(file_path):
    """Calculate the MD5 checksum for a file."""
    md5_hash = hashlib.md5()
    with open(file_path, 'rb') as file:
        for chunk in iter(lambda: file.read(4096), b''):
            md5_hash.update(chunk)
    return md5_hash.hexdigest()

# Provide the file name list and DataFrame
df = pd.read_table("/Users/apple/Desktop/test_gen3/DH_ExportedFiles/ms_raw_data.tsv")
file_names = df["file_name"].to_list()

# Provide the path to the folder containing the files
folder_path = '/Users/apple/Desktop/test_gen3/DH_ExportedFiles/ms_raw_data/'

# Update the MD5 checksum for each file name in the DataFrame
for file_name in file_names:
    file_path = folder_path + file_name
    md5_sum = calculate_md5(file_path)
    file_size = os.path.getsize(file_path)
    df.loc[df['file_name'] == file_name, 'md5sum'] = md5_sum
    df.loc[df['file_name'] == file_name, 'file_size'] = file_size
df['file_size'] = df['file_size'].astype(int)
df.to_csv("/Users/apple/Desktop/test_gen3/DH_ExportedFiles/ms_raw_data_revised.tsv", sep='\t', index=False)
df.head()
# Out:
#           type                 submitter_id mass_spec_assays.submitter_id  \
# 0  ms_raw_data  Prj171:TQSm_042122_010.mzML        Prj171:TQSm_042122_010
# 1  ms_raw_data  Prj171:TQSm_042122_011.mzML        Prj171:TQSm_042122_011
# 2  ms_raw_data  Prj171:TQSm_042122_012.mzML        Prj171:TQSm_042122_012
# 3  ms_raw_data  Prj171:TQSm_042122_013.mzML        Prj171:TQSm_042122_013
# 4  ms_raw_data  Prj171:TQSm_042122_014.mzML        Prj171:TQSm_042122_014
#
#               file_name  file_size                            md5sum  \
# 0  TQSm_042122_010.mzML         80  0edb4486c3bda16534226663e0efc929
# 1  TQSm_042122_011.mzML         80  575e7adfd53ada1f08f55175e17ead6b
# 2  TQSm_042122_012.mzML         80  9d27dee74274d28c76149450710bf659
# 3  TQSm_042122_013.mzML         80  65ca95b578bd68c254fab02c651c2a42
# 4  TQSm_042122_014.mzML         80  84af47183d95a3384ace7e15d4c7be2e
#
#    object_id          data_category data_format      data_type  \
# 0        NaN  targeted metabolomics       .mzML  chromatograms
# 1        NaN  targeted metabolomics       .mzML  chromatograms
# 2        NaN  targeted metabolomics       .mzML  chromatograms
# 3        NaN  targeted metabolomics       .mzML  chromatograms
# 4        NaN  targeted metabolomics       .mzML  chromatograms
#
#    file_source_repository  repository_accession_id  repository_download_ftp  \
# 0                     NaN                      NaN                      NaN
# 1                     NaN                      NaN                      NaN
# 2                     NaN                      NaN                      NaN
# 3                     NaN                      NaN                      NaN
# 4                     NaN                      NaN                      NaN
#
#    provenance
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
# ms_raw_Data
data = sub.submit_file(filename="/Users/apple/Desktop/test_gen3/DH_ExportedFiles/ms_raw_data_revised.tsv", project_id="MyFirstProgram-MyFirstProject")
# Out:
# Submitting /Users/apple/Desktop/test_gen3/DH_ExportedFiles/ms_raw_data_revised.tsv with 30 records.
# Chunk 1 (chunk size: 30, submitted: 0 of 30)
# 	 Succeeded: 30 entities.
# Chunk 2 (chunk size: 30, submitted: 30 of 30)
# 	Chunk Failed (status code 400): 0 entities.
# 	Invalid records in this chunk: 0
# Finished data submission.
# Successful records: 30
# Failed invalid records: 0

# %%
df = pd.read_table("/Users/apple/Desktop/test_gen3/DH_ExportedFiles/ms_analysis.tsv")

df.head()
# Out:
#           type            submitter_id    ms_raw_datas.submitter_id  \
# 0  ms_analysis  Prj171:TQSm_042122_010  Prj171:TQSm_042122_010.mzML
# 1  ms_analysis  Prj171:TQSm_042122_011  Prj171:TQSm_042122_011.mzML
# 2  ms_analysis  Prj171:TQSm_042122_012  Prj171:TQSm_042122_012.mzML
# 3  ms_analysis  Prj171:TQSm_042122_013  Prj171:TQSm_042122_013.mzML
# 4  ms_analysis  Prj171:TQSm_042122_014  Prj171:TQSm_042122_014.mzML
#
#            normalization  transformation  transformation_purpose  \
# 0  normalized to protein             NaN                     NaN
# 1  normalized to protein             NaN                     NaN
# 2  normalized to protein             NaN                     NaN
# 3  normalized to protein             NaN                     NaN
# 4  normalized to protein             NaN                     NaN
#
#    transformation_description                  unit  analysis_protocols  \
# 0                         NaN  normalized peak area                 NaN
# 1                         NaN  normalized peak area                 NaN
# 2                         NaN  normalized peak area                 NaN
# 3                         NaN  normalized peak area                 NaN
# 4                         NaN  normalized peak area                 NaN
#
#                                        provenance
# 0  DataHarmonizer v1.4.10, mass_spec_assay v1.0.0
# 1  DataHarmonizer v1.4.10, mass_spec_assay v1.0.0
# 2  DataHarmonizer v1.4.10, mass_spec_assay v1.0.0
# 3  DataHarmonizer v1.4.10, mass_spec_assay v1.0.0
# 4  DataHarmonizer v1.4.10, mass_spec_assay v1.0.0

# %%
# ms_analysis
data = sub.submit_file(filename="/Users/apple/Desktop/test_gen3/DH_ExportedFiles/ms_analysis.tsv", project_id="MyFirstProgram-MyFirstProject")
# Out:
# Submitting /Users/apple/Desktop/test_gen3/DH_ExportedFiles/ms_analysis.tsv with 30 records.
# Chunk 1 (chunk size: 30, submitted: 0 of 30)
# 	 Succeeded: 30 entities.
# Chunk 2 (chunk size: 30, submitted: 30 of 30)
# 	Chunk Failed (status code 400): 0 entities.
# 	Invalid records in this chunk: 0
# Finished data submission.
# Successful records: 30
# Failed invalid records: 0

# %%
# create a folder of files
df = pd.read_table("/Users/apple/Desktop/test_gen3/DH_ExportedFiles/ms_analysed_data.tsv")
file_names = df["file_name"].to_list()
for file_name in file_names:
    path = '/Users/apple/Desktop/test_gen3/DH_ExportedFiles/processeddata_ms/' + file_name
    with open(path, 'w') as file:
        file.write(path)

# %%
import pandas as pd
import hashlib
import os
def calculate_md5(file_path):
    """Calculate the MD5 checksum for a file."""
    md5_hash = hashlib.md5()
    with open(file_path, 'rb') as file:
        for chunk in iter(lambda: file.read(4096), b''):
            md5_hash.update(chunk)
    return md5_hash.hexdigest()

# Provide the file name list and DataFrame
df = pd.read_table("/Users/apple/Desktop/test_gen3/DH_ExportedFiles/ms_analysed_data.tsv")
file_names = df["file_name"].to_list()

folder_path = '/Users/apple/Desktop/test_gen3/DH_ExportedFiles/processeddata_ms/'

# Update the MD5 checksum for each file name in the DataFrame
for file_name in file_names:
    file_path = folder_path + file_name
    md5_sum = calculate_md5(file_path)
    file_size = os.path.getsize(file_path)
    df.loc[df['file_name'] == file_name, 'md5sum'] = md5_sum
    df.loc[df['file_name'] == file_name, 'file_size'] = file_size
df['file_size'] = df['file_size'].astype(int)
df.to_csv("/Users/apple/Desktop/test_gen3/DH_ExportedFiles/ms_analysed_data_updated.tsv", sep='\t', index=False)
df.head()
# Out:
#                type                         submitter_id  \
# 0  ms_analysed_data  Prj171:CEC_normalized_peak_area.txt
#
#                             ms_analyses.submitter_id  \
# 0  Prj171:TQSm_042122_010,Prj171:TQSm_042122_011,...
#
#                       file_name  file_size                            md5sum  \
# 0  CEC_normalized_peak_area.txt         93  914f22bde76c63cb776f88855317f8e6
#
#    object_id          data_category data_format      data_type  \
# 0        NaN  targeted metabolomics       .mzML  chromatograms
#
#    file_source_repository  repository_accession_id  repository_download_ftp  \
# 0                     NaN                      NaN                      NaN
#
#                                        provenance
# 0  DataHarmonizer v1.4.10, mass_spec_assay v1.0.0

# %%
# ms_analysed_data
data = sub.submit_file(filename="/Users/apple/Desktop/test_gen3/DH_ExportedFiles/ms_analysed_data_updated.tsv", project_id="MyFirstProgram-MyFirstProject")
# Out:
# Submitting /Users/apple/Desktop/test_gen3/DH_ExportedFiles/ms_analysed_data_updated.tsv with 1 records.
# Chunk 1 (chunk size: 30, submitted: 0 of 1)
# 	 Succeeded: 1 entities.
# Finished data submission.
# Successful records: 1
# Failed invalid records: 0

# %%
df = pd.read_table("/Users/apple/Desktop/test_gen3/DH_ExportedFiles/metabolite_id.tsv")
df.head()
# Out:
#             type                          submitter_id  \
# 0  metabolite_id  Prj171:S-(2-carboxyethyl)-L-cysteine
# 1  metabolite_id             Prj171:13C,15N-methionine
#
#         ms_analysed_datas.submitter_id                metabolite_name  \
# 0  Prj171:CEC_normalized_peak_area.txt  S-(2-carboxyethyl)-L-cysteine
# 1  Prj171:CEC_normalized_peak_area.txt             13C,15N-methionine
#
#   refmet_name          dtxsid  \
# 0         NaN  DTXSID40193329
# 1  methionine             NaN
#
#                                             inchikey      mass  elution_time  \
# 0  1S/C6H11NO4S/c7-4(6(10)11)3-12-2-1-5(8)9/h4H,1...  193.2200          2.60
# 1  1S/C5H11NO2S/c1-9-3-2-4(6)5(7)8/h4H,2-3,6H2,1H...  149.0511          5.12
#
#                                        provenance
# 0  DataHarmonizer v1.4.10, mass_spec_assay v1.0.0
# 1  DataHarmonizer v1.4.10, mass_spec_assay v1.0.0

# %%
# metabolite_id
data = sub.submit_file(filename="/Users/apple/Desktop/test_gen3/DH_ExportedFiles/metabolite_id.tsv", project_id="MyFirstProgram-MyFirstProject")
# Out:
# Submitting /Users/apple/Desktop/test_gen3/DH_ExportedFiles/metabolite_id.tsv with 2 records.
# Chunk 1 (chunk size: 30, submitted: 0 of 2)
# 	 Succeeded: 2 entities.
# Finished data submission.
# Successful records: 2
# Failed invalid records: 0
