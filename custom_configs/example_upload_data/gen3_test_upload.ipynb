# %%
import pandas as pd
import numpy as np
import subprocess
import sys
import gen3
import json
from gen3.submission import Gen3Submission
from gen3.auth import Gen3Auth
from gen3.index import Gen3Index
from gen3.query import Gen3Query
from gen3.metadata import Gen3Metadata
from gen3.file import Gen3File
import os

# download and import some custom Python scripts from https://github.com/cgmeyer/gen3sdk-python
# os.system("wget https://raw.githubusercontent.com/cgmeyer/gen3sdk-python/master/expansion/expansion.py")
from expansion import Gen3Expansion

# %%
api = 'https://fairtox.com/'
cred = '/Users/apple/Desktop/test_gen3/credentials20.json'
auth = Gen3Auth(api, refresh_file=cred)
sub = Gen3Submission(api, auth)
query = Gen3Query(auth)
index = Gen3Index(auth)
file = Gen3File(auth)
metadata = Gen3Metadata(auth)
exp = Gen3Expansion(api,auth,sub)

# %% [markdown]
# ## create program

# %%
prog = 'MyFirstProgram'

prog_txt = """{
    "dbgap_accession_number": "%s",
    "type": "program",
    "name": "%s"
}""" % (prog,prog)

prog_json = json.loads(prog_txt)
data = sub.create_program(json=prog_json)

# %% [markdown]
# ## create project

# %%
proj_txt = """{
    "availability_type": "Open",
    "code": "MyFirstProject",
    "dbgap_accession_number": "MyFirstProject",
    "type": "project",
    "contact_name": "test",
    "institution": "MSU",
    "description": "test",
    "email_address": "xxxxx@fdas.sdfs",
    "telephone_number": "ssd-asdf-asdf"
    }"""
proj_json = json.loads(proj_txt)
data = sub.create_project(program="MyFirstProgram",json=proj_json)

# %% [markdown]
# ## upload other nodes

# %%
df = pd.read_table("/Users/apple/Desktop/test_gen3/data_test2/study.tsv")
df.head()
# Out:
#     type submitter_id   projects.code  \
# 0  study       PRJ129  MyFirstProject
#
#                                          study_title  \
# 0  28 day repeated dose TCDD dose-response study ...
#
#                                    study_description          study_design  \
# 0  These experiments aimed to evaluate the dose-d...  dose response design
#
#        study_type experimental_setting      organism  provenance
# 0  Toxicogenomics              in vivo  Mus musculus         NaN

# %%
# study
df = pd.read_table('/Users/apple/Desktop/test_gen3/data_test2/study.tsv')
df["projects.code"].fillna("MyFirstProject", inplace=True)
df.to_csv('/Users/apple/Desktop/test_gen3/data_test2/study.tsv', sep='\t', index=False)
data = sub.submit_file(filename="/Users/apple/Desktop/test_gen3/data_test2/study.tsv", project_id="MyFirstProgram-MyFirstProject")
# Out:
# Submitting /Users/apple/Desktop/test_gen3/data_test2/study.tsv with 1 records.
# Chunk 1 (chunk size: 30, submitted: 0 of 1)
# 	 Succeeded: 1 entities.
# Finished data submission.
# Successful records: 1
# Failed invalid records: 0

# %%
df = pd.read_table('/Users/apple/Desktop/test_gen3/data_test2/contact.tsv')
df.head()
# Out:
#       type     submitter_id studies.submitter_id     contact_name  \
# 0  contact  Tim Zacharewski               PRJ129  Tim Zacharewski
#
#          contact_orcid     contact_email contact_telephone  \
# 0  0000-0002-3662-7919  tzachare@msu.edu      517-884-2054
#
#                  contact_department        contact_institution  \
# 0  Biochemistry & Molecular Biology  Michigan State University
#
#              location  provenance
# 0  48824:East Lansing         NaN

# %%
# contact
data = sub.submit_file(filename="/Users/apple/Desktop/test_gen3/data_test2/contact.tsv", project_id="MyFirstProgram-MyFirstProject")
# Out:
# Submitting /Users/apple/Desktop/test_gen3/data_test2/contact.tsv with 1 records.
# Chunk 1 (chunk size: 30, submitted: 0 of 1)
# 	 Succeeded: 1 entities.
# Finished data submission.
# Successful records: 1
# Failed invalid records: 0

# %%
df = pd.read_table('/Users/apple/Desktop/test_gen3/data_test2/funding.tsv')
df.head()
# Out:
#       type submitter_id studies.submitter_id   support_id  \
# 0  funding  P42ES004911               PRJ129  P42ES004911
#
#                             support_source  provenance
# 0  NIEHS; Superfund Basic Research Program         NaN

# %%
# funding
data = sub.submit_file(filename="/Users/apple/Desktop/test_gen3/data_test2/funding.tsv", project_id="MyFirstProgram-MyFirstProject")
# Out:
# Submitting /Users/apple/Desktop/test_gen3/data_test2/funding.tsv with 1 records.
# Chunk 1 (chunk size: 30, submitted: 0 of 1)
# 	 Succeeded: 1 entities.
# Finished data submission.
# Successful records: 1
# Failed invalid records: 0

# %%
df = pd.read_table('/Users/apple/Desktop/test_gen3/data_test2/publication.tsv')
df.head()
# Out:
#           type     submitter_id studies.submitter_id           PMC_id  \
# 0  publication  5009443:4456707               PRJ129  5009443:4456707
#
#                                                DOI               PMID  \
# 0  10.1093/toxsci/kfv206:10.1186/s12864-015-1527-z  26377647:25958198
#
#    provenance
# 0         NaN

# %%
# publication
data = sub.submit_file(filename="/Users/apple/Desktop/test_gen3/data_test2/publication.tsv", project_id="MyFirstProgram-MyFirstProject")
# Out:
# Submitting /Users/apple/Desktop/test_gen3/data_test2/publication.tsv with 1 records.
# Chunk 1 (chunk size: 30, submitted: 0 of 1)
# 	Chunk Failed (status code 400): 1 entities.
# 	Invalid records in this chunk: 1
# Finished data submission.
# Successful records: 0
# Failed invalid records: 1

# %%
df = pd.read_table("/Users/apple/Desktop/test_gen3/data_test2/subject.tsv")
df.head()
# Out:
#       type submitter_id studies.submitter_id  start_date  start_date_age  \
# 0  subject         K001               PRJ129  2012-04-13              23
# 1  subject         K002               PRJ129  2012-04-13              23
# 2  subject         K003               PRJ129  2012-04-13              23
# 3  subject         K004               PRJ129  2012-04-13              23
# 4  subject         K005               PRJ129  2012-04-13              23
#
#   experiment_start_date  experiment_start_zt     sex       strain  \
# 0            2012-04-18                  NaN  female  C57BL/6NCrl
# 1            2012-04-18                  NaN  female  C57BL/6NCrl
# 2            2012-04-18                  NaN  female  C57BL/6NCrl
# 3            2012-04-18                  NaN  female  C57BL/6NCrl
# 4            2012-04-18                  NaN  female  C57BL/6NCrl
#
#                    strain_source euthanasia_date  euthanasia_zt  \
# 0  Charles Rivers Laboraratories      2012-05-16            NaN
# 1  Charles Rivers Laboraratories      2012-05-16            NaN
# 2  Charles Rivers Laboraratories      2012-05-16            NaN
# 3  Charles Rivers Laboraratories      2012-05-16            NaN
# 4  Charles Rivers Laboraratories      2012-05-16            NaN
#
#       euthanasia_method  provenance
# 0  Cervical dislocation         NaN
# 1  Cervical dislocation         NaN
# 2  Cervical dislocation         NaN
# 3  Cervical dislocation         NaN
# 4  Cervical dislocation         NaN

# %%
# subject
data = sub.submit_file(filename="/Users/apple/Desktop/test_gen3/data_test2/subject.tsv", project_id="MyFirstProgram-MyFirstProject")
# Out:
# Submitting /Users/apple/Desktop/test_gen3/data_test2/subject.tsv with 6 records.
# Chunk 1 (chunk size: 30, submitted: 0 of 6)
# 	 Succeeded: 6 entities.
# Finished data submission.
# Successful records: 6
# Failed invalid records: 0

# %%
api = 'https://fairtox.com/'
cred = '/Users/apple/Desktop/test_gen3/credentials20.json'
auth = Gen3Auth(api, refresh_file=cred)
sub = Gen3Submission(api, auth)
query = Gen3Query(auth)
index = Gen3Index(auth)
file = Gen3File(auth)
metadata = Gen3Metadata(auth)
exp = Gen3Expansion(api,auth,sub)

# treatment 
data = sub.submit_file(filename="/Users/apple/Desktop/test_gen3/data_test2/treatment.tsv", project_id="MyFirstProgram-MyFirstProject")
# Out:
# Submitting /Users/apple/Desktop/test_gen3/data_test2/treatment.tsv with 1 records.
# Chunk 1 (chunk size: 30, submitted: 0 of 1)
# 	 Succeeded: 1 entities.
# Finished data submission.
# Successful records: 1
# Failed invalid records: 0

# %%
# housing
data = sub.submit_file(filename="/Users/apple/Desktop/test_gen3/data_test2/housing.tsv", project_id="MyFirstProgram-MyFirstProject")
# Out:
# Submitting /Users/apple/Desktop/test_gen3/data_test2/housing.tsv with 2 records.
# Chunk 1 (chunk size: 30, submitted: 0 of 2)
# 	 Succeeded: 2 entities.
# Finished data submission.
# Successful records: 2
# Failed invalid records: 0

# %%
df = pd.read_table("/Users/apple/Desktop/test_gen3/data_test2/sample.tsv")
df.head()
# Out:
#      type             submitter_id subjects.submitter_id        date  \
# 0  sample  PR129:Liver_frozen_M001                  K001  2012-05-16
# 1  sample  PR129:Liver_frozen_M002                  K002  2012-05-16
# 2  sample  PR129:Liver_frozen_M003                  K003  2012-05-16
# 3  sample  PR129:Liver_frozen_M004                  K004  2012-05-16
# 4  sample  PR129:Liver_frozen_M005                  K005  2012-05-16
#
#   biospecimen_anatomic_site method_of_sample_procurement preservation_method  \
# 0                     Liver                 Not provided         Snap Frozen
# 1                     Liver                 Not provided         Snap Frozen
# 2                     Liver                 Not provided         Snap Frozen
# 3                     Liver                 Not provided         Snap Frozen
# 4                     Liver                 Not provided         Snap Frozen
#
#    weight  volume                             provenance
# 0     NaN     NaN  DataHarmonizer v1.4.10, Sample v4.3.1
# 1     NaN     NaN  DataHarmonizer v1.4.10, Sample v4.3.1
# 2     NaN     NaN  DataHarmonizer v1.4.10, Sample v4.3.1
# 3     NaN     NaN  DataHarmonizer v1.4.10, Sample v4.3.1
# 4     NaN     NaN  DataHarmonizer v1.4.10, Sample v4.3.1

# %%
api = 'https://fairtox.com/'
cred = '/Users/apple/Desktop/test_gen3/credentials20.json'
auth = Gen3Auth(api, refresh_file=cred)
sub = Gen3Submission(api, auth)
query = Gen3Query(auth)
index = Gen3Index(auth)
file = Gen3File(auth)
metadata = Gen3Metadata(auth)
exp = Gen3Expansion(api,auth,sub)

data = sub.submit_file(filename="/Users/apple/Desktop/test_gen3/data_test2/sample.tsv", project_id="MyFirstProgram-MyFirstProject")
# Out:
# Submitting /Users/apple/Desktop/test_gen3/data_test2/sample.tsv with 12 records.
# Chunk 1 (chunk size: 30, submitted: 0 of 12)
# 	 Succeeded: 12 entities.
# Finished data submission.
# Successful records: 12
# Failed invalid records: 0

# %%
df = pd.read_table("/Users/apple/Desktop/test_gen3/data_test2/aliquot.tsv")
df.head()
# Out:
#       type                  submitter_id     samples.submitter_id  \
# 0  aliquot  PR129:Flow_Liver_frozen_M001  PR129:Liver_frozen_M001
# 1  aliquot  PR129:Flow_Liver_frozen_M002  PR129:Liver_frozen_M002
# 2  aliquot  PR129:Flow_Liver_frozen_M003  PR129:Liver_frozen_M003
# 3  aliquot  PR129:Flow_Liver_frozen_M004  PR129:Liver_frozen_M004
# 4  aliquot  PR129:Flow_Liver_frozen_M005  PR129:Liver_frozen_M005
#
#       analyte_type                                   analyte_protocol  \
# 0  Cell suspension  intestine was removed and cut into the proxima...
# 1  Cell suspension  intestine was removed and cut into the proxima...
# 2  Cell suspension  intestine was removed and cut into the proxima...
# 3  Cell suspension  intestine was removed and cut into the proxima...
# 4  Cell suspension  intestine was removed and cut into the proxima...
#
#                                provenance
# 0  DataHarmonizer v1.4.10, Aliquot v1.0.0
# 1  DataHarmonizer v1.4.10, Aliquot v1.0.0
# 2  DataHarmonizer v1.4.10, Aliquot v1.0.0
# 3  DataHarmonizer v1.4.10, Aliquot v1.0.0
# 4  DataHarmonizer v1.4.10, Aliquot v1.0.0

# %%
# aliquot(miflowcyt)
import requests
COMMONS = "https://fairtox.com/"
API_KEY_FILEPATH = '/Users/apple/Desktop/test_gen3/credentials20.json'

projectname = 'MyFirstProject'
programname = 'MyFirstProgram'
api_url = "{}/api/v0/submission/{}/{}".format(COMMONS,programname,projectname)
df = pd.read_table('/Users/apple/Desktop/test_gen3/data_test2/aliquot.tsv')
col_name = df.columns.tolist()
# this is external link
col_name.remove("samples.submitter_id")

for _, row in df.iterrows():
    jsondata = []
    # this is for the external link
    dic = {
        "samples": [
            {
                "submitter_id": row["samples.submitter_id"]
            }
        ]
    }

    for i in col_name:
        value = row[i]
        if isinstance(value, float) and (value == float('inf') or value == float('-inf') or pd.isna(value)):
            dic[i] = str(value)
        else:
            dic[i] = value

    jsondata.append(dic)
    print(jsondata)
    authn = Gen3Auth(COMMONS, refresh_file=API_KEY_FILEPATH)
    output = requests.put(api_url, auth=authn, json=jsondata)
    output.json()
# Out:
# [{'samples': [{'submitter_id': 'PR129:Liver_frozen_M001'}], 'type': 'aliquot', 'submitter_id': 'PR129:Flow_Liver_frozen_M001', 'analyte_type': 'Cell suspension', 'analyte_protocol': 'intestine was removed and cut into the proximal intestine consisting of the duodenum and jejunum, and the distal intestine consisting of the ileum. Each section was flushed with Ca2+/Mg2+-free PBS, opened longitudinally, and cut into ∼1.5\u2009cm pieces. The proximal and distal intestinal pieces were placed in separate conical tubes containing 10\u2009ml of pre-warmed (37°C) Ca2+/Mg2+-free Hank’s Balanced Salt Solution (HBSS; Sigma) with 5% heat-inactivated fetal bovine serum (HBSS/FBS) and 2\u2009mM EDTA. Enterocytes were dissociated using two 20-min rounds of horizontal shaking (∼250 revolutions per minute [rpm]) at 37°C, transferring the tissue to fresh HBSS/FBS with 2\u2009mM EDTA after the first 20\u2009min. The contents of each tube were strained, intestinal pieces minced, and tissue transferred to a conical tube containing 10\u2009ml of pre-warmed HBSS/FBS with 1.5\u2009mg/ml Collagenase Type IV from Clostridium histolyticum (Sigma) and 40\u2009µg/ml Deoxyribonuclease I from bovine pancreas (Sigma). To digest the tissue, the proximal and distal samples were horizontally shaken (∼250\u2009rpm) at 37°C for 10 and 15\u2009min, respectively, followed by 10\u2009s of vortexing. Each tube was then filtered through a 70\u2009µm cell strainer (Falcon, Tewksbury, Massachusetts) into a conical tube containing HBSS/FBS. The strained cells were pelleted at 1500\u2009rpm for 5\u2009min, washed twice in ice-cold HBSS/FBS and resuspended in ice-cold FACS buffer (Ca2+/Mg2+-free HBSS with 1% bovine serum albumin (Sigma) and 0.1% sodium azide (Sigma), pH 7.6).', 'provenance': 'DataHarmonizer v1.4.10, Aliquot v1.0.0'}]
# [{'samples': [{'submitter_id': 'PR129:Liver_frozen_M002'}], 'type': 'aliquot', 'submitter_id': 'PR129:Flow_Liver_frozen_M002', 'analyte_type': 'Cell suspension', 'analyte_protocol': 'intestine was removed and cut into the proximal intestine consisting of the duodenum and jejunum, and the distal intestine consisting of the ileum. Each section was flushed with Ca2+/Mg2+-free PBS, opened longitudinally, and cut into ∼1.5\u2009cm pieces. The proximal and distal intestinal pieces were placed in separate conical tubes containing 10\u2009ml of pre-warmed (37°C) Ca2+/Mg2+-free Hank’s Balanced Salt Solution (HBSS; Sigma) with 5% heat-inactivated fetal bovine serum (HBSS/FBS) and 2\u2009mM EDTA. Enterocytes were dissociated using two 20-min rounds of horizontal shaking (∼250 revolutions per minute [rpm]) at 37°C, transferring the tissue to fresh HBSS/FBS with 2\u2009mM EDTA after the first 20\u2009min. The contents of each tube were strained, intestinal pieces minced, and tissue transferred to a conical tube containing 10\u2009ml of pre-warmed HBSS/FBS with 1.5\u2009mg/ml Collagenase Type IV from Clostridium histolyticum (Sigma) and 40\u2009µg/ml Deoxyribonuclease I from bovine pancreas (Sigma). To digest the tissue, the proximal and distal samples were horizontally shaken (∼250\u2009rpm) at 37°C for 10 and 15\u2009min, respectively, followed by 10\u2009s of vortexing. Each tube was then filtered through a 70\u2009µm cell strainer (Falcon, Tewksbury, Massachusetts) into a conical tube containing HBSS/FBS. The strained cells were pelleted at 1500\u2009rpm for 5\u2009min, washed twice in ice-cold HBSS/FBS and resuspended in ice-cold FACS buffer (Ca2+/Mg2+-free HBSS with 1% bovine serum albumin (Sigma) and 0.1% sodium azide (Sigma), pH 7.6).', 'provenance': 'DataHarmonizer v1.4.10, Aliquot v1.0.0'}]
# [{'samples': [{'submitter_id': 'PR129:Liver_frozen_M003'}], 'type': 'aliquot', 'submitter_id': 'PR129:Flow_Liver_frozen_M003', 'analyte_type': 'Cell suspension', 'analyte_protocol': 'intestine was removed and cut into the proximal intestine consisting of the duodenum and jejunum, and the distal intestine consisting of the ileum. Each section was flushed with Ca2+/Mg2+-free PBS, opened longitudinally, and cut into ∼1.5\u2009cm pieces. The proximal and distal intestinal pieces were placed in separate conical tubes containing 10\u2009ml of pre-warmed (37°C) Ca2+/Mg2+-free Hank’s Balanced Salt Solution (HBSS; Sigma) with 5% heat-inactivated fetal bovine serum (HBSS/FBS) and 2\u2009mM EDTA. Enterocytes were dissociated using two 20-min rounds of horizontal shaking (∼250 revolutions per minute [rpm]) at 37°C, transferring the tissue to fresh HBSS/FBS with 2\u2009mM EDTA after the first 20\u2009min. The contents of each tube were strained, intestinal pieces minced, and tissue transferred to a conical tube containing 10\u2009ml of pre-warmed HBSS/FBS with 1.5\u2009mg/ml Collagenase Type IV from Clostridium histolyticum (Sigma) and 40\u2009µg/ml Deoxyribonuclease I from bovine pancreas (Sigma). To digest the tissue, the proximal and distal samples were horizontally shaken (∼250\u2009rpm) at 37°C for 10 and 15\u2009min, respectively, followed by 10\u2009s of vortexing. Each tube was then filtered through a 70\u2009µm cell strainer (Falcon, Tewksbury, Massachusetts) into a conical tube containing HBSS/FBS. The strained cells were pelleted at 1500\u2009rpm for 5\u2009min, washed twice in ice-cold HBSS/FBS and resuspended in ice-cold FACS buffer (Ca2+/Mg2+-free HBSS with 1% bovine serum albumin (Sigma) and 0.1% sodium azide (Sigma), pH 7.6).', 'provenance': 'DataHarmonizer v1.4.10, Aliquot v1.0.0'}]
# [{'samples': [{'submitter_id': 'PR129:Liver_frozen_M004'}], 'type': 'aliquot', 'submitter_id': 'PR129:Flow_Liver_frozen_M004', 'analyte_type': 'Cell suspension', 'analyte_protocol': 'intestine was removed and cut into the proximal intestine consisting of the duodenum and jejunum, and the distal intestine consisting of the ileum. Each section was flushed with Ca2+/Mg2+-free PBS, opened longitudinally, and cut into ∼1.5\u2009cm pieces. The proximal and distal intestinal pieces were placed in separate conical tubes containing 10\u2009ml of pre-warmed (37°C) Ca2+/Mg2+-free Hank’s Balanced Salt Solution (HBSS; Sigma) with 5% heat-inactivated fetal bovine serum (HBSS/FBS) and 2\u2009mM EDTA. Enterocytes were dissociated using two 20-min rounds of horizontal shaking (∼250 revolutions per minute [rpm]) at 37°C, transferring the tissue to fresh HBSS/FBS with 2\u2009mM EDTA after the first 20\u2009min. The contents of each tube were strained, intestinal pieces minced, and tissue transferred to a conical tube containing 10\u2009ml of pre-warmed HBSS/FBS with 1.5\u2009mg/ml Collagenase Type IV from Clostridium histolyticum (Sigma) and 40\u2009µg/ml Deoxyribonuclease I from bovine pancreas (Sigma). To digest the tissue, the proximal and distal samples were horizontally shaken (∼250\u2009rpm) at 37°C for 10 and 15\u2009min, respectively, followed by 10\u2009s of vortexing. Each tube was then filtered through a 70\u2009µm cell strainer (Falcon, Tewksbury, Massachusetts) into a conical tube containing HBSS/FBS. The strained cells were pelleted at 1500\u2009rpm for 5\u2009min, washed twice in ice-cold HBSS/FBS and resuspended in ice-cold FACS buffer (Ca2+/Mg2+-free HBSS with 1% bovine serum albumin (Sigma) and 0.1% sodium azide (Sigma), pH 7.6).', 'provenance': 'DataHarmonizer v1.4.10, Aliquot v1.0.0'}]
# [{'samples': [{'submitter_id': 'PR129:Liver_frozen_M005'}], 'type': 'aliquot', 'submitter_id': 'PR129:Flow_Liver_frozen_M005', 'analyte_type': 'Cell suspension', 'analyte_protocol': 'intestine was removed and cut into the proximal intestine consisting of the duodenum and jejunum, and the distal intestine consisting of the ileum. Each section was flushed with Ca2+/Mg2+-free PBS, opened longitudinally, and cut into ∼1.5\u2009cm pieces. The proximal and distal intestinal pieces were placed in separate conical tubes containing 10\u2009ml of pre-warmed (37°C) Ca2+/Mg2+-free Hank’s Balanced Salt Solution (HBSS; Sigma) with 5% heat-inactivated fetal bovine serum (HBSS/FBS) and 2\u2009mM EDTA. Enterocytes were dissociated using two 20-min rounds of horizontal shaking (∼250 revolutions per minute [rpm]) at 37°C, transferring the tissue to fresh HBSS/FBS with 2\u2009mM EDTA after the first 20\u2009min. The contents of each tube were strained, intestinal pieces minced, and tissue transferred to a conical tube containing 10\u2009ml of pre-warmed HBSS/FBS with 1.5\u2009mg/ml Collagenase Type IV from Clostridium histolyticum (Sigma) and 40\u2009µg/ml Deoxyribonuclease I from bovine pancreas (Sigma). To digest the tissue, the proximal and distal samples were horizontally shaken (∼250\u2009rpm) at 37°C for 10 and 15\u2009min, respectively, followed by 10\u2009s of vortexing. Each tube was then filtered through a 70\u2009µm cell strainer (Falcon, Tewksbury, Massachusetts) into a conical tube containing HBSS/FBS. The strained cells were pelleted at 1500\u2009rpm for 5\u2009min, washed twice in ice-cold HBSS/FBS and resuspended in ice-cold FACS buffer (Ca2+/Mg2+-free HBSS with 1% bovine serum albumin (Sigma) and 0.1% sodium azide (Sigma), pH 7.6).', 'provenance': 'DataHarmonizer v1.4.10, Aliquot v1.0.0'}]
# [{'samples': [{'submitter_id': 'PR129:Liver_frozen_M006'}], 'type': 'aliquot', 'submitter_id': 'PR129:Flow_Liver_frozen_M006', 'analyte_type': 'Cell suspension', 'analyte_protocol': 'intestine was removed and cut into the proximal intestine consisting of the duodenum and jejunum, and the distal intestine consisting of the ileum. Each section was flushed with Ca2+/Mg2+-free PBS, opened longitudinally, and cut into ∼1.5\u2009cm pieces. The proximal and distal intestinal pieces were placed in separate conical tubes containing 10\u2009ml of pre-warmed (37°C) Ca2+/Mg2+-free Hank’s Balanced Salt Solution (HBSS; Sigma) with 5% heat-inactivated fetal bovine serum (HBSS/FBS) and 2\u2009mM EDTA. Enterocytes were dissociated using two 20-min rounds of horizontal shaking (∼250 revolutions per minute [rpm]) at 37°C, transferring the tissue to fresh HBSS/FBS with 2\u2009mM EDTA after the first 20\u2009min. The contents of each tube were strained, intestinal pieces minced, and tissue transferred to a conical tube containing 10\u2009ml of pre-warmed HBSS/FBS with 1.5\u2009mg/ml Collagenase Type IV from Clostridium histolyticum (Sigma) and 40\u2009µg/ml Deoxyribonuclease I from bovine pancreas (Sigma). To digest the tissue, the proximal and distal samples were horizontally shaken (∼250\u2009rpm) at 37°C for 10 and 15\u2009min, respectively, followed by 10\u2009s of vortexing. Each tube was then filtered through a 70\u2009µm cell strainer (Falcon, Tewksbury, Massachusetts) into a conical tube containing HBSS/FBS. The strained cells were pelleted at 1500\u2009rpm for 5\u2009min, washed twice in ice-cold HBSS/FBS and resuspended in ice-cold FACS buffer (Ca2+/Mg2+-free HBSS with 1% bovine serum albumin (Sigma) and 0.1% sodium azide (Sigma), pH 7.6).', 'provenance': 'DataHarmonizer v1.4.10, Aliquot v1.0.0'}]
# [{'samples': [{'submitter_id': 'PR129:Liver_formalin_M001'}], 'type': 'aliquot', 'submitter_id': 'PR129:Flow_Liver_formalin_M001', 'analyte_type': 'Cell suspension', 'analyte_protocol': 'intestine was removed and cut into the proximal intestine consisting of the duodenum and jejunum, and the distal intestine consisting of the ileum. Each section was flushed with Ca2+/Mg2+-free PBS, opened longitudinally, and cut into ∼1.5\u2009cm pieces. The proximal and distal intestinal pieces were placed in separate conical tubes containing 10\u2009ml of pre-warmed (37°C) Ca2+/Mg2+-free Hank’s Balanced Salt Solution (HBSS; Sigma) with 5% heat-inactivated fetal bovine serum (HBSS/FBS) and 2\u2009mM EDTA. Enterocytes were dissociated using two 20-min rounds of horizontal shaking (∼250 revolutions per minute [rpm]) at 37°C, transferring the tissue to fresh HBSS/FBS with 2\u2009mM EDTA after the first 20\u2009min. The contents of each tube were strained, intestinal pieces minced, and tissue transferred to a conical tube containing 10\u2009ml of pre-warmed HBSS/FBS with 1.5\u2009mg/ml Collagenase Type IV from Clostridium histolyticum (Sigma) and 40\u2009µg/ml Deoxyribonuclease I from bovine pancreas (Sigma). To digest the tissue, the proximal and distal samples were horizontally shaken (∼250\u2009rpm) at 37°C for 10 and 15\u2009min, respectively, followed by 10\u2009s of vortexing. Each tube was then filtered through a 70\u2009µm cell strainer (Falcon, Tewksbury, Massachusetts) into a conical tube containing HBSS/FBS. The strained cells were pelleted at 1500\u2009rpm for 5\u2009min, washed twice in ice-cold HBSS/FBS and resuspended in ice-cold FACS buffer (Ca2+/Mg2+-free HBSS with 1% bovine serum albumin (Sigma) and 0.1% sodium azide (Sigma), pH 7.6).', 'provenance': 'DataHarmonizer v1.4.10, Aliquot v1.0.0'}]
# [{'samples': [{'submitter_id': 'PR129:Liver_formalin_M002'}], 'type': 'aliquot', 'submitter_id': 'PR129:Flow_Liver_formalin_M002', 'analyte_type': 'Cell suspension', 'analyte_protocol': 'intestine was removed and cut into the proximal intestine consisting of the duodenum and jejunum, and the distal intestine consisting of the ileum. Each section was flushed with Ca2+/Mg2+-free PBS, opened longitudinally, and cut into ∼1.5\u2009cm pieces. The proximal and distal intestinal pieces were placed in separate conical tubes containing 10\u2009ml of pre-warmed (37°C) Ca2+/Mg2+-free Hank’s Balanced Salt Solution (HBSS; Sigma) with 5% heat-inactivated fetal bovine serum (HBSS/FBS) and 2\u2009mM EDTA. Enterocytes were dissociated using two 20-min rounds of horizontal shaking (∼250 revolutions per minute [rpm]) at 37°C, transferring the tissue to fresh HBSS/FBS with 2\u2009mM EDTA after the first 20\u2009min. The contents of each tube were strained, intestinal pieces minced, and tissue transferred to a conical tube containing 10\u2009ml of pre-warmed HBSS/FBS with 1.5\u2009mg/ml Collagenase Type IV from Clostridium histolyticum (Sigma) and 40\u2009µg/ml Deoxyribonuclease I from bovine pancreas (Sigma). To digest the tissue, the proximal and distal samples were horizontally shaken (∼250\u2009rpm) at 37°C for 10 and 15\u2009min, respectively, followed by 10\u2009s of vortexing. Each tube was then filtered through a 70\u2009µm cell strainer (Falcon, Tewksbury, Massachusetts) into a conical tube containing HBSS/FBS. The strained cells were pelleted at 1500\u2009rpm for 5\u2009min, washed twice in ice-cold HBSS/FBS and resuspended in ice-cold FACS buffer (Ca2+/Mg2+-free HBSS with 1% bovine serum albumin (Sigma) and 0.1% sodium azide (Sigma), pH 7.6).', 'provenance': 'DataHarmonizer v1.4.10, Aliquot v1.0.0'}]
# [{'samples': [{'submitter_id': 'PR129:Liver_formalin_M003'}], 'type': 'aliquot', 'submitter_id': 'PR129:Flow_Liver_formalin_M003', 'analyte_type': 'Cell suspension', 'analyte_protocol': 'intestine was removed and cut into the proximal intestine consisting of the duodenum and jejunum, and the distal intestine consisting of the ileum. Each section was flushed with Ca2+/Mg2+-free PBS, opened longitudinally, and cut into ∼1.5\u2009cm pieces. The proximal and distal intestinal pieces were placed in separate conical tubes containing 10\u2009ml of pre-warmed (37°C) Ca2+/Mg2+-free Hank’s Balanced Salt Solution (HBSS; Sigma) with 5% heat-inactivated fetal bovine serum (HBSS/FBS) and 2\u2009mM EDTA. Enterocytes were dissociated using two 20-min rounds of horizontal shaking (∼250 revolutions per minute [rpm]) at 37°C, transferring the tissue to fresh HBSS/FBS with 2\u2009mM EDTA after the first 20\u2009min. The contents of each tube were strained, intestinal pieces minced, and tissue transferred to a conical tube containing 10\u2009ml of pre-warmed HBSS/FBS with 1.5\u2009mg/ml Collagenase Type IV from Clostridium histolyticum (Sigma) and 40\u2009µg/ml Deoxyribonuclease I from bovine pancreas (Sigma). To digest the tissue, the proximal and distal samples were horizontally shaken (∼250\u2009rpm) at 37°C for 10 and 15\u2009min, respectively, followed by 10\u2009s of vortexing. Each tube was then filtered through a 70\u2009µm cell strainer (Falcon, Tewksbury, Massachusetts) into a conical tube containing HBSS/FBS. The strained cells were pelleted at 1500\u2009rpm for 5\u2009min, washed twice in ice-cold HBSS/FBS and resuspended in ice-cold FACS buffer (Ca2+/Mg2+-free HBSS with 1% bovine serum albumin (Sigma) and 0.1% sodium azide (Sigma), pH 7.6).', 'provenance': 'DataHarmonizer v1.4.10, Aliquot v1.0.0'}]
# [{'samples': [{'submitter_id': 'PR129:Liver_formalin_M004'}], 'type': 'aliquot', 'submitter_id': 'PR129:Flow_Liver_formalin_M004', 'analyte_type': 'Cell suspension', 'analyte_protocol': 'intestine was removed and cut into the proximal intestine consisting of the duodenum and jejunum, and the distal intestine consisting of the ileum. Each section was flushed with Ca2+/Mg2+-free PBS, opened longitudinally, and cut into ∼1.5\u2009cm pieces. The proximal and distal intestinal pieces were placed in separate conical tubes containing 10\u2009ml of pre-warmed (37°C) Ca2+/Mg2+-free Hank’s Balanced Salt Solution (HBSS; Sigma) with 5% heat-inactivated fetal bovine serum (HBSS/FBS) and 2\u2009mM EDTA. Enterocytes were dissociated using two 20-min rounds of horizontal shaking (∼250 revolutions per minute [rpm]) at 37°C, transferring the tissue to fresh HBSS/FBS with 2\u2009mM EDTA after the first 20\u2009min. The contents of each tube were strained, intestinal pieces minced, and tissue transferred to a conical tube containing 10\u2009ml of pre-warmed HBSS/FBS with 1.5\u2009mg/ml Collagenase Type IV from Clostridium histolyticum (Sigma) and 40\u2009µg/ml Deoxyribonuclease I from bovine pancreas (Sigma). To digest the tissue, the proximal and distal samples were horizontally shaken (∼250\u2009rpm) at 37°C for 10 and 15\u2009min, respectively, followed by 10\u2009s of vortexing. Each tube was then filtered through a 70\u2009µm cell strainer (Falcon, Tewksbury, Massachusetts) into a conical tube containing HBSS/FBS. The strained cells were pelleted at 1500\u2009rpm for 5\u2009min, washed twice in ice-cold HBSS/FBS and resuspended in ice-cold FACS buffer (Ca2+/Mg2+-free HBSS with 1% bovine serum albumin (Sigma) and 0.1% sodium azide (Sigma), pH 7.6).', 'provenance': 'DataHarmonizer v1.4.10, Aliquot v1.0.0'}]
# [{'samples': [{'submitter_id': 'PR129:Liver_formalin_M005'}], 'type': 'aliquot', 'submitter_id': 'PR129:Flow_Liver_formalin_M005', 'analyte_type': 'Cell suspension', 'analyte_protocol': 'intestine was removed and cut into the proximal intestine consisting of the duodenum and jejunum, and the distal intestine consisting of the ileum. Each section was flushed with Ca2+/Mg2+-free PBS, opened longitudinally, and cut into ∼1.5\u2009cm pieces. The proximal and distal intestinal pieces were placed in separate conical tubes containing 10\u2009ml of pre-warmed (37°C) Ca2+/Mg2+-free Hank’s Balanced Salt Solution (HBSS; Sigma) with 5% heat-inactivated fetal bovine serum (HBSS/FBS) and 2\u2009mM EDTA. Enterocytes were dissociated using two 20-min rounds of horizontal shaking (∼250 revolutions per minute [rpm]) at 37°C, transferring the tissue to fresh HBSS/FBS with 2\u2009mM EDTA after the first 20\u2009min. The contents of each tube were strained, intestinal pieces minced, and tissue transferred to a conical tube containing 10\u2009ml of pre-warmed HBSS/FBS with 1.5\u2009mg/ml Collagenase Type IV from Clostridium histolyticum (Sigma) and 40\u2009µg/ml Deoxyribonuclease I from bovine pancreas (Sigma). To digest the tissue, the proximal and distal samples were horizontally shaken (∼250\u2009rpm) at 37°C for 10 and 15\u2009min, respectively, followed by 10\u2009s of vortexing. Each tube was then filtered through a 70\u2009µm cell strainer (Falcon, Tewksbury, Massachusetts) into a conical tube containing HBSS/FBS. The strained cells were pelleted at 1500\u2009rpm for 5\u2009min, washed twice in ice-cold HBSS/FBS and resuspended in ice-cold FACS buffer (Ca2+/Mg2+-free HBSS with 1% bovine serum albumin (Sigma) and 0.1% sodium azide (Sigma), pH 7.6).', 'provenance': 'DataHarmonizer v1.4.10, Aliquot v1.0.0'}]
# [{'samples': [{'submitter_id': 'PR129:Liver_formalin_M006'}], 'type': 'aliquot', 'submitter_id': 'PR129:Flow_Liver_formalin_M006', 'analyte_type': 'Cell suspension', 'analyte_protocol': 'intestine was removed and cut into the proximal intestine consisting of the duodenum and jejunum, and the distal intestine consisting of the ileum. Each section was flushed with Ca2+/Mg2+-free PBS, opened longitudinally, and cut into ∼1.5\u2009cm pieces. The proximal and distal intestinal pieces were placed in separate conical tubes containing 10\u2009ml of pre-warmed (37°C) Ca2+/Mg2+-free Hank’s Balanced Salt Solution (HBSS; Sigma) with 5% heat-inactivated fetal bovine serum (HBSS/FBS) and 2\u2009mM EDTA. Enterocytes were dissociated using two 20-min rounds of horizontal shaking (∼250 revolutions per minute [rpm]) at 37°C, transferring the tissue to fresh HBSS/FBS with 2\u2009mM EDTA after the first 20\u2009min. The contents of each tube were strained, intestinal pieces minced, and tissue transferred to a conical tube containing 10\u2009ml of pre-warmed HBSS/FBS with 1.5\u2009mg/ml Collagenase Type IV from Clostridium histolyticum (Sigma) and 40\u2009µg/ml Deoxyribonuclease I from bovine pancreas (Sigma). To digest the tissue, the proximal and distal samples were horizontally shaken (∼250\u2009rpm) at 37°C for 10 and 15\u2009min, respectively, followed by 10\u2009s of vortexing. Each tube was then filtered through a 70\u2009µm cell strainer (Falcon, Tewksbury, Massachusetts) into a conical tube containing HBSS/FBS. The strained cells were pelleted at 1500\u2009rpm for 5\u2009min, washed twice in ice-cold HBSS/FBS and resuspended in ice-cold FACS buffer (Ca2+/Mg2+-free HBSS with 1% bovine serum albumin (Sigma) and 0.1% sodium azide (Sigma), pH 7.6).', 'provenance': 'DataHarmonizer v1.4.10, Aliquot v1.0.0'}]
# [{'samples': [{'submitter_id': 'PR129:Liver_formalin_M007'}], 'type': 'aliquot', 'submitter_id': 'PR129:Flow_Liver_formalin_M007', 'analyte_type': 'Cell suspension', 'analyte_protocol': 'intestine was removed and cut into the proximal intestine consisting of the duodenum and jejunum, and the distal intestine consisting of the ileum. Each section was flushed with Ca2+/Mg2+-free PBS, opened longitudinally, and cut into ∼1.5\u2009cm pieces. The proximal and distal intestinal pieces were placed in separate conical tubes containing 10\u2009ml of pre-warmed (37°C) Ca2+/Mg2+-free Hank’s Balanced Salt Solution (HBSS; Sigma) with 5% heat-inactivated fetal bovine serum (HBSS/FBS) and 2\u2009mM EDTA. Enterocytes were dissociated using two 20-min rounds of horizontal shaking (∼250 revolutions per minute [rpm]) at 37°C, transferring the tissue to fresh HBSS/FBS with 2\u2009mM EDTA after the first 20\u2009min. The contents of each tube were strained, intestinal pieces minced, and tissue transferred to a conical tube containing 10\u2009ml of pre-warmed HBSS/FBS with 1.5\u2009mg/ml Collagenase Type IV from Clostridium histolyticum (Sigma) and 40\u2009µg/ml Deoxyribonuclease I from bovine pancreas (Sigma). To digest the tissue, the proximal and distal samples were horizontally shaken (∼250\u2009rpm) at 37°C for 10 and 15\u2009min, respectively, followed by 10\u2009s of vortexing. Each tube was then filtered through a 70\u2009µm cell strainer (Falcon, Tewksbury, Massachusetts) into a conical tube containing HBSS/FBS. The strained cells were pelleted at 1500\u2009rpm for 5\u2009min, washed twice in ice-cold HBSS/FBS and resuspended in ice-cold FACS buffer (Ca2+/Mg2+-free HBSS with 1% bovine serum albumin (Sigma) and 0.1% sodium azide (Sigma), pH 7.6).', 'provenance': 'DataHarmonizer v1.4.10, Aliquot v1.0.0'}]

# %%
df = pd.read_table("/Users/apple/Desktop/test_gen3/data_test2/flow_cytometry_assay.tsv")
df.head()
# Out:
#                    type                   submitter_id  \
# 0  flow_cytometry_assay  PR129:Specimen_001_E1_E01.fcs
# 1  flow_cytometry_assay  PR129:Specimen_001_E2_E02.fcs
# 2  flow_cytometry_assay  PR129:Specimen_001_E3_E03.fcs
# 3  flow_cytometry_assay  PR129:Specimen_001_E4_E04.fcs
# 4  flow_cytometry_assay  PR129:Specimen_001_E5_E05.fcs
#
#           aliquots.submitter_id  \
# 0  PR129:Flow_Liver_frozen_M001
# 1  PR129:Flow_Liver_frozen_M002
# 2  PR129:Flow_Liver_frozen_M003
# 3  PR129:Flow_Liver_frozen_M004
# 4  PR129:Flow_Liver_frozen_M005
#
#                                             protocol  protocol_doi  \
# 0  Fluorescent labeling of the cell suspensions w...           NaN
# 1  Fluorescent labeling of the cell suspensions w...           NaN
# 2  Fluorescent labeling of the cell suspensions w...           NaN
# 3  Fluorescent labeling of the cell suspensions w...           NaN
# 4  Fluorescent labeling of the cell suspensions w...           NaN
#
#   quality_control_measures instruments_submitter_id  \
# 0                  Missing                    PR129
# 1                  Missing                    PR129
# 2                  Missing                    PR129
# 3                  Missing                    PR129
# 4                  Missing                    PR129
#
#                                    staining_protocol  staining_protocol_doi  \
# 0  Cells (10^6) were pelleted and surface Fc rece...                    NaN
# 1  Cells (10^6) were pelleted and surface Fc rece...                    NaN
# 2  Cells (10^6) were pelleted and surface Fc rece...                    NaN
# 3  Cells (10^6) were pelleted and surface Fc rece...                    NaN
# 4  Cells (10^6) were pelleted and surface Fc rece...                    NaN
#
#   characteristics_being_measured analyte           analyte_detector  \
# 0             Leukocytes (NK1.1)   KLRB1  NK1.1 Monoclonal Antibody
# 1             Leukocytes (NK1.1)   KLRB1  NK1.1 Monoclonal Antibody
# 2             Leukocytes (NK1.1)   KLRB1  NK1.1 Monoclonal Antibody
# 3             Leukocytes (NK1.1)   KLRB1  NK1.1 Monoclonal Antibody
# 4             Leukocytes (NK1.1)   KLRB1  NK1.1 Monoclonal Antibody
#
#   analyte_reporter  clone reagent_manufacturer  reagent_catalogue  \
# 0              APC  PK136            BioLegend             108710
# 1              APC  PK136            BioLegend             108710
# 2              APC  PK136            BioLegend             108710
# 3              APC  PK136            BioLegend             108710
# 4              APC  PK136            BioLegend             108710
#
#   staining_status  other_reagent  \
# 0         stained            NaN
# 1         stained            NaN
# 2         stained            NaN
# 3         stained            NaN
# 4         stained            NaN
#
#                                           provenance
# 0  DataHarmonizer v1.4.6, Flow cytometry experime...
# 1  DataHarmonizer v1.4.6, Flow cytometry experime...
# 2  DataHarmonizer v1.4.6, Flow cytometry experime...
# 3  DataHarmonizer v1.4.6, Flow cytometry experime...
# 4  DataHarmonizer v1.4.6, Flow cytometry experime...

# %%
# flow cytometry assay
data = sub.submit_file(filename="/Users/apple/Desktop/test_gen3/data_test2/flow_cytometry_assay.tsv", project_id="MyFirstProgram-MyFirstProject")
# Out:
# Submitting /Users/apple/Desktop/test_gen3/data_test2/flow_cytometry_assay.tsv with 12 records.
# Chunk 1 (chunk size: 30, submitted: 0 of 12)
# 	 Succeeded: 12 entities.
# Finished data submission.
# Successful records: 12
# Failed invalid records: 0

# %%
# create a folder of files
df = pd.read_table("/Users/apple/Desktop/test_gen3/data_test2/flow_data.tsv")
file_names = df["file_name"].to_list()
for file_name in file_names:
    path = '/Users/apple/Desktop/test_gen3/data_test2/raw_data_miflowcyt/' + file_name
    with open(path, 'w') as file:
        file.write(path)

# %%
import pandas as pd
import hashlib
import os
def calculate_md5(file_path):
    """Calculate the MD5 checksum for a file."""
    md5_hash = hashlib.md5()
    with open(file_path, 'rb') as file:
        for chunk in iter(lambda: file.read(4096), b''):
            md5_hash.update(chunk)
    return md5_hash.hexdigest()

# Provide the file name list and DataFrame
df = pd.read_table("/Users/apple/Desktop/test_gen3/data_test2/flow_data.tsv")
file_names = df["file_name"].to_list()

folder_path = '/Users/apple/Desktop/test_gen3/data_test2/raw_data_miflowcyt/'

# Update the MD5 checksum for each file name in the DataFrame
for file_name in file_names:
    file_path = folder_path + file_name
    md5_sum = calculate_md5(file_path)
    file_size = os.path.getsize(file_path)
    df.loc[df['file_name'] == file_name, 'md5sum'] = md5_sum
    df.loc[df['file_name'] == file_name, 'file_size'] = file_size
df['file_size'] = df['file_size'].astype(int)
df.to_csv("/Users/apple/Desktop/test_gen3/data_test2/flow_data_updated.tsv", sep='\t', index=False)
df.head()
# Out:
#         type                       submitter_id  \
# 0  flow_data  PR129:new_Specimen_001_E1_E01.fcs
# 1  flow_data  PR129:new_Specimen_001_E2_E02.fcs
# 2  flow_data  PR129:new_Specimen_001_E3_E03.fcs
# 3  flow_data  PR129:new_Specimen_001_E4_E04.fcs
# 4  flow_data  PR129:new_Specimen_001_E5_E05.fcs
#
#   flow_cytometry_assays.submitter_id                    file_name  \
# 0      PR129:Specimen_001_E1_E01.fcs  new_Specimen_001_E1_E01.fcs
# 1      PR129:Specimen_001_E2_E02.fcs  new_Specimen_001_E2_E02.fcs
# 2      PR129:Specimen_001_E3_E03.fcs  new_Specimen_001_E3_E03.fcs
# 3      PR129:Specimen_001_E4_E04.fcs  new_Specimen_001_E4_E04.fcs
# 4      PR129:Specimen_001_E5_E05.fcs  new_Specimen_001_E5_E05.fcs
#
#         data_type data_format  file_size                            md5sum  \
# 0  flow cytometry         FCS         88  13fbd54b6f8a372ae421c8c0650189f5
# 1  flow cytometry         FCS         88  29c875c24cb6bfca0836b1663cd8cde1
# 2  flow cytometry         FCS         88  8e8215ba2e14dcf936b4c8f5a7095e96
# 3  flow cytometry         FCS         88  7314578708ab5a5b63c43f9fbadd2ce2
# 4  flow cytometry         FCS         88  7b05f70ff756cc9fe87e670847cf2056
#
#    object_id   data_category  \
# 0        NaN  flow cytometry
# 1        NaN  flow cytometry
# 2        NaN  flow cytometry
# 3        NaN  flow cytometry
# 4        NaN  flow cytometry
#
#                                           provenance
# 0  DataHarmonizer v1.4.6, Flow cytometry experime...
# 1  DataHarmonizer v1.4.6, Flow cytometry experime...
# 2  DataHarmonizer v1.4.6, Flow cytometry experime...
# 3  DataHarmonizer v1.4.6, Flow cytometry experime...
# 4  DataHarmonizer v1.4.6, Flow cytometry experime...

# %%
# flow data
data = sub.submit_file(filename="/Users/apple/Desktop/test_gen3/data_test2/flow_data_updated.tsv", project_id="MyFirstProgram-MyFirstProject")
# Out:
# Submitting /Users/apple/Desktop/test_gen3/data_test2/flow_data_updated.tsv with 12 records.
# Chunk 1 (chunk size: 30, submitted: 0 of 12)
# 	 Succeeded: 12 entities.
# Finished data submission.
# Successful records: 12
# Failed invalid records: 0

# %%
df = pd.read_table("/Users/apple/Desktop/test_gen3/data_test2/flow_analysis.tsv")
df
# Out:
#             type                     submitter_id  \
# 0  flow_analysis  PR129:transformationdescription
#
#                              flow_datas.submitter_id           protocol  \
# 0  PR129:new_Specimen_001_E1_E01.fcs,PR129:new_Sp...  analysis_protocol
#
#   compensation_description  transformation_purpose transformation_description  \
# 0  compensationdescription  transformation purpose  transformationdescription
#
#   gate_description gate_statistics gate_boundaries  \
# 0  gatedescription  gatestatistics    gateboundary
#
#                                           provenance           protocol_doi
# 0  DataHarmonizer v1.4.6, Flow cytometry experime...  analysis protocol DOI

# %%
# flow analysis
data = sub.submit_file(filename="/Users/apple/Desktop/test_gen3/data_test2/flow_analysis.tsv", project_id="MyFirstProgram-MyFirstProject")
# Out:
# Submitting /Users/apple/Desktop/test_gen3/data_test2/flow_analysis.tsv with 1 records.
# Chunk 1 (chunk size: 30, submitted: 0 of 1)
# 	 Succeeded: 1 entities.
# Finished data submission.
# Successful records: 1
# Failed invalid records: 0

# %%
# create a folder of files
df = pd.read_table("/Users/apple/Desktop/test_gen3/data_test2/flow_analysis_data.tsv")
file_names = df["file_name"].to_list()
for file_name in file_names:
    path = '/Users/apple/Desktop/test_gen3/data_test2/processdata_miflowcyt/' + file_name
    with open(path, 'w') as file:
        file.write(path)

# %%
import pandas as pd
import hashlib
import os
def calculate_md5(file_path):
    """Calculate the MD5 checksum for a file."""
    md5_hash = hashlib.md5()
    with open(file_path, 'rb') as file:
        for chunk in iter(lambda: file.read(4096), b''):
            md5_hash.update(chunk)
    return md5_hash.hexdigest()

# Provide the file name list and DataFrame
df = pd.read_table("/Users/apple/Desktop/test_gen3/data_test2/flow_analysis_data.tsv")
file_names = df["file_name"].to_list()

folder_path = '/Users/apple/Desktop/test_gen3/data_test2/processdata_miflowcyt/'

# Update the MD5 checksum for each file name in the DataFrame
for file_name in file_names:
    file_path = folder_path + file_name
    md5_sum = calculate_md5(file_path)
    file_size = os.path.getsize(file_path)
    df.loc[df['file_name'] == file_name, 'md5sum'] = md5_sum
    df.loc[df['file_name'] == file_name, 'file_size'] = file_size
df['file_size'] = df['file_size'].astype(int)
df.to_csv("/Users/apple/Desktop/test_gen3/data_test2/flow_analysis_data_updated.tsv", sep='\t', index=False)
df.head()
# Out:
#                  type      submitter_id     flow_analysises.submitter_id  \
# 0  flow_analysis_data  PR129:processed1  PR129:transformationdescription
# 1  flow_analysis_data  PR129:processed2  PR129:transformationdescription
# 2  flow_analysis_data  PR129:processed3  PR129:transformationdescription
# 3  flow_analysis_data  PR129:processed4  PR129:transformationdescription
# 4  flow_analysis_data  PR129:processed5  PR129:transformationdescription
#
#     file_name       data_type data_format  file_size  \
# 0  processed1  flow cytometry         FCS         74
# 1  processed2  flow cytometry         FCS         74
# 2  processed3  flow cytometry         FCS         74
# 3  processed4  flow cytometry         FCS         74
# 4  processed5  flow cytometry         FCS         74
#
#                              md5sum  object_id   data_category  \
# 0  7d692b4285d1f8c1bb28e5d64cad3886        NaN  flow cytometry
# 1  0c71e3fa5d6dc32f0eb4d1d3718750d4        NaN  flow cytometry
# 2  bc0ac82565fc10a72f5608b39ad18ba9        NaN  flow cytometry
# 3  261918eaaa8608086863d805b14a87be        NaN  flow cytometry
# 4  b3b389f275460777a8c59328d331610a        NaN  flow cytometry
#
#                                           provenance
# 0  DataHarmonizer v1.4.6, Flow cytometry experime...
# 1  DataHarmonizer v1.4.6, Flow cytometry experime...
# 2  DataHarmonizer v1.4.6, Flow cytometry experime...
# 3  DataHarmonizer v1.4.6, Flow cytometry experime...
# 4  DataHarmonizer v1.4.6, Flow cytometry experime...

# %%
# flow analysis data
data = sub.submit_file(filename="/Users/apple/Desktop/test_gen3/data_test2/flow_analysis_data_updated.tsv", project_id="MyFirstProgram-MyFirstProject")
# Out:
# Submitting /Users/apple/Desktop/test_gen3/data_test2/flow_analysis_data_updated.tsv with 12 records.
# Chunk 1 (chunk size: 30, submitted: 0 of 12)
# 	 Succeeded: 12 entities.
# Finished data submission.
# Successful records: 12
# Failed invalid records: 0

# %%
df = pd.read_table("/Users/apple/Desktop/test_gen3/data_test2/aliquot_meta.tsv")
df.head()
# Out:
#       type                        submitter_id     samples.submitter_id  \
# 0  aliquot  PR129:metabolite_Liver_frozen_M001  PR129:Liver_frozen_M001
# 1  aliquot  PR129:metabolite_Liver_frozen_M002  PR129:Liver_frozen_M002
# 2  aliquot  PR129:metabolite_Liver_frozen_M003  PR129:Liver_frozen_M003
# 3  aliquot  PR129:metabolite_Liver_frozen_M004  PR129:Liver_frozen_M004
# 4  aliquot  PR129:metabolite_Liver_frozen_M005  PR129:Liver_frozen_M005
#
#   analyte_type derivitization extract_preservation_method  \
# 0      Aqueous           NONE                        -80C
# 1      Aqueous            CBZ                        -80C
# 2      Aqueous           NONE                        -80C
# 3      Aqueous            CBZ                        -80C
# 4      Aqueous           NONE                        -80C
#
#                                     analyte_protocol  provenance
# 0  frozen liver samples were homogenized (Polytro...         NaN
# 1  frozen liver samples were homogenized (Polytro...         NaN
# 2  frozen liver samples were homogenized (Polytro...         NaN
# 3  frozen liver samples were homogenized (Polytro...         NaN
# 4  frozen liver samples were homogenized (Polytro...         NaN

# %%
# ms_aliquot
import requests
COMMONS = "https://fairtox.com/"
API_KEY_FILEPATH = '/Users/apple/Desktop/test_gen3/credentials20.json'

projectname = 'MyFirstProject'
programname = 'MyFirstProgram'
api_url = "{}/api/v0/submission/{}/{}".format(COMMONS,programname,projectname)
df = pd.read_table('/Users/apple/Desktop/test_gen3/data_test2/aliquot_meta.tsv')
col_name = df.columns.tolist()
# this is external link
col_name.remove("samples.submitter_id")

for _, row in df.iterrows():
    jsondata = []
    # this is for the external link
    dic = {
        "samples": [
            {
                "submitter_id": row["samples.submitter_id"]
            }
        ]
    }

    for i in col_name:
        value = row[i]
        if isinstance(value, float) and (value == float('inf') or value == float('-inf') or pd.isna(value)):
            dic[i] = str(value)
        else:
            dic[i] = value

    jsondata.append(dic)
    print(jsondata)
    authn = Gen3Auth(COMMONS, refresh_file=API_KEY_FILEPATH)
    output = requests.put(api_url, auth=authn, json=jsondata)
    output.json()
# Out:
# [{'samples': [{'submitter_id': 'PR129:Liver_frozen_M001'}], 'type': 'aliquot', 'submitter_id': 'PR129:metabolite_Liver_frozen_M001', 'analyte_type': 'Aqueous', 'derivitization': 'NONE', 'extract_preservation_method': '-80C', 'analyte_protocol': 'frozen liver samples were homogenized (Polytron PT2100, Kinematica) or vortexed (serum) in HPLC grade methanol:water (5:3, 4.63\u2009mL, −20°C) in Pyrex glass tubes. HPLC-grade chloroform was added following homogenization (methanol:water:chloroform, 5:3:5), vortexed, shaken on ice for 10\u2009min, and centrifuged at 3000×g. The transferred aqueous phase was dried under nitrogen gas at room temperature and resuspended in HPLC-grade water prior to analysis. Hepatic extract protein layers were dried and a bicinchoninic acid assay (Sigma-Aldrich) on a Tecan Infinite 200 microplate reader (Männedorf, Switzerland) was used to normalize signal in liver.', 'provenance': 'nan'}]
# [{'samples': [{'submitter_id': 'PR129:Liver_frozen_M002'}], 'type': 'aliquot', 'submitter_id': 'PR129:metabolite_Liver_frozen_M002', 'analyte_type': 'Aqueous', 'derivitization': 'CBZ', 'extract_preservation_method': '-80C', 'analyte_protocol': 'frozen liver samples were homogenized (Polytron PT2100, Kinematica) or vortexed (serum) in HPLC grade methanol:water (5:3, 4.63\u2009mL, −20°C) in Pyrex glass tubes. HPLC-grade chloroform was added following homogenization (methanol:water:chloroform, 5:3:5), vortexed, shaken on ice for 10\u2009min, and centrifuged at 3000×g. The transferred aqueous phase was dried under nitrogen gas at room temperature and resuspended in HPLC-grade water prior to analysis. Hepatic extract protein layers were dried and a bicinchoninic acid assay (Sigma-Aldrich) on a Tecan Infinite 200 microplate reader (Männedorf, Switzerland) was used to normalize signal in liver.', 'provenance': 'nan'}]
# [{'samples': [{'submitter_id': 'PR129:Liver_frozen_M003'}], 'type': 'aliquot', 'submitter_id': 'PR129:metabolite_Liver_frozen_M003', 'analyte_type': 'Aqueous', 'derivitization': 'NONE', 'extract_preservation_method': '-80C', 'analyte_protocol': 'frozen liver samples were homogenized (Polytron PT2100, Kinematica) or vortexed (serum) in HPLC grade methanol:water (5:3, 4.63\u2009mL, −20°C) in Pyrex glass tubes. HPLC-grade chloroform was added following homogenization (methanol:water:chloroform, 5:3:5), vortexed, shaken on ice for 10\u2009min, and centrifuged at 3000×g. The transferred aqueous phase was dried under nitrogen gas at room temperature and resuspended in HPLC-grade water prior to analysis. Hepatic extract protein layers were dried and a bicinchoninic acid assay (Sigma-Aldrich) on a Tecan Infinite 200 microplate reader (Männedorf, Switzerland) was used to normalize signal in liver.', 'provenance': 'nan'}]
# [{'samples': [{'submitter_id': 'PR129:Liver_frozen_M004'}], 'type': 'aliquot', 'submitter_id': 'PR129:metabolite_Liver_frozen_M004', 'analyte_type': 'Aqueous', 'derivitization': 'CBZ', 'extract_preservation_method': '-80C', 'analyte_protocol': 'frozen liver samples were homogenized (Polytron PT2100, Kinematica) or vortexed (serum) in HPLC grade methanol:water (5:3, 4.63\u2009mL, −20°C) in Pyrex glass tubes. HPLC-grade chloroform was added following homogenization (methanol:water:chloroform, 5:3:5), vortexed, shaken on ice for 10\u2009min, and centrifuged at 3000×g. The transferred aqueous phase was dried under nitrogen gas at room temperature and resuspended in HPLC-grade water prior to analysis. Hepatic extract protein layers were dried and a bicinchoninic acid assay (Sigma-Aldrich) on a Tecan Infinite 200 microplate reader (Männedorf, Switzerland) was used to normalize signal in liver.', 'provenance': 'nan'}]
# [{'samples': [{'submitter_id': 'PR129:Liver_frozen_M005'}], 'type': 'aliquot', 'submitter_id': 'PR129:metabolite_Liver_frozen_M005', 'analyte_type': 'Aqueous', 'derivitization': 'NONE', 'extract_preservation_method': '-80C', 'analyte_protocol': 'frozen liver samples were homogenized (Polytron PT2100, Kinematica) or vortexed (serum) in HPLC grade methanol:water (5:3, 4.63\u2009mL, −20°C) in Pyrex glass tubes. HPLC-grade chloroform was added following homogenization (methanol:water:chloroform, 5:3:5), vortexed, shaken on ice for 10\u2009min, and centrifuged at 3000×g. The transferred aqueous phase was dried under nitrogen gas at room temperature and resuspended in HPLC-grade water prior to analysis. Hepatic extract protein layers were dried and a bicinchoninic acid assay (Sigma-Aldrich) on a Tecan Infinite 200 microplate reader (Männedorf, Switzerland) was used to normalize signal in liver.', 'provenance': 'nan'}]
# [{'samples': [{'submitter_id': 'PR129:Liver_frozen_M006'}], 'type': 'aliquot', 'submitter_id': 'PR129:metabolite_Liver_frozen_M006', 'analyte_type': 'Aqueous', 'derivitization': 'CBZ', 'extract_preservation_method': '-80C', 'analyte_protocol': 'frozen liver samples were homogenized (Polytron PT2100, Kinematica) or vortexed (serum) in HPLC grade methanol:water (5:3, 4.63\u2009mL, −20°C) in Pyrex glass tubes. HPLC-grade chloroform was added following homogenization (methanol:water:chloroform, 5:3:5), vortexed, shaken on ice for 10\u2009min, and centrifuged at 3000×g. The transferred aqueous phase was dried under nitrogen gas at room temperature and resuspended in HPLC-grade water prior to analysis. Hepatic extract protein layers were dried and a bicinchoninic acid assay (Sigma-Aldrich) on a Tecan Infinite 200 microplate reader (Männedorf, Switzerland) was used to normalize signal in liver.', 'provenance': 'nan'}]
# [{'samples': [{'submitter_id': 'PR129:Liver_formalin_M001'}], 'type': 'aliquot', 'submitter_id': 'PR129:metabolite_Liver_formalin_M001', 'analyte_type': 'Aqueous', 'derivitization': 'NONE', 'extract_preservation_method': '-80C', 'analyte_protocol': 'frozen liver samples were homogenized (Polytron PT2100, Kinematica) or vortexed (serum) in HPLC grade methanol:water (5:3, 4.63\u2009mL, −20°C) in Pyrex glass tubes. HPLC-grade chloroform was added following homogenization (methanol:water:chloroform, 5:3:5), vortexed, shaken on ice for 10\u2009min, and centrifuged at 3000×g. The transferred aqueous phase was dried under nitrogen gas at room temperature and resuspended in HPLC-grade water prior to analysis. Hepatic extract protein layers were dried and a bicinchoninic acid assay (Sigma-Aldrich) on a Tecan Infinite 200 microplate reader (Männedorf, Switzerland) was used to normalize signal in liver.', 'provenance': 'nan'}]
# [{'samples': [{'submitter_id': 'PR129:Liver_formalin_M002'}], 'type': 'aliquot', 'submitter_id': 'PR129:metabolite_Liver_formalin_M002', 'analyte_type': 'Aqueous', 'derivitization': 'NONE', 'extract_preservation_method': '-80C', 'analyte_protocol': 'frozen liver samples were homogenized (Polytron PT2100, Kinematica) or vortexed (serum) in HPLC grade methanol:water (5:3, 4.63\u2009mL, −20°C) in Pyrex glass tubes. HPLC-grade chloroform was added following homogenization (methanol:water:chloroform, 5:3:5), vortexed, shaken on ice for 10\u2009min, and centrifuged at 3000×g. The transferred aqueous phase was dried under nitrogen gas at room temperature and resuspended in HPLC-grade water prior to analysis. Hepatic extract protein layers were dried and a bicinchoninic acid assay (Sigma-Aldrich) on a Tecan Infinite 200 microplate reader (Männedorf, Switzerland) was used to normalize signal in liver.', 'provenance': 'nan'}]
# [{'samples': [{'submitter_id': 'PR129:Liver_formalin_M003'}], 'type': 'aliquot', 'submitter_id': 'PR129:metabolite_Liver_formalin_M003', 'analyte_type': 'Aqueous', 'derivitization': 'CBZ', 'extract_preservation_method': '-80C', 'analyte_protocol': 'frozen liver samples were homogenized (Polytron PT2100, Kinematica) or vortexed (serum) in HPLC grade methanol:water (5:3, 4.63\u2009mL, −20°C) in Pyrex glass tubes. HPLC-grade chloroform was added following homogenization (methanol:water:chloroform, 5:3:5), vortexed, shaken on ice for 10\u2009min, and centrifuged at 3000×g. The transferred aqueous phase was dried under nitrogen gas at room temperature and resuspended in HPLC-grade water prior to analysis. Hepatic extract protein layers were dried and a bicinchoninic acid assay (Sigma-Aldrich) on a Tecan Infinite 200 microplate reader (Männedorf, Switzerland) was used to normalize signal in liver.', 'provenance': 'nan'}]
# [{'samples': [{'submitter_id': 'PR129:Liver_formalin_M004'}], 'type': 'aliquot', 'submitter_id': 'PR129:metabolite_Liver_formalin_M004', 'analyte_type': 'Aqueous', 'derivitization': 'NONE', 'extract_preservation_method': '-80C', 'analyte_protocol': 'frozen liver samples were homogenized (Polytron PT2100, Kinematica) or vortexed (serum) in HPLC grade methanol:water (5:3, 4.63\u2009mL, −20°C) in Pyrex glass tubes. HPLC-grade chloroform was added following homogenization (methanol:water:chloroform, 5:3:5), vortexed, shaken on ice for 10\u2009min, and centrifuged at 3000×g. The transferred aqueous phase was dried under nitrogen gas at room temperature and resuspended in HPLC-grade water prior to analysis. Hepatic extract protein layers were dried and a bicinchoninic acid assay (Sigma-Aldrich) on a Tecan Infinite 200 microplate reader (Männedorf, Switzerland) was used to normalize signal in liver.', 'provenance': 'nan'}]
# [{'samples': [{'submitter_id': 'PR129:Liver_formalin_M005'}], 'type': 'aliquot', 'submitter_id': 'PR129:metabolite_Liver_formalin_M005', 'analyte_type': 'Aqueous', 'derivitization': 'CBZ', 'extract_preservation_method': '-80C', 'analyte_protocol': 'frozen liver samples were homogenized (Polytron PT2100, Kinematica) or vortexed (serum) in HPLC grade methanol:water (5:3, 4.63\u2009mL, −20°C) in Pyrex glass tubes. HPLC-grade chloroform was added following homogenization (methanol:water:chloroform, 5:3:5), vortexed, shaken on ice for 10\u2009min, and centrifuged at 3000×g. The transferred aqueous phase was dried under nitrogen gas at room temperature and resuspended in HPLC-grade water prior to analysis. Hepatic extract protein layers were dried and a bicinchoninic acid assay (Sigma-Aldrich) on a Tecan Infinite 200 microplate reader (Männedorf, Switzerland) was used to normalize signal in liver.', 'provenance': 'nan'}]
# [{'samples': [{'submitter_id': 'PR129:Liver_formalin_M006'}], 'type': 'aliquot', 'submitter_id': 'PR129:metabolite_Liver_formalin_M006', 'analyte_type': 'Aqueous', 'derivitization': 'CBZ', 'extract_preservation_method': '-80C', 'analyte_protocol': 'frozen liver samples were homogenized (Polytron PT2100, Kinematica) or vortexed (serum) in HPLC grade methanol:water (5:3, 4.63\u2009mL, −20°C) in Pyrex glass tubes. HPLC-grade chloroform was added following homogenization (methanol:water:chloroform, 5:3:5), vortexed, shaken on ice for 10\u2009min, and centrifuged at 3000×g. The transferred aqueous phase was dried under nitrogen gas at room temperature and resuspended in HPLC-grade water prior to analysis. Hepatic extract protein layers were dried and a bicinchoninic acid assay (Sigma-Aldrich) on a Tecan Infinite 200 microplate reader (Männedorf, Switzerland) was used to normalize signal in liver.', 'provenance': 'nan'}]

# %%
# mass_spec_assay
import requests
COMMONS = "https://fairtox.com/"
API_KEY_FILEPATH = '/Users/apple/Desktop/test_gen3/credentials20.json'

projectname = 'MyFirstProject'
programname = 'MyFirstProgram'
api_url = "{}/api/v0/submission/{}/{}".format(COMMONS,programname,projectname)
df = pd.read_table('/Users/apple/Desktop/test_gen3/data_test2/mass_spec_assay.tsv')
col_name = df.columns.tolist()
# this is external link
col_name.remove("aliquots.submitter_id")

for _, row in df.iterrows():
    jsondata = []
    # this is for the external link
    dic = {
        "aliquots": [
            {
                "submitter_id": row["aliquots.submitter_id"]
            }
        ]
    }

    for i in col_name:
        value = row[i]
        if isinstance(value, float) and (value == float('inf') or value == float('-inf') or pd.isna(value)):
            dic[i] = str(value)
        else:
            dic[i] = value

    jsondata.append(dic)
    print(jsondata)
    authn = Gen3Auth(COMMONS, refresh_file=API_KEY_FILEPATH)
    output = requests.put(api_url, auth=authn, json=jsondata)
    output.json()
# Out:
# [{'aliquots': [{'submitter_id': 'PR129:metabolite_Liver_frozen_M001'}], 'type': 'mass_spec_assay', 'submitter_id': 'PR129:SYL-TSQ-13-06-21_L1.raw', 'calibration_standard': 'nan', 'chromatography_name': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'chromatography_column': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'chromatography_protocol': 'extracts were first loaded onto a trapping column (C18, 4\u2009×\u20092\u2009mm, Phenomenex) and washed for 30\u2009s with HPLC grade water containing 10\u2009mM tributylamine and 15\u2009mM acetic acid for desalting.', 'elution_program': 'For analysis of hepatic extracts, the LC parameters were as follows: autosampler\r\ntemperature, 10 ºC; injection volume, 10 μl; column temperature, room temperature; and flow\r\nrate, 200 μl∙min-1. The LC solvents were Solvent A: 10 mM tributylamine and 15 mM acetic acid\r\nin 97:3 water:methanol (pH 4.95); and Solvent B: methanol. Elution from the column was\r\nperformed over 50 min with the following gradient: t = 0, 0% B; t = 5, 0% B; t = 10, 20% B; t =\r\n20, 20% B; t = 35, 65% B; t = 38, 95% B; t = 42, 95% B, t = 43, 0% B; t = 50, 0% B.', 'flow_rate': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_method_name': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'ms_protocol': 'ESI spray\r\nvoltage was 3,000 V. Nitrogen was used as the sheath gas at 30 psi and as the auxiliary gas at\r\n10 psi, and argon as the collision gas at 1.5 mTorr, with the capillary temperature at 325 ºC.\r\nScan time for each MRM transition was 0.1 s with a scan width of 1 m/z. The LC runs were\r\ndivided into time segments, with the MRM scans within each time segment containing\r\ncompounds eluting during that time interval. For compounds eluting near boundaries between\r\ntime segments, the MRM scan corresponding to the compound was conducted in both time\r\nsegments. Instrument control, chromatographic control, and data acquisition were performed by\r\nthe Xcalibar software (Thermo Scientific).', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'PR129:metabolite_Liver_frozen_M002'}], 'type': 'mass_spec_assay', 'submitter_id': 'PR129:SYL-TSQ-13-06-21_L1cbz.raw', 'calibration_standard': 'nan', 'chromatography_name': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'chromatography_column': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'chromatography_protocol': 'extracts were first loaded onto a trapping column (C18, 4\u2009×\u20092\u2009mm, Phenomenex) and washed for 30\u2009s with HPLC grade water containing 10\u2009mM tributylamine and 15\u2009mM acetic acid for desalting.', 'elution_program': 'For analysis of hepatic extracts, the LC parameters were as follows: autosampler\n\r\ntemperature, 10 ºC; injection volume, 10 μl; column temperature, room temperature; and flow\n\r\nrate, 200 μl∙min-1. The LC solvents were Solvent A: 10 mM tributylamine and 15 mM acetic acid\n\r\nin 97:3 water:methanol (pH 4.95); and Solvent B: methanol. Elution from the column was\n\r\nperformed over 50 min with the following gradient: t = 0, 0% B; t = 5, 0% B; t = 10, 20% B; t =\n\r\n20, 20% B; t = 35, 65% B; t = 38, 95% B; t = 42, 95% B, t = 43, 0% B; t = 50, 0% B.', 'flow_rate': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_method_name': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'ms_protocol': 'ESI spray\n\r\nvoltage was 3,000 V. Nitrogen was used as the sheath gas at 30 psi and as the auxiliary gas at\n\r\n10 psi, and argon as the collision gas at 1.5 mTorr, with the capillary temperature at 325 ºC.\n\r\nScan time for each MRM transition was 0.1 s with a scan width of 1 m/z. The LC runs were\n\r\ndivided into time segments, with the MRM scans within each time segment containing\n\r\ncompounds eluting during that time interval. For compounds eluting near boundaries between\n\r\ntime segments, the MRM scan corresponding to the compound was conducted in both time\n\r\nsegments. Instrument control, chromatographic control, and data acquisition were performed by\n\r\nthe Xcalibar software (Thermo Scientific).', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'PR129:metabolite_Liver_frozen_M003'}], 'type': 'mass_spec_assay', 'submitter_id': 'PR129:SYL-TSQ-13-06-21_L3.raw', 'calibration_standard': 'nan', 'chromatography_name': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'chromatography_column': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'chromatography_protocol': 'extracts were first loaded onto a trapping column (C18, 4\u2009×\u20092\u2009mm, Phenomenex) and washed for 30\u2009s with HPLC grade water containing 10\u2009mM tributylamine and 15\u2009mM acetic acid for desalting.', 'elution_program': 'For analysis of hepatic extracts, the LC parameters were as follows: autosampler\n\r\ntemperature, 10 ºC; injection volume, 10 μl; column temperature, room temperature; and flow\n\r\nrate, 200 μl∙min-1. The LC solvents were Solvent A: 10 mM tributylamine and 15 mM acetic acid\n\r\nin 97:3 water:methanol (pH 4.95); and Solvent B: methanol. Elution from the column was\n\r\nperformed over 50 min with the following gradient: t = 0, 0% B; t = 5, 0% B; t = 10, 20% B; t =\n\r\n20, 20% B; t = 35, 65% B; t = 38, 95% B; t = 42, 95% B, t = 43, 0% B; t = 50, 0% B.', 'flow_rate': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_method_name': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'ms_protocol': 'ESI spray\n\r\nvoltage was 3,000 V. Nitrogen was used as the sheath gas at 30 psi and as the auxiliary gas at\n\r\n10 psi, and argon as the collision gas at 1.5 mTorr, with the capillary temperature at 325 ºC.\n\r\nScan time for each MRM transition was 0.1 s with a scan width of 1 m/z. The LC runs were\n\r\ndivided into time segments, with the MRM scans within each time segment containing\n\r\ncompounds eluting during that time interval. For compounds eluting near boundaries between\n\r\ntime segments, the MRM scan corresponding to the compound was conducted in both time\n\r\nsegments. Instrument control, chromatographic control, and data acquisition were performed by\n\r\nthe Xcalibar software (Thermo Scientific).', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'PR129:metabolite_Liver_frozen_M004'}], 'type': 'mass_spec_assay', 'submitter_id': 'PR129:SYL-TSQ-13-06-21_L3cbz.raw', 'calibration_standard': 'nan', 'chromatography_name': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'chromatography_column': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'chromatography_protocol': 'extracts were first loaded onto a trapping column (C18, 4\u2009×\u20092\u2009mm, Phenomenex) and washed for 30\u2009s with HPLC grade water containing 10\u2009mM tributylamine and 15\u2009mM acetic acid for desalting.', 'elution_program': 'For analysis of hepatic extracts, the LC parameters were as follows: autosampler\n\r\ntemperature, 10 ºC; injection volume, 10 μl; column temperature, room temperature; and flow\n\r\nrate, 200 μl∙min-1. The LC solvents were Solvent A: 10 mM tributylamine and 15 mM acetic acid\n\r\nin 97:3 water:methanol (pH 4.95); and Solvent B: methanol. Elution from the column was\n\r\nperformed over 50 min with the following gradient: t = 0, 0% B; t = 5, 0% B; t = 10, 20% B; t =\n\r\n20, 20% B; t = 35, 65% B; t = 38, 95% B; t = 42, 95% B, t = 43, 0% B; t = 50, 0% B.', 'flow_rate': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_method_name': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'ms_protocol': 'ESI spray\n\r\nvoltage was 3,000 V. Nitrogen was used as the sheath gas at 30 psi and as the auxiliary gas at\n\r\n10 psi, and argon as the collision gas at 1.5 mTorr, with the capillary temperature at 325 ºC.\n\r\nScan time for each MRM transition was 0.1 s with a scan width of 1 m/z. The LC runs were\n\r\ndivided into time segments, with the MRM scans within each time segment containing\n\r\ncompounds eluting during that time interval. For compounds eluting near boundaries between\n\r\ntime segments, the MRM scan corresponding to the compound was conducted in both time\n\r\nsegments. Instrument control, chromatographic control, and data acquisition were performed by\n\r\nthe Xcalibar software (Thermo Scientific).', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'PR129:metabolite_Liver_frozen_M005'}], 'type': 'mass_spec_assay', 'submitter_id': 'PR129:SYL-TSQ-13-06-21_L4.raw', 'calibration_standard': 'nan', 'chromatography_name': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'chromatography_column': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'chromatography_protocol': 'extracts were first loaded onto a trapping column (C18, 4\u2009×\u20092\u2009mm, Phenomenex) and washed for 30\u2009s with HPLC grade water containing 10\u2009mM tributylamine and 15\u2009mM acetic acid for desalting.', 'elution_program': 'For analysis of hepatic extracts, the LC parameters were as follows: autosampler\n\r\ntemperature, 10 ºC; injection volume, 10 μl; column temperature, room temperature; and flow\n\r\nrate, 200 μl∙min-1. The LC solvents were Solvent A: 10 mM tributylamine and 15 mM acetic acid\n\r\nin 97:3 water:methanol (pH 4.95); and Solvent B: methanol. Elution from the column was\n\r\nperformed over 50 min with the following gradient: t = 0, 0% B; t = 5, 0% B; t = 10, 20% B; t =\n\r\n20, 20% B; t = 35, 65% B; t = 38, 95% B; t = 42, 95% B, t = 43, 0% B; t = 50, 0% B.', 'flow_rate': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_method_name': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'ms_protocol': 'ESI spray\n\r\nvoltage was 3,000 V. Nitrogen was used as the sheath gas at 30 psi and as the auxiliary gas at\n\r\n10 psi, and argon as the collision gas at 1.5 mTorr, with the capillary temperature at 325 ºC.\n\r\nScan time for each MRM transition was 0.1 s with a scan width of 1 m/z. The LC runs were\n\r\ndivided into time segments, with the MRM scans within each time segment containing\n\r\ncompounds eluting during that time interval. For compounds eluting near boundaries between\n\r\ntime segments, the MRM scan corresponding to the compound was conducted in both time\n\r\nsegments. Instrument control, chromatographic control, and data acquisition were performed by\n\r\nthe Xcalibar software (Thermo Scientific).', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'PR129:metabolite_Liver_frozen_M006'}], 'type': 'mass_spec_assay', 'submitter_id': 'PR129:SYL-TSQ-13-06-21_L4cbz.raw', 'calibration_standard': 'nan', 'chromatography_name': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'chromatography_column': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'chromatography_protocol': 'extracts were first loaded onto a trapping column (C18, 4\u2009×\u20092\u2009mm, Phenomenex) and washed for 30\u2009s with HPLC grade water containing 10\u2009mM tributylamine and 15\u2009mM acetic acid for desalting.', 'elution_program': 'For analysis of hepatic extracts, the LC parameters were as follows: autosampler\n\r\ntemperature, 10 ºC; injection volume, 10 μl; column temperature, room temperature; and flow\n\r\nrate, 200 μl∙min-1. The LC solvents were Solvent A: 10 mM tributylamine and 15 mM acetic acid\n\r\nin 97:3 water:methanol (pH 4.95); and Solvent B: methanol. Elution from the column was\n\r\nperformed over 50 min with the following gradient: t = 0, 0% B; t = 5, 0% B; t = 10, 20% B; t =\n\r\n20, 20% B; t = 35, 65% B; t = 38, 95% B; t = 42, 95% B, t = 43, 0% B; t = 50, 0% B.', 'flow_rate': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_method_name': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'ms_protocol': 'ESI spray\n\r\nvoltage was 3,000 V. Nitrogen was used as the sheath gas at 30 psi and as the auxiliary gas at\n\r\n10 psi, and argon as the collision gas at 1.5 mTorr, with the capillary temperature at 325 ºC.\n\r\nScan time for each MRM transition was 0.1 s with a scan width of 1 m/z. The LC runs were\n\r\ndivided into time segments, with the MRM scans within each time segment containing\n\r\ncompounds eluting during that time interval. For compounds eluting near boundaries between\n\r\ntime segments, the MRM scan corresponding to the compound was conducted in both time\n\r\nsegments. Instrument control, chromatographic control, and data acquisition were performed by\n\r\nthe Xcalibar software (Thermo Scientific).', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'PR129:metabolite_Liver_formalin_M001'}], 'type': 'mass_spec_assay', 'submitter_id': 'PR129:SYL-TSQ-13-06-21_L5.raw', 'calibration_standard': 'nan', 'chromatography_name': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'chromatography_column': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'chromatography_protocol': 'extracts were first loaded onto a trapping column (C18, 4\u2009×\u20092\u2009mm, Phenomenex) and washed for 30\u2009s with HPLC grade water containing 10\u2009mM tributylamine and 15\u2009mM acetic acid for desalting.', 'elution_program': 'For analysis of hepatic extracts, the LC parameters were as follows: autosampler\n\r\ntemperature, 10 ºC; injection volume, 10 μl; column temperature, room temperature; and flow\n\r\nrate, 200 μl∙min-1. The LC solvents were Solvent A: 10 mM tributylamine and 15 mM acetic acid\n\r\nin 97:3 water:methanol (pH 4.95); and Solvent B: methanol. Elution from the column was\n\r\nperformed over 50 min with the following gradient: t = 0, 0% B; t = 5, 0% B; t = 10, 20% B; t =\n\r\n20, 20% B; t = 35, 65% B; t = 38, 95% B; t = 42, 95% B, t = 43, 0% B; t = 50, 0% B.', 'flow_rate': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_method_name': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'ms_protocol': 'ESI spray\n\r\nvoltage was 3,000 V. Nitrogen was used as the sheath gas at 30 psi and as the auxiliary gas at\n\r\n10 psi, and argon as the collision gas at 1.5 mTorr, with the capillary temperature at 325 ºC.\n\r\nScan time for each MRM transition was 0.1 s with a scan width of 1 m/z. The LC runs were\n\r\ndivided into time segments, with the MRM scans within each time segment containing\n\r\ncompounds eluting during that time interval. For compounds eluting near boundaries between\n\r\ntime segments, the MRM scan corresponding to the compound was conducted in both time\n\r\nsegments. Instrument control, chromatographic control, and data acquisition were performed by\n\r\nthe Xcalibar software (Thermo Scientific).', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'PR129:metabolite_Liver_formalin_M002'}], 'type': 'mass_spec_assay', 'submitter_id': 'PR129:SYL-TSQ-13-06-21_L58.raw', 'calibration_standard': 'nan', 'chromatography_name': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'chromatography_column': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'chromatography_protocol': 'extracts were first loaded onto a trapping column (C18, 4\u2009×\u20092\u2009mm, Phenomenex) and washed for 30\u2009s with HPLC grade water containing 10\u2009mM tributylamine and 15\u2009mM acetic acid for desalting.', 'elution_program': 'For analysis of hepatic extracts, the LC parameters were as follows: autosampler\n\r\ntemperature, 10 ºC; injection volume, 10 μl; column temperature, room temperature; and flow\n\r\nrate, 200 μl∙min-1. The LC solvents were Solvent A: 10 mM tributylamine and 15 mM acetic acid\n\r\nin 97:3 water:methanol (pH 4.95); and Solvent B: methanol. Elution from the column was\n\r\nperformed over 50 min with the following gradient: t = 0, 0% B; t = 5, 0% B; t = 10, 20% B; t =\n\r\n20, 20% B; t = 35, 65% B; t = 38, 95% B; t = 42, 95% B, t = 43, 0% B; t = 50, 0% B.', 'flow_rate': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_method_name': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'ms_protocol': 'ESI spray\n\r\nvoltage was 3,000 V. Nitrogen was used as the sheath gas at 30 psi and as the auxiliary gas at\n\r\n10 psi, and argon as the collision gas at 1.5 mTorr, with the capillary temperature at 325 ºC.\n\r\nScan time for each MRM transition was 0.1 s with a scan width of 1 m/z. The LC runs were\n\r\ndivided into time segments, with the MRM scans within each time segment containing\n\r\ncompounds eluting during that time interval. For compounds eluting near boundaries between\n\r\ntime segments, the MRM scan corresponding to the compound was conducted in both time\n\r\nsegments. Instrument control, chromatographic control, and data acquisition were performed by\n\r\nthe Xcalibar software (Thermo Scientific).', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'PR129:metabolite_Liver_formalin_M003'}], 'type': 'mass_spec_assay', 'submitter_id': 'PR129:SYL-TSQ-13-06-21_L58cbz.raw', 'calibration_standard': 'nan', 'chromatography_name': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'chromatography_column': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'chromatography_protocol': 'extracts were first loaded onto a trapping column (C18, 4\u2009×\u20092\u2009mm, Phenomenex) and washed for 30\u2009s with HPLC grade water containing 10\u2009mM tributylamine and 15\u2009mM acetic acid for desalting.', 'elution_program': 'For analysis of hepatic extracts, the LC parameters were as follows: autosampler\n\r\ntemperature, 10 ºC; injection volume, 10 μl; column temperature, room temperature; and flow\n\r\nrate, 200 μl∙min-1. The LC solvents were Solvent A: 10 mM tributylamine and 15 mM acetic acid\n\r\nin 97:3 water:methanol (pH 4.95); and Solvent B: methanol. Elution from the column was\n\r\nperformed over 50 min with the following gradient: t = 0, 0% B; t = 5, 0% B; t = 10, 20% B; t =\n\r\n20, 20% B; t = 35, 65% B; t = 38, 95% B; t = 42, 95% B, t = 43, 0% B; t = 50, 0% B.', 'flow_rate': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_method_name': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'ms_protocol': 'ESI spray\n\r\nvoltage was 3,000 V. Nitrogen was used as the sheath gas at 30 psi and as the auxiliary gas at\n\r\n10 psi, and argon as the collision gas at 1.5 mTorr, with the capillary temperature at 325 ºC.\n\r\nScan time for each MRM transition was 0.1 s with a scan width of 1 m/z. The LC runs were\n\r\ndivided into time segments, with the MRM scans within each time segment containing\n\r\ncompounds eluting during that time interval. For compounds eluting near boundaries between\n\r\ntime segments, the MRM scan corresponding to the compound was conducted in both time\n\r\nsegments. Instrument control, chromatographic control, and data acquisition were performed by\n\r\nthe Xcalibar software (Thermo Scientific).', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'PR129:metabolite_Liver_formalin_M004'}], 'type': 'mass_spec_assay', 'submitter_id': 'PR129:SYL-TSQ-13-06-21_L59.raw', 'calibration_standard': 'nan', 'chromatography_name': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'chromatography_column': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'chromatography_protocol': 'extracts were first loaded onto a trapping column (C18, 4\u2009×\u20092\u2009mm, Phenomenex) and washed for 30\u2009s with HPLC grade water containing 10\u2009mM tributylamine and 15\u2009mM acetic acid for desalting.', 'elution_program': 'For analysis of hepatic extracts, the LC parameters were as follows: autosampler\n\r\ntemperature, 10 ºC; injection volume, 10 μl; column temperature, room temperature; and flow\n\r\nrate, 200 μl∙min-1. The LC solvents were Solvent A: 10 mM tributylamine and 15 mM acetic acid\n\r\nin 97:3 water:methanol (pH 4.95); and Solvent B: methanol. Elution from the column was\n\r\nperformed over 50 min with the following gradient: t = 0, 0% B; t = 5, 0% B; t = 10, 20% B; t =\n\r\n20, 20% B; t = 35, 65% B; t = 38, 95% B; t = 42, 95% B, t = 43, 0% B; t = 50, 0% B.', 'flow_rate': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_method_name': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'ms_protocol': 'ESI spray\n\r\nvoltage was 3,000 V. Nitrogen was used as the sheath gas at 30 psi and as the auxiliary gas at\n\r\n10 psi, and argon as the collision gas at 1.5 mTorr, with the capillary temperature at 325 ºC.\n\r\nScan time for each MRM transition was 0.1 s with a scan width of 1 m/z. The LC runs were\n\r\ndivided into time segments, with the MRM scans within each time segment containing\n\r\ncompounds eluting during that time interval. For compounds eluting near boundaries between\n\r\ntime segments, the MRM scan corresponding to the compound was conducted in both time\n\r\nsegments. Instrument control, chromatographic control, and data acquisition were performed by\n\r\nthe Xcalibar software (Thermo Scientific).', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'PR129:metabolite_Liver_formalin_M005'}], 'type': 'mass_spec_assay', 'submitter_id': 'PR129:SYL-TSQ-13-06-21_L59cbz.raw', 'calibration_standard': 'nan', 'chromatography_name': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'chromatography_column': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'chromatography_protocol': 'extracts were first loaded onto a trapping column (C18, 4\u2009×\u20092\u2009mm, Phenomenex) and washed for 30\u2009s with HPLC grade water containing 10\u2009mM tributylamine and 15\u2009mM acetic acid for desalting.', 'elution_program': 'For analysis of hepatic extracts, the LC parameters were as follows: autosampler\n\r\ntemperature, 10 ºC; injection volume, 10 μl; column temperature, room temperature; and flow\n\r\nrate, 200 μl∙min-1. The LC solvents were Solvent A: 10 mM tributylamine and 15 mM acetic acid\n\r\nin 97:3 water:methanol (pH 4.95); and Solvent B: methanol. Elution from the column was\n\r\nperformed over 50 min with the following gradient: t = 0, 0% B; t = 5, 0% B; t = 10, 20% B; t =\n\r\n20, 20% B; t = 35, 65% B; t = 38, 95% B; t = 42, 95% B, t = 43, 0% B; t = 50, 0% B.', 'flow_rate': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_method_name': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'ms_protocol': 'ESI spray\n\r\nvoltage was 3,000 V. Nitrogen was used as the sheath gas at 30 psi and as the auxiliary gas at\n\r\n10 psi, and argon as the collision gas at 1.5 mTorr, with the capillary temperature at 325 ºC.\n\r\nScan time for each MRM transition was 0.1 s with a scan width of 1 m/z. The LC runs were\n\r\ndivided into time segments, with the MRM scans within each time segment containing\n\r\ncompounds eluting during that time interval. For compounds eluting near boundaries between\n\r\ntime segments, the MRM scan corresponding to the compound was conducted in both time\n\r\nsegments. Instrument control, chromatographic control, and data acquisition were performed by\n\r\nthe Xcalibar software (Thermo Scientific).', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]
# [{'aliquots': [{'submitter_id': 'PR129:metabolite_Liver_formalin_M006'}], 'type': 'mass_spec_assay', 'submitter_id': 'PR129:SYL-TSQ-13-06-21_L5cbz.raw', 'calibration_standard': 'nan', 'chromatography_name': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'chromatography_column': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'chromatography_protocol': 'extracts were first loaded onto a trapping column (C18, 4\u2009×\u20092\u2009mm, Phenomenex) and washed for 30\u2009s with HPLC grade water containing 10\u2009mM tributylamine and 15\u2009mM acetic acid for desalting.', 'elution_program': 'For analysis of hepatic extracts, the LC parameters were as follows: autosampler\n\r\ntemperature, 10 ºC; injection volume, 10 μl; column temperature, room temperature; and flow\n\r\nrate, 200 μl∙min-1. The LC solvents were Solvent A: 10 mM tributylamine and 15 mM acetic acid\n\r\nin 97:3 water:methanol (pH 4.95); and Solvent B: methanol. Elution from the column was\n\r\nperformed over 50 min with the following gradient: t = 0, 0% B; t = 5, 0% B; t = 10, 20% B; t =\n\r\n20, 20% B; t = 35, 65% B; t = 38, 95% B; t = 42, 95% B, t = 43, 0% B; t = 50, 0% B.', 'flow_rate': 'nan', 'carrier_gas': 'nan', 'oven_temperature_program': 'nan', 'ms_method_name': 'C18, 4\u2009×\u20092\u2009mm, Phenomenex', 'ms_protocol': 'ESI spray\n\r\nvoltage was 3,000 V. Nitrogen was used as the sheath gas at 30 psi and as the auxiliary gas at\n\r\n10 psi, and argon as the collision gas at 1.5 mTorr, with the capillary temperature at 325 ºC.\n\r\nScan time for each MRM transition was 0.1 s with a scan width of 1 m/z. The LC runs were\n\r\ndivided into time segments, with the MRM scans within each time segment containing\n\r\ncompounds eluting during that time interval. For compounds eluting near boundaries between\n\r\ntime segments, the MRM scan corresponding to the compound was conducted in both time\n\r\nsegments. Instrument control, chromatographic control, and data acquisition were performed by\n\r\nthe Xcalibar software (Thermo Scientific).', 'provenance': 'DataHarmonizer v1.4.10, mass_spec_assay v1.0.0'}]

# %%
# create a folder of files
df = pd.read_table("/Users/apple/Desktop/test_gen3/data_test2/ms_raw_data.tsv")
file_names = df["file_name"].to_list()
for file_name in file_names:
    path = '/Users/apple/Desktop/test_gen3/data_test2/ms_raw_data/' + file_name
    with open(path, 'w') as file:
        file.write(path)

# %%
# automatically insert md5sum and file_size
import pandas as pd
import hashlib
import os
def calculate_md5(file_path):
    """Calculate the MD5 checksum for a file."""
    md5_hash = hashlib.md5()
    with open(file_path, 'rb') as file:
        for chunk in iter(lambda: file.read(4096), b''):
            md5_hash.update(chunk)
    return md5_hash.hexdigest()

# Provide the file name list and DataFrame
df = pd.read_table("/Users/apple/Desktop/test_gen3/data_test2/ms_raw_data.tsv")
file_names = df["file_name"].to_list()

# Provide the path to the folder containing the files
folder_path = '/Users/apple/Desktop/test_gen3/data_test2/ms_raw_data/'

# Update the MD5 checksum for each file name in the DataFrame
for file_name in file_names:
    file_path = folder_path + file_name
    md5_sum = calculate_md5(file_path)
    file_size = os.path.getsize(file_path)
    df.loc[df['file_name'] == file_name, 'md5sum'] = md5_sum
    df.loc[df['file_name'] == file_name, 'file_size'] = file_size
df['file_size'] = df['file_size'].astype(int)
df.to_csv("/Users/apple/Desktop/test_gen3/data_test2/ms_raw_data_revised.tsv", sep='\t', index=False)
df.head()
# Out:
#           type                          submitter_id  \
# 0  ms_raw_data     PR129:new_SYL-TSQ-13-06-21_L1.raw
# 1  ms_raw_data  PR129:new_SYL-TSQ-13-06-21_L1cbz.raw
# 2  ms_raw_data     PR129:new_SYL-TSQ-13-06-21_L3.raw
# 3  ms_raw_data  PR129:new_SYL-TSQ-13-06-21_L3cbz.raw
# 4  ms_raw_data     PR129:new_SYL-TSQ-13-06-21_L4.raw
#
#       mass_spec_assays.submitter_id                       file_name  \
# 0     PR129:SYL-TSQ-13-06-21_L1.raw     new_SYL-TSQ-13-06-21_L1.raw
# 1  PR129:SYL-TSQ-13-06-21_L1cbz.raw  new_SYL-TSQ-13-06-21_L1cbz.raw
# 2     PR129:SYL-TSQ-13-06-21_L3.raw     new_SYL-TSQ-13-06-21_L3.raw
# 3  PR129:SYL-TSQ-13-06-21_L3cbz.raw  new_SYL-TSQ-13-06-21_L3cbz.raw
# 4     PR129:SYL-TSQ-13-06-21_L4.raw     new_SYL-TSQ-13-06-21_L4.raw
#
#            data_category data_format      data_type  file_size  \
# 0  targeted metabolomics        .RAW  chromatograms         81
# 1  targeted metabolomics        .RAW  chromatograms         84
# 2  targeted metabolomics        .RAW  chromatograms         81
# 3  targeted metabolomics        .RAW  chromatograms         84
# 4  targeted metabolomics        .RAW  chromatograms         81
#
#                              md5sum  object_id  provenance
# 0  df25b3497bb1cf7444d5a26d4c3a4fb1        NaN         NaN
# 1  d12396b1c17d783b782df605d9d018e2        NaN         NaN
# 2  16744c266948261aa7eb42f7fa6b2ddd        NaN         NaN
# 3  fa199b36351b259a48feb784001f744a        NaN         NaN
# 4  d2714dc4f7a03596c16686ab8561d873        NaN         NaN

# %%
# ms_raw_Data
data = sub.submit_file(filename="/Users/apple/Desktop/test_gen3/data_test2/ms_raw_data_revised.tsv", project_id="MyFirstProgram-MyFirstProject")
# Out:
# Submitting /Users/apple/Desktop/test_gen3/data_test2/ms_raw_data_revised.tsv with 12 records.
# Chunk 1 (chunk size: 30, submitted: 0 of 12)
# 	 Succeeded: 12 entities.
# Finished data submission.
# Successful records: 12
# Failed invalid records: 0

# %%
df = pd.read_table("/Users/apple/Desktop/test_gen3/data_test2/ms_analysis.tsv")

df.head()
# Out:
#           type                      submitter_id  \
# 0  ms_analysis     PR129:SYL-TSQ-13-06-21_L1.raw
# 1  ms_analysis  PR129:SYL-TSQ-13-06-21_L1cbz.raw
# 2  ms_analysis     PR129:SYL-TSQ-13-06-21_L3.raw
# 3  ms_analysis  PR129:SYL-TSQ-13-06-21_L3cbz.raw
# 4  ms_analysis     PR129:SYL-TSQ-13-06-21_L4.raw
#
#               ms_raw_datas.submitter_id  normalization  transformation  \
# 0     PR129:new_SYL-TSQ-13-06-21_L1.raw  normalization  transformation
# 1  PR129:new_SYL-TSQ-13-06-21_L1cbz.raw  normalization  transformation
# 2     PR129:new_SYL-TSQ-13-06-21_L3.raw  normalization  transformation
# 3  PR129:new_SYL-TSQ-13-06-21_L3cbz.raw  normalization  transformation
# 4     PR129:new_SYL-TSQ-13-06-21_L4.raw  normalization  transformation
#
#   transformation_purpose transformation_description  unit analysis_protocols  \
# 0                purpose                description     1  analysis protocol
# 1                purpose                description     1  analysis protocol
# 2                purpose                description     1  analysis protocol
# 3                purpose                description     1  analysis protocol
# 4                purpose                description     1  analysis protocol
#
#                                        provenance
# 0  DataHarmonizer v1.4.10, mass_spec_assay v1.0.0
# 1  DataHarmonizer v1.4.10, mass_spec_assay v1.0.0
# 2  DataHarmonizer v1.4.10, mass_spec_assay v1.0.0
# 3  DataHarmonizer v1.4.10, mass_spec_assay v1.0.0
# 4  DataHarmonizer v1.4.10, mass_spec_assay v1.0.0

# %%
# ms_analysis
data = sub.submit_file(filename="/Users/apple/Desktop/test_gen3/data_test2/ms_analysis.tsv", project_id="MyFirstProgram-MyFirstProject")
# Out:
# Submitting /Users/apple/Desktop/test_gen3/data_test2/ms_analysis.tsv with 12 records.
# Chunk 1 (chunk size: 30, submitted: 0 of 12)
# 	 Succeeded: 12 entities.
# Finished data submission.
# Successful records: 12
# Failed invalid records: 0

# %%
# create a folder of files
df = pd.read_table("/Users/apple/Desktop/test_gen3/data_test2/ms_analysed_data.tsv")
file_names = df["file_name"].to_list()
for file_name in file_names:
    path = '/Users/apple/Desktop/test_gen3/data_test2/processeddata_ms/' + file_name
    with open(path, 'w') as file:
        file.write(path)

# %%
import pandas as pd
import hashlib
import os
def calculate_md5(file_path):
    """Calculate the MD5 checksum for a file."""
    md5_hash = hashlib.md5()
    with open(file_path, 'rb') as file:
        for chunk in iter(lambda: file.read(4096), b''):
            md5_hash.update(chunk)
    return md5_hash.hexdigest()

# Provide the file name list and DataFrame
df = pd.read_table("/Users/apple/Desktop/test_gen3/data_test2/ms_analysed_data.tsv")
file_names = df["file_name"].to_list()

folder_path = '/Users/apple/Desktop/test_gen3/data_test2/processeddata_ms/'

# Update the MD5 checksum for each file name in the DataFrame
for file_name in file_names:
    file_path = folder_path + file_name
    md5_sum = calculate_md5(file_path)
    file_size = os.path.getsize(file_path)
    df.loc[df['file_name'] == file_name, 'md5sum'] = md5_sum
    df.loc[df['file_name'] == file_name, 'file_size'] = file_size
df['file_size'] = df['file_size'].astype(int)
df.to_csv("/Users/apple/Desktop/test_gen3/data_test2/ms_analysed_data_updated.tsv", sep='\t', index=False)
df.head()
# Out:
#                type       submitter_id          ms_analyses.submitter_id  \
# 0  ms_analysed_data  PR129:processed13     PR129:SYL-TSQ-13-06-21_L1.raw
# 1  ms_analysed_data  PR129:processed14  PR129:SYL-TSQ-13-06-21_L1cbz.raw
# 2  ms_analysed_data  PR129:processed15     PR129:SYL-TSQ-13-06-21_L3.raw
# 3  ms_analysed_data  PR129:processed16  PR129:SYL-TSQ-13-06-21_L3cbz.raw
# 4  ms_analysed_data  PR129:processed17     PR129:SYL-TSQ-13-06-21_L4.raw
#
#      file_name          data_category data_format         data_type  \
# 0  processed13  targeted metabolomics        .txt  integrated peaks
# 1  processed14  targeted metabolomics        .txt  integrated peaks
# 2  processed15  targeted metabolomics        .txt  integrated peaks
# 3  processed16  targeted metabolomics        .txt  integrated peaks
# 4  processed17  targeted metabolomics        .txt  integrated peaks
#
#    file_size                            md5sum  object_id  \
# 0         70  cc541311b0ad787668d3458536711d12        NaN
# 1         70  82511b3614741a13f83dbeaf4c03c6e1        NaN
# 2         70  9073b71cd58f9f2e37c0e19b1396ad26        NaN
# 3         70  67d99088aa978c6e28525e692dc89ac2        NaN
# 4         70  c93279547e218fbce4e5597988bb22ac        NaN
#
#                                        provenance
# 0  DataHarmonizer v1.4.10, mass_spec_assay v1.0.0
# 1  DataHarmonizer v1.4.10, mass_spec_assay v1.0.0
# 2  DataHarmonizer v1.4.10, mass_spec_assay v1.0.0
# 3  DataHarmonizer v1.4.10, mass_spec_assay v1.0.0
# 4  DataHarmonizer v1.4.10, mass_spec_assay v1.0.0

# %%
# ms_analysed_data
data = sub.submit_file(filename="/Users/apple/Desktop/test_gen3/data_test2/ms_analysed_data_updated.tsv", project_id="MyFirstProgram-MyFirstProject")
# Out:
# Submitting /Users/apple/Desktop/test_gen3/data_test2/ms_analysed_data_updated.tsv with 12 records.
# Chunk 1 (chunk size: 30, submitted: 0 of 12)
# 	 Succeeded: 12 entities.
# Finished data submission.
# Successful records: 12
# Failed invalid records: 0

# %%
df = pd.read_table("/Users/apple/Desktop/test_gen3/data_test2/metabolite_id.tsv")
df.head()
# Out:
#             type                                 submitter_id  \
# 0  metabolite_id                 PR129:Oxoglutaric acid_27.81
# 1  metabolite_id               PR129:2-dehydro-D-gluconate_12
# 2  metabolite_id  PR129:2-Hydroxy-2-methylbutanedioic acid_25
# 3  metabolite_id             PR129:isopropyl malic acid_40.51
# 4  metabolite_id       PR129:2-oxo-4-methylthiobutanoate_30.6
#
#   ms_analysed_datas.submitter_id                        metabolite_name  \
# 0              PR129:processed13                 Oxoglutaric acid_27.81
# 1              PR129:processed13               2-dehydro-D-gluconate_12
# 2              PR129:processed13  2-Hydroxy-2-methylbutanedioic acid_25
# 3              PR129:processed13             isopropyl malic acid_40.51
# 4              PR129:processed13       2-oxo-4-methylthiobutanoate_30.6
#
#                        refmet_name  dtxsid  inchikey      mass  elution_time  \
# 0                 Oxoglutaric acid     NaN       NaN  146.0215         27.81
# 1        2-Dehydro-D-gluconic acid     NaN       NaN  194.0427         12.00
# 2                  Citramalic acid     NaN       NaN  148.0372         25.00
# 3              Isopropylmalic acid     NaN       NaN  176.0685         40.51
# 4  2-Oxo-4-methylthiobutanoic acid     NaN       NaN  148.0194         30.60
#
#    provenance
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
# metabolite_id
data = sub.submit_file(filename="/Users/apple/Desktop/test_gen3/data_test2/metabolite_id.tsv", project_id="MyFirstProgram-MyFirstProject")
# Out:
# Submitting /Users/apple/Desktop/test_gen3/data_test2/metabolite_id.tsv with 428 records.
# Chunk 1 (chunk size: 30, submitted: 0 of 428)
# 	 Succeeded: 30 entities.
# Chunk 2 (chunk size: 30, submitted: 30 of 428)
# 	 Succeeded: 30 entities.
# Chunk 3 (chunk size: 30, submitted: 60 of 428)
# 	 Succeeded: 30 entities.
# Chunk 4 (chunk size: 30, submitted: 90 of 428)
# 	 Succeeded: 30 entities.
# Chunk 5 (chunk size: 30, submitted: 120 of 428)
# 	 Succeeded: 30 entities.
# Chunk 6 (chunk size: 30, submitted: 150 of 428)
# 	 Succeeded: 30 entities.
# Chunk 7 (chunk size: 30, submitted: 180 of 428)
# 	 Succeeded: 30 entities.
# Chunk 8 (chunk size: 30, submitted: 210 of 428)
# 	 Succeeded: 30 entities.
# Chunk 9 (chunk size: 30, submitted: 240 of 428)
# 	 Succeeded: 30 entities.
# Chunk 10 (chunk size: 30, submitted: 270 of 428)
# 	 Succeeded: 30 entities.
# Chunk 11 (chunk size: 30, submitted: 300 of 428)
# 	 Succeeded: 30 entities.
# Chunk 12 (chunk size: 30, submitted: 330 of 428)
# 	 Succeeded: 30 entities.
# Chunk 13 (chunk size: 30, submitted: 360 of 428)
# 	Chunk Failed (status code 400): 30 entities.
# 	Invalid records in this chunk: 28
# Retrying submission of valid entities from failed chunk: 2 valid entities.
# Chunk 14 (chunk size: 30, submitted: 388 of 428)
# 	 Succeeded: 2 entities.
# Chunk 15 (chunk size: 30, submitted: 390 of 428)
# 	Chunk Failed (status code 400): 30 entities.
# 	Invalid records in this chunk: 30
# Chunk 16 (chunk size: 30, submitted: 420 of 428)
# 	Chunk Failed (status code 400): 8 entities.
# 	Invalid records in this chunk: 8
# Finished data submission.
# Successful records: 362
# Failed invalid records: 66

# %%
with open("/Users/apple/Desktop/test_gen3/data_test/ReplaceThis.txt", 'w')as file:
    file.write('test')
calculate_md5("/Users/apple/Desktop/test_gen3/data_test/ReplaceThis.txt")

# %%
os.path.getsize("/Users/apple/Desktop/test_gen3/data_test/ReplaceThis.txt")

# %%
# ms_analysed_data
import requests
COMMONS = "https://fairtox.com/"
API_KEY_FILEPATH = '/Users/apple/Desktop/test_gen3/credentials20.json'

projectname = 'MyFirstProject'
programname = 'MyFirstProgram'
api_url = "{}/api/v0/submission/{}/{}".format(COMMONS,programname,projectname)
jsondata = [ 
{
        "type": "ms_analysed_data",
        "submitter_id": "ReplaceThis",
        "file_size": 4,
        "md5sum": '098f6bcd4621d373cade4e832627b4f6',
        "object_id": None,
        "ms_analyses": [
            {
                "submitter_id": "SYL-TSQ-13-06-21_L1"
            }
        ]
    }]
#Auth
print(jsondata)
authn = Gen3Auth(COMMONS, refresh_file=API_KEY_FILEPATH)
output = requests.put(api_url, auth=authn, json=jsondata)
output.json()
# Out:
# [{'type': 'ms_analysed_data', 'submitter_id': 'ReplaceThis', 'file_size': 4, 'md5sum': '098f6bcd4621d373cade4e832627b4f6', 'object_id': None, 'ms_analyses': [{'submitter_id': 'SYL-TSQ-13-06-21_L1'}]}]
# {'code': 200,
#  'created_entity_count': 1,
#  'entities': [{'action': 'create',
#    'errors': [],
#    'id': 'b7229101-7f10-4788-b5f2-b80b3436b92f',
#    'type': 'ms_analysed_data',
#    'unique_keys': [{'project_id': 'MyFirstProgram-MyFirstProject',
#      'submitter_id': 'ReplaceThis'}],
#    'valid': True,
#    'warnings': []}],
#  'entity_error_count': 0,
#  'message': 'Transaction successful.',
#  'success': True,
#  'transaction_id': 444,
#  'transactional_error_count': 0,
#  'transactional_errors': [],
#  'updated_entity_count': 0}

# %%
df = pd.read_table("/Users/apple/Downloads/ms_analysed_data_4.tsv")
df

# %%
df = pd.read_table("/Users/apple/Desktop/test_gen3/data_test/metabolite_id.tsv")
df
# Out:
#               type                           submitter_id  \
# 0    metabolite_id                 Oxoglutaric acid_27.81
# 1    metabolite_id               2-dehydro-D-gluconate_12
# 2    metabolite_id  2-Hydroxy-2-methylbutanedioic acid_25
# 3    metabolite_id             isopropyl malic acid_40.51
# 4    metabolite_id       2-oxo-4-methylthiobutanoate_30.6
# ..             ...                                    ...
# 423  metabolite_id               UDP-D-glucose_0.06867472
# 424  metabolite_id           UDP-D-glucuronate_0.08770466
# 425  metabolite_id    UDP-N-acetyl-glucosamine_0.06857285
# 426  metabolite_id                propionyl-CoA_0.1547353
# 427  metabolite_id                  butyryl-CoA_0.1568367
#
#     ms_analysed_datas.submitter_id                        metabolite_name  \
# 0                      ReplaceThis                 Oxoglutaric acid_27.81
# 1                      ReplaceThis               2-dehydro-D-gluconate_12
# 2                      ReplaceThis  2-Hydroxy-2-methylbutanedioic acid_25
# 3                      ReplaceThis             isopropyl malic acid_40.51
# 4                      ReplaceThis       2-oxo-4-methylthiobutanoate_30.6
# ..                             ...                                    ...
# 423                    ReplaceThis               UDP-D-glucose_0.06867472
# 424                    ReplaceThis           UDP-D-glucuronate_0.08770466
# 425                    ReplaceThis    UDP-N-acetyl-glucosamine_0.06857285
# 426                    ReplaceThis                propionyl-CoA_0.1547353
# 427                    ReplaceThis                  butyryl-CoA_0.1568367
#
#                          refmet_name  dtxsid  inchikey      mass  \
# 0                   Oxoglutaric acid     NaN       NaN  146.0215
# 1          2-Dehydro-D-gluconic acid     NaN       NaN  194.0427
# 2                    Citramalic acid     NaN       NaN  148.0372
# 3                Isopropylmalic acid     NaN       NaN  176.0685
# 4    2-Oxo-4-methylthiobutanoic acid     NaN       NaN  148.0194
# ..                               ...     ...       ...       ...
# 423                      UDP-glucose     NaN       NaN  566.0550
# 424              UDP-glucuronic acid     NaN       NaN  580.0343
# 425          UDP-N-acetylglucosamine     NaN       NaN  607.0816
# 426                    Propionyl-CoA     NaN       NaN  823.1414
# 427                      Butyryl-CoA     NaN       NaN  837.1571
#
#      elution_time  provenance
# 0       27.810000         NaN
# 1       12.000000         NaN
# 2       25.000000         NaN
# 3       40.510000         NaN
# 4       30.600000         NaN
# ..            ...         ...
# 423      0.068675         NaN
# 424      0.087705         NaN
# 425      0.068573         NaN
# 426      0.154735         NaN
# 427      0.156837         NaN
#
# [428 rows x 10 columns]

# %%
# metabolite_id
data = sub.submit_file(filename="/Users/apple/Desktop/test_gen3/data_test/metabolite_id.tsv", project_id="MyFirstProgram-MyFirstProject")
# Out:
# Submitting /Users/apple/Desktop/test_gen3/data_test/metabolite_id.tsv with 428 records.
# Chunk 1 (chunk size: 30, submitted: 0 of 428)
# 	 Succeeded: 30 entities.
# Chunk 2 (chunk size: 30, submitted: 30 of 428)
# 	 Succeeded: 30 entities.
# Chunk 3 (chunk size: 30, submitted: 60 of 428)
# 	 Succeeded: 30 entities.
# Chunk 4 (chunk size: 30, submitted: 90 of 428)
# 	 Succeeded: 30 entities.
# Chunk 5 (chunk size: 30, submitted: 120 of 428)
# 	 Succeeded: 30 entities.
# Chunk 6 (chunk size: 30, submitted: 150 of 428)
# 	 Succeeded: 30 entities.
# Chunk 7 (chunk size: 30, submitted: 180 of 428)
# 	 Succeeded: 30 entities.
# Chunk 8 (chunk size: 30, submitted: 210 of 428)
# 	 Succeeded: 30 entities.
# Chunk 9 (chunk size: 30, submitted: 240 of 428)
# 	 Succeeded: 30 entities.
# Chunk 10 (chunk size: 30, submitted: 270 of 428)
# 	 Succeeded: 30 entities.
# Chunk 11 (chunk size: 30, submitted: 300 of 428)
# 	 Succeeded: 30 entities.
# Chunk 12 (chunk size: 30, submitted: 330 of 428)
# 	 Succeeded: 30 entities.
# Chunk 13 (chunk size: 30, submitted: 360 of 428)
# 	 Succeeded: 30 entities.
# Chunk 14 (chunk size: 30, submitted: 390 of 428)
# 	 Succeeded: 30 entities.
# Chunk 15 (chunk size: 30, submitted: 420 of 428)
# 	 Succeeded: 8 entities.
# Finished data submission.
# Successful records: 428
# Failed invalid records: 0
